# %%
# -*- coding: utf-8 -*-

from matplotlib import pyplot as plt
import numpy as np
import random
from torch.utils.data import Dataset, DataLoader
import torch
import os
from torch.optim import *
from torch import nn
from torch.nn import functional as F
from scipy import ndimage
import pandas as pd
from copy import deepcopy
import random
from sklearn.metrics import f1_score

random.seed(7)
torch.cuda.manual_seed(7)
torch.manual_seed(7)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(7)

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
DATA_ROOT = '/beegfs/bva212/openmic-2018'
OPENMIC = np.load(os.path.join(DATA_ROOT, 'openmic-2018.npz'))
X, Y_true, Y_mask, sample_key = OPENMIC['X'], OPENMIC['Y_true'], OPENMIC['Y_mask'], OPENMIC['sample_key']

# %%
len_data = Y_mask.shape[0]
idx_train = np.random.choice(len_data, int(len_data*0.7), replace=False)
remain_set = set(np.arange(len_data))-set(idx_train)
idx_test = np.random.choice(list(remain_set), int(len_data*0.1), replace=False)
idx_val = list(remain_set-set(idx_test))

# %%
Y_mask_val = Y_mask[idx_val]
Y_mask_test = Y_mask[idx_test]

label_val = Y_true[idx_val]
label_test = Y_true[idx_test]

# %%
class ArrowOfTime(Dataset):

    def __init__(self, root_dir, files, weights, label):
        self.weights = weights
        self.device = device
        self.root_dir = root_dir
        self.files = files
        self.label = label

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        logscalogram = (np.load(self.root_dir + self.files[idx]+'_cqt.npy') - -24.3633)/14.2659
        weight = self.weights[idx]
        label = (self.label[idx] > 0.5).astype(int)
        return {'logscalogram': logscalogram[np.newaxis, :], 'label': label[np.newaxis, :], 'weight': weight[np.newaxis, :]}

filenames = []
root_dir = '/beegfs/bva212/openmic-2018/cqt_full/'

BATCH_SIZE = 32

def my_collate(batch):
    data = np.stack([item['logscalogram'] for item in batch])
    target = np.concatenate([item['label'] for item in batch],axis=0)
    weight = np.concatenate([item['weight'] for item in batch],axis=0)
    weight_sum = weight.sum(0)
    weight_sum = np.repeat(weight_sum[np.newaxis, :], len(batch), 0)
    weight_sum[weight_sum==0]=1
    weight = weight/weight_sum
    return [torch.from_numpy(data).float(), torch.from_numpy(target).float(), torch.from_numpy(weight).float()]

# %%
class snet2_jigsaw(nn.Module):

    def __init__(self, output_classes = 20):
        '''
        Create the 5 Conv Layer Sound Net network architecture as per the paper - https://arxiv.org/pdf/1610.09001.pdf
        '''
        super(snet2_jigsaw, self).__init__()

        self.conv_layers = nn.Sequential(nn.Conv2d(in_channels = 1, out_channels= 16, kernel_size = 5, stride = 2, padding = 5), 
                                nn.BatchNorm2d(num_features = 16), 
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = 5, stride = 2, padding = 5),
                                nn.BatchNorm2d(32),
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = 5, padding = 5),
                                nn.BatchNorm2d(64),
                                nn.ReLU(inplace = True),
                                nn.AvgPool2d(kernel_size = 3),

                                nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 4, padding = 4),
                                nn.BatchNorm2d(128),
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = 4, padding = 4),
                                nn.BatchNorm2d(256),
                                nn.ReLU(inplace = True),
                                nn.AvgPool2d(kernel_size = 3),

                                nn.Conv2d(in_channels = 256, out_channels = 512, kernel_size = 3, stride = 2, padding = 3),
                                nn.BatchNorm2d(512),
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 512, out_channels = 1024, kernel_size = 3, stride = 2, padding = 3),
                                nn.BatchNorm2d(1024),
                                nn.ReLU(inplace = True),
                                nn.AdaptiveAvgPool2d(output_size = 1)
                                )
        self.mlp_layer = nn.Linear(1024, output_classes)
              
    def forward(self, input):
        out = self.conv_layers(input)
        out = self.mlp_layer(out.view(out.shape[0], -1))
        return out
    
    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, a=0, mode='fan_in', nonlinearity='relu')
        
# Function for testing the model
def test_model(loader, model):
    correct = 0
    total_loss = 0
    total = 0
    total_num = 0
    actual_arr = []
    predicted_arr = []
    weight_array = []
    model.eval()
    with torch.no_grad():
        for spectrogram, target, weight in loader:
            spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
            outputs = model(spectrogram_batch)
            loss = F.binary_cross_entropy_with_logits(outputs, target_batch,
                                                  weight = weight_batch,
                                                  reduction='sum')
            predicted = (torch.sigmoid(outputs.data)>0.5).float()
            
            actual_arr.extend(target.view(1,-1).squeeze().numpy().astype(int).tolist())
            predicted_arr.extend(predicted.view(1,-1).squeeze().cpu().numpy().astype(int).tolist())
            
            total_loss += loss.item()
            total += weight_batch.shape[0]
            
            correct += ((weight_batch != 0).float()*(predicted.eq(target_batch.view_as(predicted)).float())).sum().item()
            total_num += (weight_batch != 0).sum().item()
            weight_array = np.concatenate((weight_array,(weight != 0).reshape(-1).numpy().astype(int)))
        accuracy = (100 * correct / total_num)
        return accuracy, f1_score(actual_arr, predicted_arr, average='micro', sample_weight = weight_array), total_loss/total

def train_model(train_loader, val_loader, model, optimizer, scheduler, num_epochs):
    train_acc_list = []
    train_loss_list = []
    val_acc_list = []
    val_loss_list = []
    train_f1_list = []
    val_f1_list = []
    best_val_acc = 0
    for epoch in range(num_epochs):
        for spectrogram, target, weight in train_loader:
            model.train()
            spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
            optimizer.zero_grad()
            outputs = model(spectrogram_batch)
            loss = F.binary_cross_entropy_with_logits(outputs, target_batch,
                                                  weight = weight_batch,
                                                  reduction='sum')
            loss.backward()
            optimizer.step()
        train_acc, f1_score_train, train_loss = test_model(train_loader, model)
        val_acc, f1_score_val, val_loss = test_model(val_loader, model)
        
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state_dict = deepcopy(model.state_dict())
        
        train_acc_list.append(train_acc)
        train_f1_list.append(f1_score_train)
        train_loss_list.append(train_loss)
        val_f1_list.append(f1_score_val)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)
        
        scheduler.step(val_acc)
        print("Epoch:{}".format(epoch+1))
        print("Validation Accuracy:{:.2f}, Validation F1:{:.2f}, Val Loss: {:.5f}".format(val_acc, f1_score_val, val_loss))
        print("Training Acc: {:.2f}, Training F1:{:.2f}, Train Loss: {:.5f}".format(train_acc, f1_score_train, train_loss))
    return train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict

# %%
import pickle
sizes = [10, 50, 250, 500, 1000, 1500]

Model_Data = pickle.load(open('List_indices_data_size_exp.pkl', 'rb'))

Val_dataset = ArrowOfTime(root_dir, sample_key[idx_val], Y_mask_val, label_val)
Val_loader = torch.utils.data.DataLoader(dataset = Val_dataset, 
                                              batch_size = BATCH_SIZE,
                                              shuffle = True,
                                        collate_fn = my_collate)

Test_dataset = ArrowOfTime(root_dir, sample_key[idx_test], Y_mask_test, label_test)
Test_loader = torch.utils.data.DataLoader(dataset = Test_dataset, 
                                              batch_size = BATCH_SIZE,
                                              shuffle = True,
                                        collate_fn = my_collate)

results_dict = {}

for i in range(len(sizes)):
    if sizes[i] != 1500:
        idx_train_new = Model_Data[i]
        Y_mask_train = Y_mask[idx_train_new]
        label_train = Y_true[idx_train_new]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train_new], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)
    else:
        Y_mask_train = Y_mask[idx_train]
        label_train = Y_true[idx_train]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)

    
    weights = torch.load('/beegfs/sc6957/capstone/models/20191106/snet2_jigsaw_large_best_model.pth')['modelStateDict']
    model = snet2_jigsaw(20)
    reqd_weights = {key:value for key, value in weights.items() if key in model.state_dict() and key[:9] != 'mlp_layer'}
    reqd_weights["mlp_layer.weight"] = model.mlp_layer.weight
    reqd_weights["mlp_layer.bias"] = model.mlp_layer.bias
    model.load_state_dict(reqd_weights)
    model.to(device)
    learning_rate = 10**(-2)
    num_epochs = 50 # number epoch to train

    optimizer = torch.optim.Adam([param for param in model.parameters() if param.requires_grad == True], lr=learning_rate, weight_decay = 0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=2, verbose=True, threshold=0.03,
                                                           threshold_mode='abs', cooldown=0, min_lr=0, eps=1e-08)

    train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict = train_model(Train_loader, Val_loader, model, optimizer, scheduler, num_epochs)
    results_dict[sizes[i]] = {
        'train_acc_list':train_acc_list,
        'train_loss_list': train_loss_list,
        'val_acc_list': val_acc_list,
        'val_loss_list': val_loss_list,
        'best_model_state_dict': best_model_state_dict
    }
pickle.dump(results_dict, open('Size_Exp_Jigsaw_Wt_NoLin_Results.pkl'.format(sizes[i]),'wb'))
# Out:
# Epoch:1
# Validation Accuracy:57.69, Validation F1:0.58, Val Loss: 13.09279
# Training Acc: 60.81, Training F1:0.61, Train Loss: 11.64351
# Epoch:2
# Validation Accuracy:61.29, Validation F1:0.61, Val Loss: 0.40483
# Training Acc: 62.39, Training F1:0.62, Train Loss: 0.42143
# Epoch:3
# Validation Accuracy:58.38, Validation F1:0.58, Val Loss: 0.40425
# Training Acc: 62.61, Training F1:0.63, Train Loss: 0.42197
# Epoch:4
# Validation Accuracy:60.79, Validation F1:0.61, Val Loss: 0.40131
# Training Acc: 63.06, Training F1:0.63, Train Loss: 0.41892
# Epoch:5
# Validation Accuracy:62.63, Validation F1:0.63, Val Loss: 0.39506
# Training Acc: 63.29, Training F1:0.63, Train Loss: 0.39489
# Epoch:6
# Validation Accuracy:60.69, Validation F1:0.61, Val Loss: 0.39412
# Training Acc: 63.74, Training F1:0.64, Train Loss: 0.39535
# Epoch:7
# Validation Accuracy:60.25, Validation F1:0.60, Val Loss: 0.40000
# Training Acc: 63.74, Training F1:0.64, Train Loss: 0.42032
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:8
# Validation Accuracy:60.37, Validation F1:0.60, Val Loss: 0.39926
# Training Acc: 62.84, Training F1:0.63, Train Loss: 0.41141
# Epoch:9
# Validation Accuracy:60.86, Validation F1:0.61, Val Loss: 0.40113
# Training Acc: 65.09, Training F1:0.65, Train Loss: 0.38196
# Epoch:10
# Validation Accuracy:61.23, Validation F1:0.61, Val Loss: 0.39557
# Training Acc: 65.99, Training F1:0.66, Train Loss: 0.37687
# Epoch    10: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:11
# Validation Accuracy:61.37, Validation F1:0.61, Val Loss: 0.40027
# Training Acc: 65.77, Training F1:0.66, Train Loss: 0.38673
# Epoch:12
# Validation Accuracy:61.38, Validation F1:0.61, Val Loss: 0.40171
# Training Acc: 66.89, Training F1:0.67, Train Loss: 0.37456
# Epoch:13
# Validation Accuracy:61.39, Validation F1:0.61, Val Loss: 0.40831
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.36169
# Epoch    13: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:14
# Validation Accuracy:61.43, Validation F1:0.61, Val Loss: 0.41299
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37656
# Epoch:15
# Validation Accuracy:61.54, Validation F1:0.62, Val Loss: 0.40818
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.35642
# Epoch:16
# Validation Accuracy:61.36, Validation F1:0.61, Val Loss: 0.41801
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.35836
# Epoch    16: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:17
# Validation Accuracy:61.50, Validation F1:0.62, Val Loss: 0.40956
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.36854
# Epoch:18
# Validation Accuracy:61.45, Validation F1:0.61, Val Loss: 0.41201
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.38651
# Epoch:19
# Validation Accuracy:61.49, Validation F1:0.61, Val Loss: 0.40907
# Training Acc: 67.57, Training F1:0.68, Train Loss: 0.38022
# Epoch    19: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:20
# Validation Accuracy:61.38, Validation F1:0.61, Val Loss: 0.41224
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.37143
# Epoch:21
# Validation Accuracy:61.44, Validation F1:0.61, Val Loss: 0.41392
# Training Acc: 68.24, Training F1:0.68, Train Loss: 0.35132
# Epoch:22
# Validation Accuracy:61.47, Validation F1:0.61, Val Loss: 0.41616
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.36278
# Epoch    22: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:23
# Validation Accuracy:61.47, Validation F1:0.61, Val Loss: 0.41604
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37736
# Epoch:24
# Validation Accuracy:61.48, Validation F1:0.61, Val Loss: 0.41766
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.38154
# Epoch:25
# Validation Accuracy:61.43, Validation F1:0.61, Val Loss: 0.41472
# Training Acc: 68.24, Training F1:0.68, Train Loss: 0.35982
# Epoch:26
# Validation Accuracy:61.43, Validation F1:0.61, Val Loss: 0.41544
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.35849
# Epoch:27
# Validation Accuracy:61.48, Validation F1:0.61, Val Loss: 0.41848
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.37912
# Epoch:28
# Validation Accuracy:61.48, Validation F1:0.61, Val Loss: 0.42471
# Training Acc: 67.57, Training F1:0.68, Train Loss: 0.36436
# Epoch:29
# Validation Accuracy:61.47, Validation F1:0.61, Val Loss: 0.41567
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.36613
# Epoch:30
# Validation Accuracy:61.39, Validation F1:0.61, Val Loss: 0.41760
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.38181
# Epoch:31
# Validation Accuracy:61.42, Validation F1:0.61, Val Loss: 0.41205
# Training Acc: 68.24, Training F1:0.68, Train Loss: 0.36785
# Epoch:32
# Validation Accuracy:61.41, Validation F1:0.61, Val Loss: 0.41164
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.37625
# Epoch:33
# Validation Accuracy:61.45, Validation F1:0.61, Val Loss: 0.41285
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.37897
# Epoch:34
# Validation Accuracy:61.42, Validation F1:0.61, Val Loss: 0.41841
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37268
# Epoch:35
# Validation Accuracy:61.47, Validation F1:0.61, Val Loss: 0.41436
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.36941
# Epoch:36
# Validation Accuracy:61.45, Validation F1:0.61, Val Loss: 0.41558
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.34700
# Epoch:37
# Validation Accuracy:61.39, Validation F1:0.61, Val Loss: 0.41591
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.37952
# Epoch:38
# Validation Accuracy:61.39, Validation F1:0.61, Val Loss: 0.41282
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.36850
# Epoch:39
# Validation Accuracy:61.48, Validation F1:0.61, Val Loss: 0.42069
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.35537
# Epoch:40
# Validation Accuracy:61.42, Validation F1:0.61, Val Loss: 0.42256
# Training Acc: 67.57, Training F1:0.68, Train Loss: 0.38375
# Epoch:41
# Validation Accuracy:61.45, Validation F1:0.61, Val Loss: 0.42131
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.36956
# Epoch:42
# Validation Accuracy:61.47, Validation F1:0.61, Val Loss: 0.41819
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.38148
# Epoch:43
# Validation Accuracy:61.45, Validation F1:0.61, Val Loss: 0.41378
# Training Acc: 67.57, Training F1:0.68, Train Loss: 0.37274
# Epoch:44
# Validation Accuracy:61.44, Validation F1:0.61, Val Loss: 0.42270
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37737
# Epoch:45
# Validation Accuracy:61.49, Validation F1:0.61, Val Loss: 0.41447
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37011
# Epoch:46
# Validation Accuracy:61.43, Validation F1:0.61, Val Loss: 0.42360
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.36368
# Epoch:47
# Validation Accuracy:61.43, Validation F1:0.61, Val Loss: 0.41856
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37054
# Epoch:48
# Validation Accuracy:61.44, Validation F1:0.61, Val Loss: 0.41939
# Training Acc: 68.02, Training F1:0.68, Train Loss: 0.37805
# Epoch:49
# Validation Accuracy:61.45, Validation F1:0.61, Val Loss: 0.41685
# Training Acc: 67.79, Training F1:0.68, Train Loss: 0.38725
# Epoch:50
# Validation Accuracy:61.41, Validation F1:0.61, Val Loss: 0.42196
# Training Acc: 67.57, Training F1:0.68, Train Loss: 0.35830
# Epoch:1
# Validation Accuracy:62.87, Validation F1:0.63, Val Loss: 0.39022
# Training Acc: 63.38, Training F1:0.63, Train Loss: 0.39276
# Epoch:2
# Validation Accuracy:63.99, Validation F1:0.64, Val Loss: 0.39296
# Training Acc: 64.11, Training F1:0.64, Train Loss: 0.38771
# Epoch:3
# Validation Accuracy:65.73, Validation F1:0.66, Val Loss: 0.38489
# Training Acc: 66.28, Training F1:0.66, Train Loss: 0.37879
# Epoch:4
# Validation Accuracy:64.54, Validation F1:0.65, Val Loss: 0.39109
# Training Acc: 63.48, Training F1:0.63, Train Loss: 0.39467
# Epoch:5
# Validation Accuracy:64.22, Validation F1:0.64, Val Loss: 0.38115
# Training Acc: 65.89, Training F1:0.66, Train Loss: 0.37676
# Epoch     5: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:6
# Validation Accuracy:61.76, Validation F1:0.62, Val Loss: 0.39023
# Training Acc: 63.62, Training F1:0.64, Train Loss: 0.38605
# Epoch:7
# Validation Accuracy:68.66, Validation F1:0.69, Val Loss: 0.34861
# Training Acc: 70.24, Training F1:0.70, Train Loss: 0.34501
# Epoch:8
# Validation Accuracy:70.13, Validation F1:0.70, Val Loss: 0.33851
# Training Acc: 71.35, Training F1:0.71, Train Loss: 0.33587
# Epoch:9
# Validation Accuracy:70.23, Validation F1:0.70, Val Loss: 0.33585
# Training Acc: 72.56, Training F1:0.73, Train Loss: 0.32182
# Epoch:10
# Validation Accuracy:70.61, Validation F1:0.71, Val Loss: 0.33101
# Training Acc: 71.35, Training F1:0.71, Train Loss: 0.32461
# Epoch:11
# Validation Accuracy:67.62, Validation F1:0.68, Val Loss: 0.35268
# Training Acc: 70.24, Training F1:0.70, Train Loss: 0.33036
# Epoch:12
# Validation Accuracy:70.93, Validation F1:0.71, Val Loss: 0.33711
# Training Acc: 72.37, Training F1:0.72, Train Loss: 0.31942
# Epoch:13
# Validation Accuracy:70.21, Validation F1:0.70, Val Loss: 0.33037
# Training Acc: 73.24, Training F1:0.73, Train Loss: 0.31312
# Epoch:14
# Validation Accuracy:70.25, Validation F1:0.70, Val Loss: 0.33143
# Training Acc: 72.80, Training F1:0.73, Train Loss: 0.31751
# Epoch:15
# Validation Accuracy:71.81, Validation F1:0.72, Val Loss: 0.32311
# Training Acc: 74.69, Training F1:0.75, Train Loss: 0.29367
# Epoch:16
# Validation Accuracy:71.48, Validation F1:0.71, Val Loss: 0.32717
# Training Acc: 75.65, Training F1:0.76, Train Loss: 0.29659
# Epoch:17
# Validation Accuracy:71.36, Validation F1:0.71, Val Loss: 0.32987
# Training Acc: 74.01, Training F1:0.74, Train Loss: 0.30030
# Epoch    17: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:18
# Validation Accuracy:71.52, Validation F1:0.72, Val Loss: 0.33351
# Training Acc: 75.51, Training F1:0.76, Train Loss: 0.29218
# Epoch:19
# Validation Accuracy:72.04, Validation F1:0.72, Val Loss: 0.31828
# Training Acc: 76.18, Training F1:0.76, Train Loss: 0.28197
# Epoch:20
# Validation Accuracy:72.22, Validation F1:0.72, Val Loss: 0.32002
# Training Acc: 76.62, Training F1:0.77, Train Loss: 0.27901
# Epoch:21
# Validation Accuracy:71.96, Validation F1:0.72, Val Loss: 0.31745
# Training Acc: 76.71, Training F1:0.77, Train Loss: 0.28248
# Epoch:22
# Validation Accuracy:72.06, Validation F1:0.72, Val Loss: 0.31806
# Training Acc: 77.29, Training F1:0.77, Train Loss: 0.27737
# Epoch    22: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:23
# Validation Accuracy:71.97, Validation F1:0.72, Val Loss: 0.32264
# Training Acc: 76.91, Training F1:0.77, Train Loss: 0.27279
# Epoch:24
# Validation Accuracy:72.11, Validation F1:0.72, Val Loss: 0.31932
# Training Acc: 76.71, Training F1:0.77, Train Loss: 0.27035
# Epoch:25
# Validation Accuracy:72.05, Validation F1:0.72, Val Loss: 0.32164
# Training Acc: 77.05, Training F1:0.77, Train Loss: 0.27779
# Epoch    25: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:26
# Validation Accuracy:72.07, Validation F1:0.72, Val Loss: 0.31865
# Training Acc: 76.91, Training F1:0.77, Train Loss: 0.27487
# Epoch:27
# Validation Accuracy:72.26, Validation F1:0.72, Val Loss: 0.31910
# Training Acc: 76.96, Training F1:0.77, Train Loss: 0.27666
# Epoch:28
# Validation Accuracy:72.18, Validation F1:0.72, Val Loss: 0.32215
# Training Acc: 76.96, Training F1:0.77, Train Loss: 0.26573
# Epoch:29
# Validation Accuracy:72.13, Validation F1:0.72, Val Loss: 0.31713
# Training Acc: 77.05, Training F1:0.77, Train Loss: 0.27785
# Epoch    29: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:30
# Validation Accuracy:72.14, Validation F1:0.72, Val Loss: 0.31976
# Training Acc: 77.10, Training F1:0.77, Train Loss: 0.27902
# Epoch:31
# Validation Accuracy:72.17, Validation F1:0.72, Val Loss: 0.31705
# Training Acc: 77.00, Training F1:0.77, Train Loss: 0.27492
# Epoch:32
# Validation Accuracy:72.12, Validation F1:0.72, Val Loss: 0.31726
# Training Acc: 76.91, Training F1:0.77, Train Loss: 0.26975
# Epoch    32: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:33
# Validation Accuracy:72.16, Validation F1:0.72, Val Loss: 0.31507
# Training Acc: 77.10, Training F1:0.77, Train Loss: 0.27127
# Epoch:34
# Validation Accuracy:72.06, Validation F1:0.72, Val Loss: 0.31723
# Training Acc: 76.91, Training F1:0.77, Train Loss: 0.26897
# Epoch:35
# Validation Accuracy:72.11, Validation F1:0.72, Val Loss: 0.31787
# Training Acc: 77.00, Training F1:0.77, Train Loss: 0.26885
# Epoch:36
# Validation Accuracy:72.14, Validation F1:0.72, Val Loss: 0.31664
# Training Acc: 77.15, Training F1:0.77, Train Loss: 0.27455
# Epoch:37
# Validation Accuracy:72.01, Validation F1:0.72, Val Loss: 0.31671
# Training Acc: 76.96, Training F1:0.77, Train Loss: 0.27474
# Epoch:38
# Validation Accuracy:72.08, Validation F1:0.72, Val Loss: 0.31983
# Training Acc: 76.76, Training F1:0.77, Train Loss: 0.27636
# Epoch:39
# Validation Accuracy:72.04, Validation F1:0.72, Val Loss: 0.31960
# Training Acc: 76.81, Training F1:0.77, Train Loss: 0.27437
# Epoch:40
# Validation Accuracy:72.17, Validation F1:0.72, Val Loss: 0.32295
# Training Acc: 77.15, Training F1:0.77, Train Loss: 0.26790
# Epoch:41
# Validation Accuracy:72.08, Validation F1:0.72, Val Loss: 0.32209
# Training Acc: 76.81, Training F1:0.77, Train Loss: 0.27620
# Epoch:42
# Validation Accuracy:72.06, Validation F1:0.72, Val Loss: 0.32262
# Training Acc: 76.86, Training F1:0.77, Train Loss: 0.26670
# Epoch:43
# Validation Accuracy:72.07, Validation F1:0.72, Val Loss: 0.31898
# Training Acc: 77.20, Training F1:0.77, Train Loss: 0.26696
# Epoch:44
# Validation Accuracy:72.14, Validation F1:0.72, Val Loss: 0.31493
# Training Acc: 76.81, Training F1:0.77, Train Loss: 0.26999
# Epoch:45
# Validation Accuracy:72.20, Validation F1:0.72, Val Loss: 0.31766
# Training Acc: 76.71, Training F1:0.77, Train Loss: 0.27025
# Epoch:46
# Validation Accuracy:72.06, Validation F1:0.72, Val Loss: 0.31516
# Training Acc: 76.86, Training F1:0.77, Train Loss: 0.27513
# Epoch:47
# Validation Accuracy:72.07, Validation F1:0.72, Val Loss: 0.31982
# Training Acc: 76.96, Training F1:0.77, Train Loss: 0.27533
# Epoch:48
# Validation Accuracy:72.11, Validation F1:0.72, Val Loss: 0.31887
# Training Acc: 77.00, Training F1:0.77, Train Loss: 0.27165
# Epoch:49
# Validation Accuracy:72.07, Validation F1:0.72, Val Loss: 0.31667
# Training Acc: 76.86, Training F1:0.77, Train Loss: 0.27822
# Epoch:50
# Validation Accuracy:72.16, Validation F1:0.72, Val Loss: 0.31967
# Training Acc: 77.10, Training F1:0.77, Train Loss: 0.27104
# Epoch:1
# Validation Accuracy:66.16, Validation F1:0.66, Val Loss: 0.38472
# Training Acc: 65.05, Training F1:0.65, Train Loss: 0.38246
# Epoch:2
# Validation Accuracy:66.53, Validation F1:0.67, Val Loss: 0.37158
# Training Acc: 66.08, Training F1:0.66, Train Loss: 0.37384
# Epoch:3
# Validation Accuracy:60.62, Validation F1:0.61, Val Loss: 0.60703
# Training Acc: 60.01, Training F1:0.60, Train Loss: 0.59951
# Epoch:4
# Validation Accuracy:68.61, Validation F1:0.69, Val Loss: 0.36026
# Training Acc: 68.03, Training F1:0.68, Train Loss: 0.36039
# Epoch:5
# Validation Accuracy:69.44, Validation F1:0.69, Val Loss: 0.34360
# Training Acc: 69.47, Training F1:0.69, Train Loss: 0.34383
# Epoch:6
# Validation Accuracy:70.50, Validation F1:0.71, Val Loss: 0.32986
# Training Acc: 70.06, Training F1:0.70, Train Loss: 0.33783
# Epoch:7
# Validation Accuracy:70.44, Validation F1:0.70, Val Loss: 0.33178
# Training Acc: 69.28, Training F1:0.69, Train Loss: 0.33588
# Epoch:8
# Validation Accuracy:70.88, Validation F1:0.71, Val Loss: 0.35350
# Training Acc: 69.85, Training F1:0.70, Train Loss: 0.35233
# Epoch:9
# Validation Accuracy:70.60, Validation F1:0.71, Val Loss: 0.34437
# Training Acc: 69.95, Training F1:0.70, Train Loss: 0.34794
# Epoch:10
# Validation Accuracy:71.06, Validation F1:0.71, Val Loss: 0.33174
# Training Acc: 71.25, Training F1:0.71, Train Loss: 0.33363
# Epoch:11
# Validation Accuracy:70.37, Validation F1:0.70, Val Loss: 0.33073
# Training Acc: 70.29, Training F1:0.70, Train Loss: 0.32633
# Epoch:12
# Validation Accuracy:70.62, Validation F1:0.71, Val Loss: 0.34036
# Training Acc: 69.76, Training F1:0.70, Train Loss: 0.34189
# Epoch    12: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:13
# Validation Accuracy:68.11, Validation F1:0.68, Val Loss: 0.35933
# Training Acc: 67.86, Training F1:0.68, Train Loss: 0.35959
# Epoch:14
# Validation Accuracy:72.45, Validation F1:0.72, Val Loss: 0.31465
# Training Acc: 72.14, Training F1:0.72, Train Loss: 0.31628
# Epoch:15
# Validation Accuracy:72.95, Validation F1:0.73, Val Loss: 0.31185
# Training Acc: 72.57, Training F1:0.73, Train Loss: 0.31018
# Epoch:16
# Validation Accuracy:72.25, Validation F1:0.72, Val Loss: 0.31735
# Training Acc: 72.62, Training F1:0.73, Train Loss: 0.31550
# Epoch:17
# Validation Accuracy:73.48, Validation F1:0.73, Val Loss: 0.31074
# Training Acc: 73.07, Training F1:0.73, Train Loss: 0.30941
# Epoch:18
# Validation Accuracy:73.43, Validation F1:0.73, Val Loss: 0.30735
# Training Acc: 73.36, Training F1:0.73, Train Loss: 0.30306
# Epoch:19
# Validation Accuracy:73.48, Validation F1:0.73, Val Loss: 0.30811
# Training Acc: 73.47, Training F1:0.73, Train Loss: 0.30365
# Epoch:20
# Validation Accuracy:73.56, Validation F1:0.74, Val Loss: 0.30675
# Training Acc: 74.01, Training F1:0.74, Train Loss: 0.30206
# Epoch:21
# Validation Accuracy:73.45, Validation F1:0.73, Val Loss: 0.30467
# Training Acc: 73.39, Training F1:0.73, Train Loss: 0.29747
# Epoch:22
# Validation Accuracy:72.71, Validation F1:0.73, Val Loss: 0.30782
# Training Acc: 72.93, Training F1:0.73, Train Loss: 0.30362
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:23
# Validation Accuracy:73.42, Validation F1:0.73, Val Loss: 0.30345
# Training Acc: 73.83, Training F1:0.74, Train Loss: 0.30212
# Epoch:24
# Validation Accuracy:73.86, Validation F1:0.74, Val Loss: 0.30635
# Training Acc: 74.01, Training F1:0.74, Train Loss: 0.29907
# Epoch:25
# Validation Accuracy:74.05, Validation F1:0.74, Val Loss: 0.30234
# Training Acc: 74.05, Training F1:0.74, Train Loss: 0.29606
# Epoch:26
# Validation Accuracy:74.29, Validation F1:0.74, Val Loss: 0.30136
# Training Acc: 74.51, Training F1:0.75, Train Loss: 0.29026
# Epoch:27
# Validation Accuracy:73.99, Validation F1:0.74, Val Loss: 0.30142
# Training Acc: 74.10, Training F1:0.74, Train Loss: 0.29678
# Epoch:28
# Validation Accuracy:74.23, Validation F1:0.74, Val Loss: 0.30271
# Training Acc: 74.49, Training F1:0.74, Train Loss: 0.29135
# Epoch    28: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:29
# Validation Accuracy:73.94, Validation F1:0.74, Val Loss: 0.30310
# Training Acc: 74.11, Training F1:0.74, Train Loss: 0.29201
# Epoch:30
# Validation Accuracy:74.10, Validation F1:0.74, Val Loss: 0.29886
# Training Acc: 74.33, Training F1:0.74, Train Loss: 0.29302
# Epoch:31
# Validation Accuracy:73.92, Validation F1:0.74, Val Loss: 0.30140
# Training Acc: 74.41, Training F1:0.74, Train Loss: 0.29303
# Epoch    31: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:32
# Validation Accuracy:74.04, Validation F1:0.74, Val Loss: 0.30043
# Training Acc: 74.66, Training F1:0.75, Train Loss: 0.29406
# Epoch:33
# Validation Accuracy:74.01, Validation F1:0.74, Val Loss: 0.29917
# Training Acc: 74.71, Training F1:0.75, Train Loss: 0.29584
# Epoch:34
# Validation Accuracy:73.94, Validation F1:0.74, Val Loss: 0.29856
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.29615
# Epoch    34: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:35
# Validation Accuracy:74.13, Validation F1:0.74, Val Loss: 0.30182
# Training Acc: 74.39, Training F1:0.74, Train Loss: 0.29495
# Epoch:36
# Validation Accuracy:74.12, Validation F1:0.74, Val Loss: 0.30307
# Training Acc: 74.45, Training F1:0.74, Train Loss: 0.29426
# Epoch:37
# Validation Accuracy:74.21, Validation F1:0.74, Val Loss: 0.29766
# Training Acc: 74.73, Training F1:0.75, Train Loss: 0.29304
# Epoch    37: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:38
# Validation Accuracy:74.03, Validation F1:0.74, Val Loss: 0.30390
# Training Acc: 74.60, Training F1:0.75, Train Loss: 0.29089
# Epoch:39
# Validation Accuracy:74.03, Validation F1:0.74, Val Loss: 0.29947
# Training Acc: 74.33, Training F1:0.74, Train Loss: 0.29436
# Epoch:40
# Validation Accuracy:74.18, Validation F1:0.74, Val Loss: 0.29849
# Training Acc: 74.50, Training F1:0.74, Train Loss: 0.29258
# Epoch:41
# Validation Accuracy:74.13, Validation F1:0.74, Val Loss: 0.30035
# Training Acc: 74.64, Training F1:0.75, Train Loss: 0.29443
# Epoch:42
# Validation Accuracy:74.04, Validation F1:0.74, Val Loss: 0.30344
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.29057
# Epoch:43
# Validation Accuracy:74.12, Validation F1:0.74, Val Loss: 0.29969
# Training Acc: 74.53, Training F1:0.75, Train Loss: 0.29531
# Epoch:44
# Validation Accuracy:74.16, Validation F1:0.74, Val Loss: 0.29640
# Training Acc: 74.73, Training F1:0.75, Train Loss: 0.29179
# Epoch:45
# Validation Accuracy:74.21, Validation F1:0.74, Val Loss: 0.29861
# Training Acc: 74.67, Training F1:0.75, Train Loss: 0.29305
# Epoch:46
# Validation Accuracy:74.05, Validation F1:0.74, Val Loss: 0.30202
# Training Acc: 74.69, Training F1:0.75, Train Loss: 0.29263
# Epoch:47
# Validation Accuracy:74.13, Validation F1:0.74, Val Loss: 0.30090
# Training Acc: 74.51, Training F1:0.75, Train Loss: 0.29043
# Epoch:48
# Validation Accuracy:74.11, Validation F1:0.74, Val Loss: 0.30110
# Training Acc: 74.62, Training F1:0.75, Train Loss: 0.29600
# Epoch:49
# Validation Accuracy:74.01, Validation F1:0.74, Val Loss: 0.29912
# Training Acc: 74.63, Training F1:0.75, Train Loss: 0.29517
# Epoch:50
# Validation Accuracy:74.09, Validation F1:0.74, Val Loss: 0.29897
# Training Acc: 74.54, Training F1:0.75, Train Loss: 0.29149
# Epoch:1
# Validation Accuracy:66.57, Validation F1:0.67, Val Loss: 0.36164
# Training Acc: 66.17, Training F1:0.66, Train Loss: 0.36586
# Epoch:2
# Validation Accuracy:69.30, Validation F1:0.69, Val Loss: 0.34243
# Training Acc: 69.11, Training F1:0.69, Train Loss: 0.34511
# Epoch:3
# Validation Accuracy:69.56, Validation F1:0.70, Val Loss: 0.34422
# Training Acc: 69.05, Training F1:0.69, Train Loss: 0.34569
# Epoch:4
# Validation Accuracy:69.54, Validation F1:0.70, Val Loss: 0.34029
# Training Acc: 69.55, Training F1:0.70, Train Loss: 0.33913
# Epoch:5
# Validation Accuracy:70.94, Validation F1:0.71, Val Loss: 0.32841
# Training Acc: 70.43, Training F1:0.70, Train Loss: 0.33253
# Epoch:6
# Validation Accuracy:67.38, Validation F1:0.67, Val Loss: 0.35520
# Training Acc: 67.48, Training F1:0.67, Train Loss: 0.35728
# Epoch:7
# Validation Accuracy:65.77, Validation F1:0.66, Val Loss: 0.38776
# Training Acc: 65.48, Training F1:0.65, Train Loss: 0.38989
# Epoch:8
# Validation Accuracy:71.11, Validation F1:0.71, Val Loss: 0.33570
# Training Acc: 70.71, Training F1:0.71, Train Loss: 0.33120
# Epoch:9
# Validation Accuracy:67.95, Validation F1:0.68, Val Loss: 0.35268
# Training Acc: 68.37, Training F1:0.68, Train Loss: 0.35260
# Epoch:10
# Validation Accuracy:72.19, Validation F1:0.72, Val Loss: 0.32157
# Training Acc: 71.75, Training F1:0.72, Train Loss: 0.31775
# Epoch:11
# Validation Accuracy:70.90, Validation F1:0.71, Val Loss: 0.32735
# Training Acc: 70.61, Training F1:0.71, Train Loss: 0.32738
# Epoch:12
# Validation Accuracy:71.18, Validation F1:0.71, Val Loss: 0.32305
# Training Acc: 71.31, Training F1:0.71, Train Loss: 0.32092
# Epoch    12: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:13
# Validation Accuracy:71.53, Validation F1:0.72, Val Loss: 0.32662
# Training Acc: 71.05, Training F1:0.71, Train Loss: 0.32795
# Epoch:14
# Validation Accuracy:72.84, Validation F1:0.73, Val Loss: 0.30519
# Training Acc: 73.04, Training F1:0.73, Train Loss: 0.30052
# Epoch:15
# Validation Accuracy:73.36, Validation F1:0.73, Val Loss: 0.30760
# Training Acc: 73.25, Training F1:0.73, Train Loss: 0.30154
# Epoch:16
# Validation Accuracy:73.59, Validation F1:0.74, Val Loss: 0.30560
# Training Acc: 73.92, Training F1:0.74, Train Loss: 0.29666
# Epoch:17
# Validation Accuracy:73.66, Validation F1:0.74, Val Loss: 0.30438
# Training Acc: 74.02, Training F1:0.74, Train Loss: 0.29344
# Epoch:18
# Validation Accuracy:73.54, Validation F1:0.74, Val Loss: 0.30450
# Training Acc: 73.38, Training F1:0.73, Train Loss: 0.29588
# Epoch:19
# Validation Accuracy:73.92, Validation F1:0.74, Val Loss: 0.30275
# Training Acc: 74.09, Training F1:0.74, Train Loss: 0.29425
# Epoch:20
# Validation Accuracy:74.00, Validation F1:0.74, Val Loss: 0.30077
# Training Acc: 74.69, Training F1:0.75, Train Loss: 0.28797
# Epoch:21
# Validation Accuracy:73.86, Validation F1:0.74, Val Loss: 0.29933
# Training Acc: 74.25, Training F1:0.74, Train Loss: 0.29210
# Epoch:22
# Validation Accuracy:74.51, Validation F1:0.75, Val Loss: 0.29137
# Training Acc: 75.07, Training F1:0.75, Train Loss: 0.28640
# Epoch:23
# Validation Accuracy:74.58, Validation F1:0.75, Val Loss: 0.29558
# Training Acc: 75.26, Training F1:0.75, Train Loss: 0.28641
# Epoch:24
# Validation Accuracy:74.51, Validation F1:0.75, Val Loss: 0.29713
# Training Acc: 74.91, Training F1:0.75, Train Loss: 0.28664
# Epoch:25
# Validation Accuracy:74.50, Validation F1:0.74, Val Loss: 0.29409
# Training Acc: 75.25, Training F1:0.75, Train Loss: 0.28267
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:26
# Validation Accuracy:74.56, Validation F1:0.75, Val Loss: 0.29582
# Training Acc: 75.50, Training F1:0.76, Train Loss: 0.28066
# Epoch:27
# Validation Accuracy:75.12, Validation F1:0.75, Val Loss: 0.29057
# Training Acc: 76.31, Training F1:0.76, Train Loss: 0.27685
# Epoch:28
# Validation Accuracy:75.14, Validation F1:0.75, Val Loss: 0.28739
# Training Acc: 76.28, Training F1:0.76, Train Loss: 0.27515
# Epoch:29
# Validation Accuracy:75.24, Validation F1:0.75, Val Loss: 0.28815
# Training Acc: 76.27, Training F1:0.76, Train Loss: 0.27499
# Epoch:30
# Validation Accuracy:75.24, Validation F1:0.75, Val Loss: 0.29051
# Training Acc: 76.40, Training F1:0.76, Train Loss: 0.27268
# Epoch:31
# Validation Accuracy:75.28, Validation F1:0.75, Val Loss: 0.28983
# Training Acc: 76.44, Training F1:0.76, Train Loss: 0.27539
# Epoch:32
# Validation Accuracy:75.51, Validation F1:0.76, Val Loss: 0.28622
# Training Acc: 76.38, Training F1:0.76, Train Loss: 0.27384
# Epoch:33
# Validation Accuracy:75.29, Validation F1:0.75, Val Loss: 0.28754
# Training Acc: 76.45, Training F1:0.76, Train Loss: 0.27559
# Epoch:34
# Validation Accuracy:75.30, Validation F1:0.75, Val Loss: 0.28742
# Training Acc: 76.52, Training F1:0.77, Train Loss: 0.27420
# Epoch    34: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:35
# Validation Accuracy:75.26, Validation F1:0.75, Val Loss: 0.28732
# Training Acc: 76.41, Training F1:0.76, Train Loss: 0.27326
# Epoch:36
# Validation Accuracy:75.17, Validation F1:0.75, Val Loss: 0.28833
# Training Acc: 76.59, Training F1:0.77, Train Loss: 0.27287
# Epoch:37
# Validation Accuracy:75.27, Validation F1:0.75, Val Loss: 0.28621
# Training Acc: 76.55, Training F1:0.77, Train Loss: 0.27535
# Epoch    37: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:38
# Validation Accuracy:75.23, Validation F1:0.75, Val Loss: 0.28781
# Training Acc: 76.54, Training F1:0.77, Train Loss: 0.27146
# Epoch:39
# Validation Accuracy:75.23, Validation F1:0.75, Val Loss: 0.28735
# Training Acc: 76.58, Training F1:0.77, Train Loss: 0.27402
# Epoch:40
# Validation Accuracy:75.17, Validation F1:0.75, Val Loss: 0.28461
# Training Acc: 76.61, Training F1:0.77, Train Loss: 0.27203
# Epoch    40: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:41
# Validation Accuracy:75.32, Validation F1:0.75, Val Loss: 0.29117
# Training Acc: 76.48, Training F1:0.76, Train Loss: 0.27295
# Epoch:42
# Validation Accuracy:75.24, Validation F1:0.75, Val Loss: 0.28577
# Training Acc: 76.54, Training F1:0.77, Train Loss: 0.27261
# Epoch:43
# Validation Accuracy:75.16, Validation F1:0.75, Val Loss: 0.28858
# Training Acc: 76.54, Training F1:0.77, Train Loss: 0.27242
# Epoch    43: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:44
# Validation Accuracy:75.20, Validation F1:0.75, Val Loss: 0.28995
# Training Acc: 76.52, Training F1:0.77, Train Loss: 0.27376
# Epoch:45
# Validation Accuracy:75.15, Validation F1:0.75, Val Loss: 0.28618
# Training Acc: 76.63, Training F1:0.77, Train Loss: 0.27492
# Epoch:46
# Validation Accuracy:75.35, Validation F1:0.75, Val Loss: 0.28704
# Training Acc: 76.50, Training F1:0.77, Train Loss: 0.27261
# Epoch:47
# Validation Accuracy:75.24, Validation F1:0.75, Val Loss: 0.28365
# Training Acc: 76.61, Training F1:0.77, Train Loss: 0.27373
# Epoch:48
# Validation Accuracy:75.27, Validation F1:0.75, Val Loss: 0.28618
# Training Acc: 76.49, Training F1:0.76, Train Loss: 0.27072
# Epoch:49
# Validation Accuracy:75.28, Validation F1:0.75, Val Loss: 0.29137
# Training Acc: 76.59, Training F1:0.77, Train Loss: 0.27319
# Epoch:50
# Validation Accuracy:75.30, Validation F1:0.75, Val Loss: 0.28800
# Training Acc: 76.58, Training F1:0.77, Train Loss: 0.27228
# Epoch:1
# Validation Accuracy:68.21, Validation F1:0.68, Val Loss: 0.36048
# Training Acc: 67.50, Training F1:0.68, Train Loss: 0.36426
# Epoch:2
# Validation Accuracy:69.50, Validation F1:0.70, Val Loss: 0.34570
# Training Acc: 68.80, Training F1:0.69, Train Loss: 0.34717
# Epoch:3
# Validation Accuracy:69.79, Validation F1:0.70, Val Loss: 0.33729
# Training Acc: 69.62, Training F1:0.70, Train Loss: 0.33712
# Epoch:4
# Validation Accuracy:68.16, Validation F1:0.68, Val Loss: 0.36734
# Training Acc: 67.87, Training F1:0.68, Train Loss: 0.36543
# Epoch:5
# Validation Accuracy:70.76, Validation F1:0.71, Val Loss: 0.32937
# Training Acc: 70.11, Training F1:0.70, Train Loss: 0.33371
# Epoch:6
# Validation Accuracy:70.83, Validation F1:0.71, Val Loss: 0.32224
# Training Acc: 70.25, Training F1:0.70, Train Loss: 0.33013
# Epoch:7
# Validation Accuracy:71.73, Validation F1:0.72, Val Loss: 0.31779
# Training Acc: 71.25, Training F1:0.71, Train Loss: 0.31655
# Epoch:8
# Validation Accuracy:71.15, Validation F1:0.71, Val Loss: 0.32430
# Training Acc: 70.49, Training F1:0.70, Train Loss: 0.32228
# Epoch:9
# Validation Accuracy:70.33, Validation F1:0.70, Val Loss: 0.33081
# Training Acc: 69.94, Training F1:0.70, Train Loss: 0.33393
# Epoch:10
# Validation Accuracy:72.16, Validation F1:0.72, Val Loss: 0.32283
# Training Acc: 71.86, Training F1:0.72, Train Loss: 0.32140
# Epoch:11
# Validation Accuracy:70.64, Validation F1:0.71, Val Loss: 0.32942
# Training Acc: 70.45, Training F1:0.70, Train Loss: 0.32622
# Epoch:12
# Validation Accuracy:72.46, Validation F1:0.72, Val Loss: 0.31064
# Training Acc: 72.15, Training F1:0.72, Train Loss: 0.31211
# Epoch:13
# Validation Accuracy:70.71, Validation F1:0.71, Val Loss: 0.35511
# Training Acc: 70.42, Training F1:0.70, Train Loss: 0.35253
# Epoch:14
# Validation Accuracy:72.80, Validation F1:0.73, Val Loss: 0.31374
# Training Acc: 72.34, Training F1:0.72, Train Loss: 0.31307
# Epoch:15
# Validation Accuracy:72.41, Validation F1:0.72, Val Loss: 0.31462
# Training Acc: 72.32, Training F1:0.72, Train Loss: 0.31105
# Epoch:16
# Validation Accuracy:70.53, Validation F1:0.71, Val Loss: 0.33732
# Training Acc: 70.30, Training F1:0.70, Train Loss: 0.33904
# Epoch    16: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:17
# Validation Accuracy:72.55, Validation F1:0.73, Val Loss: 0.32563
# Training Acc: 72.26, Training F1:0.72, Train Loss: 0.32408
# Epoch:18
# Validation Accuracy:73.43, Validation F1:0.73, Val Loss: 0.29875
# Training Acc: 73.59, Training F1:0.74, Train Loss: 0.29854
# Epoch:19
# Validation Accuracy:73.33, Validation F1:0.73, Val Loss: 0.29840
# Training Acc: 74.01, Training F1:0.74, Train Loss: 0.29757
# Epoch:20
# Validation Accuracy:74.10, Validation F1:0.74, Val Loss: 0.29681
# Training Acc: 74.25, Training F1:0.74, Train Loss: 0.29711
# Epoch:21
# Validation Accuracy:74.17, Validation F1:0.74, Val Loss: 0.29961
# Training Acc: 74.23, Training F1:0.74, Train Loss: 0.29643
# Epoch:22
# Validation Accuracy:74.19, Validation F1:0.74, Val Loss: 0.29812
# Training Acc: 74.19, Training F1:0.74, Train Loss: 0.29401
# Epoch:23
# Validation Accuracy:74.34, Validation F1:0.74, Val Loss: 0.29818
# Training Acc: 74.26, Training F1:0.74, Train Loss: 0.29611
# Epoch:24
# Validation Accuracy:74.35, Validation F1:0.74, Val Loss: 0.29568
# Training Acc: 74.64, Training F1:0.75, Train Loss: 0.29594
# Epoch:25
# Validation Accuracy:74.19, Validation F1:0.74, Val Loss: 0.29947
# Training Acc: 74.56, Training F1:0.75, Train Loss: 0.29819
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:26
# Validation Accuracy:74.22, Validation F1:0.74, Val Loss: 0.29706
# Training Acc: 74.52, Training F1:0.75, Train Loss: 0.29291
# Epoch:27
# Validation Accuracy:74.51, Validation F1:0.75, Val Loss: 0.29263
# Training Acc: 74.93, Training F1:0.75, Train Loss: 0.28928
# Epoch:28
# Validation Accuracy:74.70, Validation F1:0.75, Val Loss: 0.29375
# Training Acc: 75.09, Training F1:0.75, Train Loss: 0.28942
# Epoch:29
# Validation Accuracy:74.63, Validation F1:0.75, Val Loss: 0.29245
# Training Acc: 75.07, Training F1:0.75, Train Loss: 0.28827
# Epoch:30
# Validation Accuracy:74.70, Validation F1:0.75, Val Loss: 0.28767
# Training Acc: 75.19, Training F1:0.75, Train Loss: 0.28731
# Epoch:31
# Validation Accuracy:74.76, Validation F1:0.75, Val Loss: 0.28893
# Training Acc: 75.32, Training F1:0.75, Train Loss: 0.28924
# Epoch:32
# Validation Accuracy:74.73, Validation F1:0.75, Val Loss: 0.29313
# Training Acc: 75.31, Training F1:0.75, Train Loss: 0.28856
# Epoch:33
# Validation Accuracy:74.76, Validation F1:0.75, Val Loss: 0.29100
# Training Acc: 75.43, Training F1:0.75, Train Loss: 0.28689
# Epoch    33: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:34
# Validation Accuracy:74.73, Validation F1:0.75, Val Loss: 0.28785
# Training Acc: 75.40, Training F1:0.75, Train Loss: 0.28616
# Epoch:35
# Validation Accuracy:74.59, Validation F1:0.75, Val Loss: 0.29107
# Training Acc: 75.42, Training F1:0.75, Train Loss: 0.28767
# Epoch:36
# Validation Accuracy:74.59, Validation F1:0.75, Val Loss: 0.28704
# Training Acc: 75.27, Training F1:0.75, Train Loss: 0.28622
# Epoch    36: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:37
# Validation Accuracy:74.60, Validation F1:0.75, Val Loss: 0.29065
# Training Acc: 75.39, Training F1:0.75, Train Loss: 0.28655
# Epoch:38
# Validation Accuracy:74.73, Validation F1:0.75, Val Loss: 0.28729
# Training Acc: 75.44, Training F1:0.75, Train Loss: 0.28627
# Epoch:39
# Validation Accuracy:74.56, Validation F1:0.75, Val Loss: 0.29109
# Training Acc: 75.30, Training F1:0.75, Train Loss: 0.28713
# Epoch    39: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:40
# Validation Accuracy:74.71, Validation F1:0.75, Val Loss: 0.29474
# Training Acc: 75.55, Training F1:0.76, Train Loss: 0.28711
# Epoch:41
# Validation Accuracy:74.62, Validation F1:0.75, Val Loss: 0.29148
# Training Acc: 75.42, Training F1:0.75, Train Loss: 0.28762
# Epoch:42
# Validation Accuracy:74.54, Validation F1:0.75, Val Loss: 0.28835
# Training Acc: 75.48, Training F1:0.75, Train Loss: 0.28545
# Epoch    42: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:43
# Validation Accuracy:74.65, Validation F1:0.75, Val Loss: 0.28990
# Training Acc: 75.52, Training F1:0.76, Train Loss: 0.28721
# Epoch:44
# Validation Accuracy:74.60, Validation F1:0.75, Val Loss: 0.29217
# Training Acc: 75.34, Training F1:0.75, Train Loss: 0.28763
# Epoch:45
# Validation Accuracy:74.57, Validation F1:0.75, Val Loss: 0.28748
# Training Acc: 75.44, Training F1:0.75, Train Loss: 0.28611
# Epoch:46
# Validation Accuracy:74.79, Validation F1:0.75, Val Loss: 0.29173
# Training Acc: 75.41, Training F1:0.75, Train Loss: 0.28726
# Epoch:47
# Validation Accuracy:74.76, Validation F1:0.75, Val Loss: 0.29016
# Training Acc: 75.46, Training F1:0.75, Train Loss: 0.28754
# Epoch:48
# Validation Accuracy:74.74, Validation F1:0.75, Val Loss: 0.28781
# Training Acc: 75.53, Training F1:0.76, Train Loss: 0.28644
# Epoch:49
# Validation Accuracy:74.74, Validation F1:0.75, Val Loss: 0.29091
# Training Acc: 75.39, Training F1:0.75, Train Loss: 0.28800
# Epoch:50
# Validation Accuracy:74.64, Validation F1:0.75, Val Loss: 0.29141
# Training Acc: 75.50, Training F1:0.75, Train Loss: 0.28775
# Epoch:1
# Validation Accuracy:59.46, Validation F1:0.59, Val Loss: 0.65325
# Training Acc: 60.11, Training F1:0.60, Train Loss: 0.64189
# Epoch:2
# Validation Accuracy:69.88, Validation F1:0.70, Val Loss: 0.34162
# Training Acc: 69.68, Training F1:0.70, Train Loss: 0.33819
# Epoch:3
# Validation Accuracy:69.61, Validation F1:0.70, Val Loss: 0.33669
# Training Acc: 69.25, Training F1:0.69, Train Loss: 0.33816
# Epoch:4
# Validation Accuracy:67.57, Validation F1:0.68, Val Loss: 0.36610
# Training Acc: 67.61, Training F1:0.68, Train Loss: 0.36749
# Epoch:5
# Validation Accuracy:71.21, Validation F1:0.71, Val Loss: 0.32108
# Training Acc: 71.10, Training F1:0.71, Train Loss: 0.32086
# Epoch:6
# Validation Accuracy:70.45, Validation F1:0.70, Val Loss: 0.32858
# Training Acc: 70.48, Training F1:0.70, Train Loss: 0.32721
# Epoch:7
# Validation Accuracy:71.08, Validation F1:0.71, Val Loss: 0.33123
# Training Acc: 70.64, Training F1:0.71, Train Loss: 0.32845
# Epoch:8
# Validation Accuracy:71.26, Validation F1:0.71, Val Loss: 0.32150
# Training Acc: 71.52, Training F1:0.72, Train Loss: 0.32250
# Epoch:9
# Validation Accuracy:72.51, Validation F1:0.73, Val Loss: 0.31112
# Training Acc: 72.27, Training F1:0.72, Train Loss: 0.31194
# Epoch:10
# Validation Accuracy:72.30, Validation F1:0.72, Val Loss: 0.31479
# Training Acc: 72.13, Training F1:0.72, Train Loss: 0.31126
# Epoch:11
# Validation Accuracy:71.76, Validation F1:0.72, Val Loss: 0.31673
# Training Acc: 71.94, Training F1:0.72, Train Loss: 0.31569
# Epoch    11: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:12
# Validation Accuracy:70.67, Validation F1:0.71, Val Loss: 0.33383
# Training Acc: 70.22, Training F1:0.70, Train Loss: 0.33714
# Epoch:13
# Validation Accuracy:73.54, Validation F1:0.74, Val Loss: 0.30651
# Training Acc: 73.15, Training F1:0.73, Train Loss: 0.30377
# Epoch:14
# Validation Accuracy:73.53, Validation F1:0.74, Val Loss: 0.30649
# Training Acc: 73.33, Training F1:0.73, Train Loss: 0.29858
# Epoch:15
# Validation Accuracy:73.70, Validation F1:0.74, Val Loss: 0.30405
# Training Acc: 73.37, Training F1:0.73, Train Loss: 0.29985
# Epoch:16
# Validation Accuracy:73.60, Validation F1:0.74, Val Loss: 0.30246
# Training Acc: 73.53, Training F1:0.74, Train Loss: 0.29997
# Epoch:17
# Validation Accuracy:73.71, Validation F1:0.74, Val Loss: 0.30487
# Training Acc: 73.49, Training F1:0.73, Train Loss: 0.29832
# Epoch    17: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:18
# Validation Accuracy:73.39, Validation F1:0.73, Val Loss: 0.30305
# Training Acc: 73.48, Training F1:0.73, Train Loss: 0.29867
# Epoch:19
# Validation Accuracy:73.86, Validation F1:0.74, Val Loss: 0.30171
# Training Acc: 73.57, Training F1:0.74, Train Loss: 0.29780
# Epoch:20
# Validation Accuracy:73.77, Validation F1:0.74, Val Loss: 0.30015
# Training Acc: 73.60, Training F1:0.74, Train Loss: 0.29765
# Epoch:21
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.29947
# Training Acc: 73.65, Training F1:0.74, Train Loss: 0.29834
# Epoch    21: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:22
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.30282
# Training Acc: 73.70, Training F1:0.74, Train Loss: 0.29894
# Epoch:23
# Validation Accuracy:73.69, Validation F1:0.74, Val Loss: 0.30369
# Training Acc: 73.72, Training F1:0.74, Train Loss: 0.29766
# Epoch:24
# Validation Accuracy:73.68, Validation F1:0.74, Val Loss: 0.30137
# Training Acc: 73.64, Training F1:0.74, Train Loss: 0.29646
# Epoch    24: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:25
# Validation Accuracy:73.78, Validation F1:0.74, Val Loss: 0.30278
# Training Acc: 73.64, Training F1:0.74, Train Loss: 0.29734
# Epoch:26
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.29970
# Training Acc: 73.62, Training F1:0.74, Train Loss: 0.29557
# Epoch:27
# Validation Accuracy:73.77, Validation F1:0.74, Val Loss: 0.30355
# Training Acc: 73.73, Training F1:0.74, Train Loss: 0.29826
# Epoch    27: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:28
# Validation Accuracy:73.80, Validation F1:0.74, Val Loss: 0.30147
# Training Acc: 73.73, Training F1:0.74, Train Loss: 0.29688
# Epoch:29
# Validation Accuracy:73.68, Validation F1:0.74, Val Loss: 0.30091
# Training Acc: 73.65, Training F1:0.74, Train Loss: 0.29958
# Epoch:30
# Validation Accuracy:73.70, Validation F1:0.74, Val Loss: 0.30060
# Training Acc: 73.74, Training F1:0.74, Train Loss: 0.29653
# Epoch    30: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:31
# Validation Accuracy:73.62, Validation F1:0.74, Val Loss: 0.30476
# Training Acc: 73.71, Training F1:0.74, Train Loss: 0.29674
# Epoch:32
# Validation Accuracy:73.75, Validation F1:0.74, Val Loss: 0.30432
# Training Acc: 73.66, Training F1:0.74, Train Loss: 0.29895
# Epoch:33
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.30239
# Training Acc: 73.71, Training F1:0.74, Train Loss: 0.29610
# Epoch:34
# Validation Accuracy:73.75, Validation F1:0.74, Val Loss: 0.30097
# Training Acc: 73.63, Training F1:0.74, Train Loss: 0.29997
# Epoch:35
# Validation Accuracy:73.81, Validation F1:0.74, Val Loss: 0.29948
# Training Acc: 73.70, Training F1:0.74, Train Loss: 0.29786
# Epoch:36
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.30117
# Training Acc: 73.68, Training F1:0.74, Train Loss: 0.29719
# Epoch:37
# Validation Accuracy:73.64, Validation F1:0.74, Val Loss: 0.30461
# Training Acc: 73.68, Training F1:0.74, Train Loss: 0.29809
# Epoch:38
# Validation Accuracy:73.66, Validation F1:0.74, Val Loss: 0.30286
# Training Acc: 73.68, Training F1:0.74, Train Loss: 0.29960
# Epoch:39
# Validation Accuracy:73.65, Validation F1:0.74, Val Loss: 0.30264
# Training Acc: 73.67, Training F1:0.74, Train Loss: 0.29853
# Epoch:40
# Validation Accuracy:73.65, Validation F1:0.74, Val Loss: 0.30261
# Training Acc: 73.68, Training F1:0.74, Train Loss: 0.29507
# Epoch:41
# Validation Accuracy:73.82, Validation F1:0.74, Val Loss: 0.30580
# Training Acc: 73.73, Training F1:0.74, Train Loss: 0.29937
# Epoch:42
# Validation Accuracy:73.71, Validation F1:0.74, Val Loss: 0.30274
# Training Acc: 73.74, Training F1:0.74, Train Loss: 0.29745
# Epoch:43
# Validation Accuracy:73.68, Validation F1:0.74, Val Loss: 0.30200
# Training Acc: 73.66, Training F1:0.74, Train Loss: 0.29891
# Epoch:44
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.30335
# Training Acc: 73.70, Training F1:0.74, Train Loss: 0.29871
# Epoch:45
# Validation Accuracy:73.66, Validation F1:0.74, Val Loss: 0.30196
# Training Acc: 73.65, Training F1:0.74, Train Loss: 0.29841
# Epoch:46
# Validation Accuracy:73.64, Validation F1:0.74, Val Loss: 0.30247
# Training Acc: 73.68, Training F1:0.74, Train Loss: 0.29578
# Epoch:47
# Validation Accuracy:73.80, Validation F1:0.74, Val Loss: 0.30626
# Training Acc: 73.79, Training F1:0.74, Train Loss: 0.29847
# Epoch:48
# Validation Accuracy:73.72, Validation F1:0.74, Val Loss: 0.30340
# Training Acc: 73.69, Training F1:0.74, Train Loss: 0.29903
# Epoch:49
# Validation Accuracy:73.66, Validation F1:0.74, Val Loss: 0.30194
# Training Acc: 73.71, Training F1:0.74, Train Loss: 0.29807
# Epoch:50
# Validation Accuracy:73.72, Validation F1:0.74, Val Loss: 0.30410
# Training Acc: 73.75, Training F1:0.74, Train Loss: 0.29779

# %%
results_dict = {}
model1 = snet2_jigsaw(20).to(device)
model = snet2_jigsaw(20).to(device)

for i in range(len(sizes)):
    if sizes[i] != 1500:
        idx_train_new = Model_Data[i]
        Y_mask_train = Y_mask[idx_train_new]
        label_train = Y_true[idx_train_new]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train_new], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)
    else:
        Y_mask_train = Y_mask[idx_train]
        label_train = Y_true[idx_train]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)

    
    model.load_state_dict(model1.state_dict())
    learning_rate = 10**(-5)
    num_epochs = 50 # number epoch to train

    optimizer = torch.optim.Adam([param for param in model.parameters() if param.requires_grad == True], lr=learning_rate, weight_decay = 0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=2, verbose=True, threshold=0.03,
                                                           threshold_mode='abs', cooldown=0, min_lr=0, eps=1e-08)

    train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict = train_model(Train_loader, Val_loader, model, optimizer, scheduler, num_epochs)
    results_dict[sizes[i]] = {
        'train_acc_list':train_acc_list,
        'train_loss_list': train_loss_list,
        'val_acc_list': val_acc_list,
        'val_loss_list': val_loss_list,
        'best_model_state_dict': best_model_state_dict
    }
pickle.dump(results_dict, open('Size_Exp_Random_Wt_NoLinear_Results_size_{}.pkl'.format(sizes[i]),'wb'))

# %%
mean = 0.
std = 0.
for images, _, _ in Train_loader:
    batch_samples = images.size(0) # batch size (the last batch can have smaller size!)
    images1 = images.reshape(batch_samples, images.size(1), -1)
    mean += images1.mean(2).sum(0)
    std += images1.std(2).sum(0)
    
mean /= len(Train_loader.dataset)
std /= len(Train_loader.dataset)

# %%
print(mean, std)
# Out:
# tensor([-24.3633]) tensor([14.2659])

# %%
model = conv_net().to(device)
model.load_state_dict(reqd_weights)
# Out:
# <All keys matched successfully>

# %%
pickle.dump(results_dict, open('Size_Exp_Jigsaw_Wt_Results.pkl'.format(sizes[i]),'wb'))

# %%
results_dict.keys()
# Out:
# dict_keys([10, 50, 250, 500])

# %%
import torchvision.models as models
resnet18 = models.resnet18().to(device)
alexnet = models.alexnet().to(device)
vgg16 = models.vgg16().to(device)
squeezenet = models.squeezenet1_0().to(device)
densenet = models.densenet161().to(device)
inception = models.inception_v3().to(device)

# %%
import numpy as np
a = np.array([1,2])
a[:1]
# Out:
# array([1])
