# %%
# -*- coding: utf-8 -*-

from matplotlib import pyplot as plt
import numpy as np
import random
from torch.utils.data import Dataset, DataLoader
import torch
import os
from torch.optim import *
from torch import nn
from torch.nn import functional as F
from scipy import ndimage
import pandas as pd
from copy import deepcopy
import random
from sklearn.metrics import f1_score

random.seed(7)
torch.cuda.manual_seed(7)
torch.manual_seed(7)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(7)

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
DATA_ROOT = '/beegfs/bva212/openmic-2018'
OPENMIC = np.load(os.path.join(DATA_ROOT, 'openmic-2018.npz'))
X, Y_true, Y_mask, sample_key = OPENMIC['X'], OPENMIC['Y_true'], OPENMIC['Y_mask'], OPENMIC['sample_key']

# %%
train_samples = pd.read_csv(os.path.join(DATA_ROOT,'partitions/split01_train.csv'), names =['id']).to_numpy().squeeze()
test_samples = pd.read_csv(os.path.join(DATA_ROOT,'partitions/split01_test.csv'), names =['id']).to_numpy().squeeze()

# %%
len_data = len(train_samples)
idx_train = np.random.choice(len_data, int(len_data*0.8), replace=False)
remain_set = list(set(np.arange(len_data))-set(idx_train))

# %%
val_idx = np.isin(sample_key, train_samples[remain_set])
train_idx = np.isin(sample_key, train_samples[idx_train])
test_idx = np.isin(sample_key, test_samples)

# %%
class ArrowOfTime(Dataset):

    def __init__(self, root_dir, files, weights, label):
        self.weights = weights
        self.device = device
        self.root_dir = root_dir
        self.files = files
        self.label = label

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        logscalogram = (np.load(self.root_dir + self.files[idx]+'_cqt.npy') - -24.3633)/14.2659
        weight = self.weights[idx]
        label = (self.label[idx] > 0.5).astype(int)
        return {'logscalogram': logscalogram[np.newaxis, :], 'label': label[np.newaxis, :], 'weight': weight[np.newaxis, :]}

filenames = []
root_dir = '/beegfs/bva212/openmic-2018/cqt_full/'

BATCH_SIZE = 32

def my_collate(batch):
    data = np.stack([item['logscalogram'] for item in batch])
    target = np.concatenate([item['label'] for item in batch],axis=0)
    weight = np.concatenate([item['weight'] for item in batch],axis=0)
    weight_sum = weight.sum(0)
    weight_sum = np.repeat(weight_sum[np.newaxis, :], len(batch), 0)
    weight_sum[weight_sum==0]=1
    weight = weight/weight_sum
    return [torch.from_numpy(data).float(), torch.from_numpy(target).float(), torch.from_numpy(weight).float()]

# %%
class snet2_jigsaw(nn.Module):

    def __init__(self, output_classes = 20):
        '''
        Create the 5 Conv Layer Sound Net network architecture as per the paper - https://arxiv.org/pdf/1610.09001.pdf
        '''
        super(snet2_jigsaw, self).__init__()

        self.conv_layers = nn.Sequential(nn.Conv2d(in_channels = 1, out_channels= 16, kernel_size = 5, stride = 2, padding = 5), 
                                nn.BatchNorm2d(num_features = 16), 
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = 5, stride = 2, padding = 5),
                                nn.BatchNorm2d(32),
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = 5, padding = 5),
                                nn.BatchNorm2d(64),
                                nn.ReLU(inplace = True),
                                nn.AvgPool2d(kernel_size = 3),

                                nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 4, padding = 4),
                                nn.BatchNorm2d(128),
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = 4, padding = 4),
                                nn.BatchNorm2d(256),
                                nn.ReLU(inplace = True),
                                nn.AvgPool2d(kernel_size = 3),

                                nn.Conv2d(in_channels = 256, out_channels = 512, kernel_size = 3, stride = 2, padding = 3),
                                nn.BatchNorm2d(512),
                                nn.ReLU(inplace = True),

                                nn.Conv2d(in_channels = 512, out_channels = 1024, kernel_size = 3, stride = 2, padding = 3),
                                nn.BatchNorm2d(1024),
                                nn.ReLU(inplace = True),
                                nn.AdaptiveAvgPool2d(output_size = 1)
                                )
        self.mlp_layer = nn.Linear(1024, output_classes)
              
    def forward(self, input):
        out = self.conv_layers(input)
        out = self.mlp_layer(out.view(out.shape[0], -1))
        return out
    
    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, a=0, mode='fan_in', nonlinearity='relu')
        
# Function for testing the model
def test_model(loader, model):
    correct = 0
    total_loss = 0
    total = 0
    total_num = 0
    actual_arr = []
    predicted_arr = []
    weight_array = []
    model.eval()
    with torch.no_grad():
        for spectrogram, target, weight in loader:
            spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
            outputs = model(spectrogram_batch)
            loss = F.binary_cross_entropy_with_logits(outputs, target_batch,
                                                  weight = weight_batch,
                                                  reduction='sum')
            predicted = (torch.sigmoid(outputs.data)>0.5).float()
            
            actual_arr.extend(target.view(1,-1).squeeze().numpy().astype(int).tolist())
            predicted_arr.extend(predicted.view(1,-1).squeeze().cpu().numpy().astype(int).tolist())
            
            total_loss += loss.item()
            total += weight_batch.shape[0]
            
            correct += ((weight_batch != 0).float()*(predicted.eq(target_batch.view_as(predicted)).float())).sum().item()
            total_num += (weight_batch != 0).sum().item()
            weight_array = np.concatenate((weight_array,(weight != 0).reshape(-1).numpy().astype(int)))
        accuracy = (100 * correct / total_num)
        return accuracy, f1_score(actual_arr, predicted_arr, average='micro', sample_weight = weight_array), total_loss/total

def train_model(train_loader, val_loader, model, optimizer, scheduler, num_epochs):
    train_acc_list = []
    train_loss_list = []
    val_acc_list = []
    val_loss_list = []
    train_f1_list = []
    val_f1_list = []
    best_val_acc = 0
    for epoch in range(num_epochs):
        for spectrogram, target, weight in train_loader:
            model.train()
            spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
            optimizer.zero_grad()
            outputs = model(spectrogram_batch)
            loss = F.binary_cross_entropy_with_logits(outputs, target_batch,
                                                  weight = weight_batch,
                                                  reduction='sum')
            loss.backward()
            optimizer.step()
        train_acc, f1_score_train, train_loss = test_model(train_loader, model)
        val_acc, f1_score_val, val_loss = test_model(val_loader, model)
        
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state_dict = deepcopy(model.state_dict())
        
        train_acc_list.append(train_acc)
        train_f1_list.append(f1_score_train)
        train_loss_list.append(train_loss)
        val_f1_list.append(f1_score_val)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)
        
        scheduler.step(val_acc)
        print("Epoch:{}".format(epoch+1))
        print("Validation Accuracy:{:.2f}, Validation F1:{:.2f}, Val Loss: {:.5f}".format(val_acc, f1_score_val, val_loss))
        print("Training Acc: {:.2f}, Training F1:{:.2f}, Train Loss: {:.5f}".format(train_acc, f1_score_train, train_loss))
    return train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict

# %%
import pickle
sizes = [10, 50, 250, 500, 950, 'Full']

Model_Data = pickle.load(open('Training_Data_Index.pkl', 'rb'))

Val_dataset = ArrowOfTime(root_dir, sample_key[val_idx], Y_mask[val_idx], Y_true[val_idx])
Val_loader = torch.utils.data.DataLoader(dataset = Val_dataset, 
                                              batch_size = BATCH_SIZE,
                                              shuffle = False,
                                        collate_fn = my_collate)

results_dict = {}

for i in range(len(sizes)):
    if sizes[i] != 'Full':
        sample_key_train = Model_Data[i]
        idx_train_new = np.isin(sample_key, sample_key_train)
        Y_mask_train = Y_mask[idx_train_new]
        label_train = Y_true[idx_train_new]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train_new], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)
    else:
        Y_mask_train = Y_mask[train_idx]
        label_train = Y_true[train_idx]
        Train_dataset = ArrowOfTime(root_dir, sample_key[train_idx], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)

    
    weights = torch.load('/beegfs/sc6957/capstone/models/20191106/snet2_jigsaw_large_best_model.pth')['modelStateDict']
    model = snet2_jigsaw(20)
    reqd_weights = {key:value for key, value in weights.items() if key in model.state_dict() and key[:9] != 'mlp_layer'}
    reqd_weights["mlp_layer.weight"] = model.mlp_layer.weight
    reqd_weights["mlp_layer.bias"] = model.mlp_layer.bias
    model.load_state_dict(reqd_weights)
    model.to(device)
    learning_rate = 10**(-2)
    num_epochs = 50 # number epoch to train

    optimizer = torch.optim.Adam([param for param in model.parameters() if param.requires_grad == True], lr=learning_rate, weight_decay = 0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=2, verbose=True, threshold=0.03,
                                                           threshold_mode='abs', cooldown=0, min_lr=0, eps=1e-08)

    train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict = train_model(Train_loader, Val_loader, model, optimizer, scheduler, num_epochs)
    results_dict[sizes[i]] = {
        'train_acc_list':train_acc_list,
        'train_loss_list': train_loss_list,
        'val_acc_list': val_acc_list,
        'val_loss_list': val_loss_list,
        'best_model_state_dict': best_model_state_dict
    }
pickle.dump(results_dict, open('/scratch/rc3620/Capstone/Size_Exp_Jigsaw_Wt_NoLin_Results.pkl','wb'))
# Out:
# Epoch:1
# Validation Accuracy:59.09, Validation F1:0.59, Val Loss: 54.79447
# Training Acc: 62.69, Training F1:0.63, Train Loss: 56.73961
# Epoch:2
# Validation Accuracy:59.49, Validation F1:0.59, Val Loss: 0.39648
# Training Acc: 62.88, Training F1:0.63, Train Loss: 0.41709
# Epoch:3
# Validation Accuracy:62.59, Validation F1:0.63, Val Loss: 0.39235
# Training Acc: 64.39, Training F1:0.64, Train Loss: 0.43675
# Epoch:4
# Validation Accuracy:62.56, Validation F1:0.63, Val Loss: 0.39250
# Training Acc: 64.02, Training F1:0.64, Train Loss: 0.42514
# Epoch:5
# Validation Accuracy:62.57, Validation F1:0.63, Val Loss: 0.39557
# Training Acc: 64.02, Training F1:0.64, Train Loss: 0.43106
# Epoch:6
# Validation Accuracy:62.70, Validation F1:0.63, Val Loss: 0.40151
# Training Acc: 64.39, Training F1:0.64, Train Loss: 0.42060
# Epoch:7
# Validation Accuracy:63.51, Validation F1:0.64, Val Loss: 0.39813
# Training Acc: 69.32, Training F1:0.69, Train Loss: 0.38798
# Epoch:8
# Validation Accuracy:63.04, Validation F1:0.63, Val Loss: 0.39932
# Training Acc: 66.86, Training F1:0.67, Train Loss: 0.38418
# Epoch:9
# Validation Accuracy:62.25, Validation F1:0.62, Val Loss: 0.50941
# Training Acc: 64.96, Training F1:0.65, Train Loss: 0.47629
# Epoch     9: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:10
# Validation Accuracy:63.27, Validation F1:0.63, Val Loss: 0.41931
# Training Acc: 68.56, Training F1:0.69, Train Loss: 0.38571
# Epoch:11
# Validation Accuracy:63.54, Validation F1:0.64, Val Loss: 0.39627
# Training Acc: 70.08, Training F1:0.70, Train Loss: 0.36700
# Epoch:12
# Validation Accuracy:63.98, Validation F1:0.64, Val Loss: 0.38857
# Training Acc: 70.64, Training F1:0.71, Train Loss: 0.36564
# Epoch:13
# Validation Accuracy:64.09, Validation F1:0.64, Val Loss: 0.38417
# Training Acc: 72.16, Training F1:0.72, Train Loss: 0.36479
# Epoch:14
# Validation Accuracy:64.72, Validation F1:0.65, Val Loss: 0.38171
# Training Acc: 72.16, Training F1:0.72, Train Loss: 0.35479
# Epoch:15
# Validation Accuracy:65.01, Validation F1:0.65, Val Loss: 0.38215
# Training Acc: 72.73, Training F1:0.73, Train Loss: 0.36766
# Epoch:16
# Validation Accuracy:65.08, Validation F1:0.65, Val Loss: 0.38465
# Training Acc: 72.35, Training F1:0.72, Train Loss: 0.36042
# Epoch:17
# Validation Accuracy:64.96, Validation F1:0.65, Val Loss: 0.38048
# Training Acc: 71.97, Training F1:0.72, Train Loss: 0.35545
# Epoch:18
# Validation Accuracy:65.43, Validation F1:0.65, Val Loss: 0.38305
# Training Acc: 73.48, Training F1:0.73, Train Loss: 0.34888
# Epoch:19
# Validation Accuracy:65.41, Validation F1:0.65, Val Loss: 0.38107
# Training Acc: 73.30, Training F1:0.73, Train Loss: 0.34506
# Epoch:20
# Validation Accuracy:64.87, Validation F1:0.65, Val Loss: 0.41762
# Training Acc: 72.16, Training F1:0.72, Train Loss: 0.34991
# Epoch:21
# Validation Accuracy:65.53, Validation F1:0.66, Val Loss: 0.40834
# Training Acc: 75.19, Training F1:0.75, Train Loss: 0.32323
# Epoch:22
# Validation Accuracy:64.74, Validation F1:0.65, Val Loss: 0.39765
# Training Acc: 73.67, Training F1:0.74, Train Loss: 0.31693
# Epoch:23
# Validation Accuracy:65.11, Validation F1:0.65, Val Loss: 0.37867
# Training Acc: 73.86, Training F1:0.74, Train Loss: 0.36025
# Epoch:24
# Validation Accuracy:65.66, Validation F1:0.66, Val Loss: 0.38062
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.32585
# Epoch:25
# Validation Accuracy:65.69, Validation F1:0.66, Val Loss: 0.36619
# Training Acc: 73.67, Training F1:0.74, Train Loss: 0.32949
# Epoch:26
# Validation Accuracy:65.04, Validation F1:0.65, Val Loss: 0.37326
# Training Acc: 73.48, Training F1:0.73, Train Loss: 0.34100
# Epoch:27
# Validation Accuracy:66.20, Validation F1:0.66, Val Loss: 0.41684
# Training Acc: 75.38, Training F1:0.75, Train Loss: 0.28929
# Epoch:28
# Validation Accuracy:66.22, Validation F1:0.66, Val Loss: 0.40000
# Training Acc: 78.22, Training F1:0.78, Train Loss: 0.29883
# Epoch:29
# Validation Accuracy:67.04, Validation F1:0.67, Val Loss: 0.40746
# Training Acc: 79.55, Training F1:0.80, Train Loss: 0.28256
# Epoch:30
# Validation Accuracy:66.20, Validation F1:0.66, Val Loss: 0.41412
# Training Acc: 78.22, Training F1:0.78, Train Loss: 0.29810
# Epoch:31
# Validation Accuracy:66.33, Validation F1:0.66, Val Loss: 0.36669
# Training Acc: 77.27, Training F1:0.77, Train Loss: 0.31939
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:32
# Validation Accuracy:66.24, Validation F1:0.66, Val Loss: 0.41039
# Training Acc: 79.92, Training F1:0.80, Train Loss: 0.27022
# Epoch:33
# Validation Accuracy:66.61, Validation F1:0.67, Val Loss: 0.39457
# Training Acc: 80.49, Training F1:0.80, Train Loss: 0.25771
# Epoch:34
# Validation Accuracy:66.25, Validation F1:0.66, Val Loss: 0.40536
# Training Acc: 80.30, Training F1:0.80, Train Loss: 0.24455
# Epoch    34: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:35
# Validation Accuracy:66.43, Validation F1:0.66, Val Loss: 0.40977
# Training Acc: 80.11, Training F1:0.80, Train Loss: 0.26126
# Epoch:36
# Validation Accuracy:66.25, Validation F1:0.66, Val Loss: 0.40906
# Training Acc: 80.49, Training F1:0.80, Train Loss: 0.26135
# Epoch:37
# Validation Accuracy:66.27, Validation F1:0.66, Val Loss: 0.41379
# Training Acc: 80.11, Training F1:0.80, Train Loss: 0.24549
# Epoch    37: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:38
# Validation Accuracy:66.46, Validation F1:0.66, Val Loss: 0.40293
# Training Acc: 81.63, Training F1:0.82, Train Loss: 0.24800
# Epoch:39
# Validation Accuracy:66.56, Validation F1:0.67, Val Loss: 0.40909
# Training Acc: 81.25, Training F1:0.81, Train Loss: 0.25922
# Epoch:40
# Validation Accuracy:66.61, Validation F1:0.67, Val Loss: 0.40250
# Training Acc: 81.44, Training F1:0.81, Train Loss: 0.25974
# Epoch    40: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:41
# Validation Accuracy:66.69, Validation F1:0.67, Val Loss: 0.39988
# Training Acc: 81.63, Training F1:0.82, Train Loss: 0.25140
# Epoch:42
# Validation Accuracy:66.48, Validation F1:0.66, Val Loss: 0.40939
# Training Acc: 81.06, Training F1:0.81, Train Loss: 0.25717
# Epoch:43
# Validation Accuracy:66.49, Validation F1:0.66, Val Loss: 0.41218
# Training Acc: 80.49, Training F1:0.80, Train Loss: 0.24281
# Epoch    43: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:44
# Validation Accuracy:66.61, Validation F1:0.67, Val Loss: 0.40744
# Training Acc: 81.44, Training F1:0.81, Train Loss: 0.24670
# Epoch:45
# Validation Accuracy:66.45, Validation F1:0.66, Val Loss: 0.40685
# Training Acc: 81.06, Training F1:0.81, Train Loss: 0.26621
# Epoch:46
# Validation Accuracy:66.38, Validation F1:0.66, Val Loss: 0.40817
# Training Acc: 81.06, Training F1:0.81, Train Loss: 0.23985
# Epoch:47
# Validation Accuracy:66.45, Validation F1:0.66, Val Loss: 0.40533
# Training Acc: 81.63, Training F1:0.82, Train Loss: 0.26135
# Epoch:48
# Validation Accuracy:66.66, Validation F1:0.67, Val Loss: 0.40224
# Training Acc: 81.82, Training F1:0.82, Train Loss: 0.26269
# Epoch:49
# Validation Accuracy:66.58, Validation F1:0.67, Val Loss: 0.40531
# Training Acc: 81.44, Training F1:0.81, Train Loss: 0.26708
# Epoch:50
# Validation Accuracy:66.40, Validation F1:0.66, Val Loss: 0.41796
# Training Acc: 80.30, Training F1:0.80, Train Loss: 0.24448
# Epoch:1
# Validation Accuracy:60.88, Validation F1:0.61, Val Loss: 0.39273
# Training Acc: 63.53, Training F1:0.64, Train Loss: 0.40526
# Epoch:2
# Validation Accuracy:62.14, Validation F1:0.62, Val Loss: 0.38999
# Training Acc: 65.16, Training F1:0.65, Train Loss: 0.41247
# Epoch:3
# Validation Accuracy:64.95, Validation F1:0.65, Val Loss: 0.40321
# Training Acc: 67.61, Training F1:0.68, Train Loss: 0.39990
# Epoch:4
# Validation Accuracy:66.43, Validation F1:0.66, Val Loss: 0.38674
# Training Acc: 68.16, Training F1:0.68, Train Loss: 0.38390
# Epoch:5
# Validation Accuracy:67.72, Validation F1:0.68, Val Loss: 0.35371
# Training Acc: 70.81, Training F1:0.71, Train Loss: 0.35576
# Epoch:6
# Validation Accuracy:65.90, Validation F1:0.66, Val Loss: 0.39874
# Training Acc: 67.77, Training F1:0.68, Train Loss: 0.39610
# Epoch:7
# Validation Accuracy:63.49, Validation F1:0.63, Val Loss: 0.37702
# Training Acc: 66.10, Training F1:0.66, Train Loss: 0.39199
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:8
# Validation Accuracy:64.37, Validation F1:0.64, Val Loss: 0.38352
# Training Acc: 66.68, Training F1:0.67, Train Loss: 0.38891
# Epoch:9
# Validation Accuracy:68.83, Validation F1:0.69, Val Loss: 0.34644
# Training Acc: 72.09, Training F1:0.72, Train Loss: 0.34564
# Epoch:10
# Validation Accuracy:67.83, Validation F1:0.68, Val Loss: 0.34781
# Training Acc: 71.43, Training F1:0.71, Train Loss: 0.34065
# Epoch:11
# Validation Accuracy:69.75, Validation F1:0.70, Val Loss: 0.33564
# Training Acc: 72.60, Training F1:0.73, Train Loss: 0.32858
# Epoch:12
# Validation Accuracy:69.96, Validation F1:0.70, Val Loss: 0.33335
# Training Acc: 73.06, Training F1:0.73, Train Loss: 0.31806
# Epoch:13
# Validation Accuracy:69.45, Validation F1:0.69, Val Loss: 0.33941
# Training Acc: 73.02, Training F1:0.73, Train Loss: 0.32709
# Epoch:14
# Validation Accuracy:69.80, Validation F1:0.70, Val Loss: 0.33614
# Training Acc: 73.53, Training F1:0.74, Train Loss: 0.32791
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:15
# Validation Accuracy:69.25, Validation F1:0.69, Val Loss: 0.33819
# Training Acc: 73.30, Training F1:0.73, Train Loss: 0.31949
# Epoch:16
# Validation Accuracy:70.09, Validation F1:0.70, Val Loss: 0.32910
# Training Acc: 74.15, Training F1:0.74, Train Loss: 0.30660
# Epoch:17
# Validation Accuracy:70.27, Validation F1:0.70, Val Loss: 0.32755
# Training Acc: 74.19, Training F1:0.74, Train Loss: 0.30150
# Epoch:18
# Validation Accuracy:70.51, Validation F1:0.71, Val Loss: 0.32704
# Training Acc: 74.23, Training F1:0.74, Train Loss: 0.31357
# Epoch:19
# Validation Accuracy:70.38, Validation F1:0.70, Val Loss: 0.32699
# Training Acc: 74.23, Training F1:0.74, Train Loss: 0.31008
# Epoch:20
# Validation Accuracy:70.35, Validation F1:0.70, Val Loss: 0.32748
# Training Acc: 74.23, Training F1:0.74, Train Loss: 0.30701
# Epoch    20: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:21
# Validation Accuracy:70.25, Validation F1:0.70, Val Loss: 0.32722
# Training Acc: 74.46, Training F1:0.74, Train Loss: 0.30308
# Epoch:22
# Validation Accuracy:70.38, Validation F1:0.70, Val Loss: 0.32678
# Training Acc: 74.54, Training F1:0.75, Train Loss: 0.30119
# Epoch:23
# Validation Accuracy:70.32, Validation F1:0.70, Val Loss: 0.32724
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.31031
# Epoch    23: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:24
# Validation Accuracy:70.43, Validation F1:0.70, Val Loss: 0.32658
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.30388
# Epoch:25
# Validation Accuracy:70.27, Validation F1:0.70, Val Loss: 0.32711
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.30462
# Epoch:26
# Validation Accuracy:70.38, Validation F1:0.70, Val Loss: 0.32760
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.30276
# Epoch    26: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:27
# Validation Accuracy:70.37, Validation F1:0.70, Val Loss: 0.32733
# Training Acc: 74.39, Training F1:0.74, Train Loss: 0.30766
# Epoch:28
# Validation Accuracy:70.25, Validation F1:0.70, Val Loss: 0.32675
# Training Acc: 74.70, Training F1:0.75, Train Loss: 0.30512
# Epoch:29
# Validation Accuracy:70.46, Validation F1:0.70, Val Loss: 0.32673
# Training Acc: 74.46, Training F1:0.74, Train Loss: 0.30812
# Epoch    29: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:30
# Validation Accuracy:70.46, Validation F1:0.70, Val Loss: 0.32699
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.30197
# Epoch:31
# Validation Accuracy:70.24, Validation F1:0.70, Val Loss: 0.32745
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.30420
# Epoch:32
# Validation Accuracy:70.29, Validation F1:0.70, Val Loss: 0.32736
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.30168
# Epoch:33
# Validation Accuracy:70.40, Validation F1:0.70, Val Loss: 0.32687
# Training Acc: 74.54, Training F1:0.75, Train Loss: 0.30448
# Epoch:34
# Validation Accuracy:70.37, Validation F1:0.70, Val Loss: 0.32672
# Training Acc: 74.54, Training F1:0.75, Train Loss: 0.30408
# Epoch:35
# Validation Accuracy:70.30, Validation F1:0.70, Val Loss: 0.32757
# Training Acc: 74.46, Training F1:0.74, Train Loss: 0.29844
# Epoch:36
# Validation Accuracy:70.27, Validation F1:0.70, Val Loss: 0.32725
# Training Acc: 74.39, Training F1:0.74, Train Loss: 0.30416
# Epoch:37
# Validation Accuracy:70.30, Validation F1:0.70, Val Loss: 0.32644
# Training Acc: 74.54, Training F1:0.75, Train Loss: 0.30077
# Epoch:38
# Validation Accuracy:70.22, Validation F1:0.70, Val Loss: 0.32793
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.29877
# Epoch:39
# Validation Accuracy:70.38, Validation F1:0.70, Val Loss: 0.32767
# Training Acc: 74.50, Training F1:0.75, Train Loss: 0.30411
# Epoch:40
# Validation Accuracy:70.29, Validation F1:0.70, Val Loss: 0.32677
# Training Acc: 74.58, Training F1:0.75, Train Loss: 0.30016
# Epoch:41
# Validation Accuracy:70.22, Validation F1:0.70, Val Loss: 0.32674
# Training Acc: 74.62, Training F1:0.75, Train Loss: 0.30579
# Epoch:42
# Validation Accuracy:70.29, Validation F1:0.70, Val Loss: 0.32683
# Training Acc: 74.62, Training F1:0.75, Train Loss: 0.30210
# Epoch:43
# Validation Accuracy:70.37, Validation F1:0.70, Val Loss: 0.32758
# Training Acc: 74.08, Training F1:0.74, Train Loss: 0.30635
# Epoch:44
# Validation Accuracy:70.30, Validation F1:0.70, Val Loss: 0.32701
# Training Acc: 74.50, Training F1:0.75, Train Loss: 0.30716
# Epoch:45
# Validation Accuracy:70.32, Validation F1:0.70, Val Loss: 0.32630
# Training Acc: 74.46, Training F1:0.74, Train Loss: 0.30972
# Epoch:46
# Validation Accuracy:70.48, Validation F1:0.70, Val Loss: 0.32685
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.30808
# Epoch:47
# Validation Accuracy:70.45, Validation F1:0.70, Val Loss: 0.32657
# Training Acc: 74.43, Training F1:0.74, Train Loss: 0.30644
# Epoch:48
# Validation Accuracy:70.43, Validation F1:0.70, Val Loss: 0.32666
# Training Acc: 74.39, Training F1:0.74, Train Loss: 0.30635
# Epoch:49
# Validation Accuracy:70.32, Validation F1:0.70, Val Loss: 0.32750
# Training Acc: 74.19, Training F1:0.74, Train Loss: 0.30330
# Epoch:50
# Validation Accuracy:70.29, Validation F1:0.70, Val Loss: 0.32703
# Training Acc: 74.35, Training F1:0.74, Train Loss: 0.30547
# Epoch:1
# Validation Accuracy:63.64, Validation F1:0.64, Val Loss: 0.38655
# Training Acc: 65.40, Training F1:0.65, Train Loss: 0.39301
# Epoch:2
# Validation Accuracy:65.53, Validation F1:0.66, Val Loss: 0.37572
# Training Acc: 67.62, Training F1:0.68, Train Loss: 0.38395
# Epoch:3
# Validation Accuracy:68.11, Validation F1:0.68, Val Loss: 0.34881
# Training Acc: 69.74, Training F1:0.70, Train Loss: 0.35219
# Epoch:4
# Validation Accuracy:67.59, Validation F1:0.68, Val Loss: 0.35272
# Training Acc: 69.54, Training F1:0.70, Train Loss: 0.35802
# Epoch:5
# Validation Accuracy:68.96, Validation F1:0.69, Val Loss: 0.34347
# Training Acc: 71.46, Training F1:0.71, Train Loss: 0.34365
# Epoch:6
# Validation Accuracy:69.77, Validation F1:0.70, Val Loss: 0.33420
# Training Acc: 71.65, Training F1:0.72, Train Loss: 0.33988
# Epoch:7
# Validation Accuracy:66.38, Validation F1:0.66, Val Loss: 0.35536
# Training Acc: 68.30, Training F1:0.68, Train Loss: 0.36156
# Epoch:8
# Validation Accuracy:69.53, Validation F1:0.70, Val Loss: 0.32914
# Training Acc: 71.96, Training F1:0.72, Train Loss: 0.32670
# Epoch     8: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:9
# Validation Accuracy:69.66, Validation F1:0.70, Val Loss: 0.32458
# Training Acc: 71.87, Training F1:0.72, Train Loss: 0.32794
# Epoch:10
# Validation Accuracy:70.69, Validation F1:0.71, Val Loss: 0.31483
# Training Acc: 72.86, Training F1:0.73, Train Loss: 0.31584
# Epoch:11
# Validation Accuracy:71.00, Validation F1:0.71, Val Loss: 0.31101
# Training Acc: 73.21, Training F1:0.73, Train Loss: 0.30829
# Epoch:12
# Validation Accuracy:70.75, Validation F1:0.71, Val Loss: 0.31002
# Training Acc: 73.23, Training F1:0.73, Train Loss: 0.30849
# Epoch:13
# Validation Accuracy:71.08, Validation F1:0.71, Val Loss: 0.31191
# Training Acc: 73.11, Training F1:0.73, Train Loss: 0.31306
# Epoch:14
# Validation Accuracy:70.93, Validation F1:0.71, Val Loss: 0.30949
# Training Acc: 73.04, Training F1:0.73, Train Loss: 0.30681
# Epoch:15
# Validation Accuracy:71.41, Validation F1:0.71, Val Loss: 0.30409
# Training Acc: 73.55, Training F1:0.74, Train Loss: 0.30099
# Epoch:16
# Validation Accuracy:71.38, Validation F1:0.71, Val Loss: 0.30304
# Training Acc: 73.73, Training F1:0.74, Train Loss: 0.29874
# Epoch:17
# Validation Accuracy:71.51, Validation F1:0.72, Val Loss: 0.30036
# Training Acc: 73.84, Training F1:0.74, Train Loss: 0.29495
# Epoch:18
# Validation Accuracy:71.04, Validation F1:0.71, Val Loss: 0.30489
# Training Acc: 73.68, Training F1:0.74, Train Loss: 0.30145
# Epoch:19
# Validation Accuracy:71.43, Validation F1:0.71, Val Loss: 0.30063
# Training Acc: 74.30, Training F1:0.74, Train Loss: 0.29514
# Epoch    19: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:20
# Validation Accuracy:71.51, Validation F1:0.72, Val Loss: 0.30368
# Training Acc: 74.00, Training F1:0.74, Train Loss: 0.29803
# Epoch:21
# Validation Accuracy:72.19, Validation F1:0.72, Val Loss: 0.29686
# Training Acc: 74.78, Training F1:0.75, Train Loss: 0.29177
# Epoch:22
# Validation Accuracy:72.25, Validation F1:0.72, Val Loss: 0.29637
# Training Acc: 74.87, Training F1:0.75, Train Loss: 0.29065
# Epoch:23
# Validation Accuracy:72.33, Validation F1:0.72, Val Loss: 0.29625
# Training Acc: 74.96, Training F1:0.75, Train Loss: 0.28797
# Epoch:24
# Validation Accuracy:72.38, Validation F1:0.72, Val Loss: 0.29691
# Training Acc: 75.00, Training F1:0.75, Train Loss: 0.29145
# Epoch:25
# Validation Accuracy:72.48, Validation F1:0.72, Val Loss: 0.29630
# Training Acc: 75.00, Training F1:0.75, Train Loss: 0.28908
# Epoch:26
# Validation Accuracy:72.29, Validation F1:0.72, Val Loss: 0.29518
# Training Acc: 75.12, Training F1:0.75, Train Loss: 0.28581
# Epoch:27
# Validation Accuracy:72.46, Validation F1:0.72, Val Loss: 0.29590
# Training Acc: 75.12, Training F1:0.75, Train Loss: 0.28715
# Epoch    27: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:28
# Validation Accuracy:72.19, Validation F1:0.72, Val Loss: 0.29468
# Training Acc: 74.93, Training F1:0.75, Train Loss: 0.28666
# Epoch:29
# Validation Accuracy:72.48, Validation F1:0.72, Val Loss: 0.29566
# Training Acc: 75.08, Training F1:0.75, Train Loss: 0.28486
# Epoch:30
# Validation Accuracy:72.22, Validation F1:0.72, Val Loss: 0.29465
# Training Acc: 75.04, Training F1:0.75, Train Loss: 0.28560
# Epoch    30: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:31
# Validation Accuracy:72.45, Validation F1:0.72, Val Loss: 0.29559
# Training Acc: 75.07, Training F1:0.75, Train Loss: 0.28758
# Epoch:32
# Validation Accuracy:72.29, Validation F1:0.72, Val Loss: 0.29449
# Training Acc: 75.14, Training F1:0.75, Train Loss: 0.28553
# Epoch:33
# Validation Accuracy:72.32, Validation F1:0.72, Val Loss: 0.29460
# Training Acc: 75.06, Training F1:0.75, Train Loss: 0.28385
# Epoch    33: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:34
# Validation Accuracy:72.48, Validation F1:0.72, Val Loss: 0.29476
# Training Acc: 75.25, Training F1:0.75, Train Loss: 0.28560
# Epoch:35
# Validation Accuracy:72.38, Validation F1:0.72, Val Loss: 0.29503
# Training Acc: 75.14, Training F1:0.75, Train Loss: 0.28553
# Epoch:36
# Validation Accuracy:72.21, Validation F1:0.72, Val Loss: 0.29490
# Training Acc: 75.08, Training F1:0.75, Train Loss: 0.28797
# Epoch    36: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:37
# Validation Accuracy:72.25, Validation F1:0.72, Val Loss: 0.29469
# Training Acc: 75.03, Training F1:0.75, Train Loss: 0.28525
# Epoch:38
# Validation Accuracy:72.33, Validation F1:0.72, Val Loss: 0.29462
# Training Acc: 75.01, Training F1:0.75, Train Loss: 0.28648
# Epoch:39
# Validation Accuracy:72.19, Validation F1:0.72, Val Loss: 0.29416
# Training Acc: 75.16, Training F1:0.75, Train Loss: 0.28904
# Epoch:40
# Validation Accuracy:72.21, Validation F1:0.72, Val Loss: 0.29451
# Training Acc: 74.98, Training F1:0.75, Train Loss: 0.28855
# Epoch:41
# Validation Accuracy:72.21, Validation F1:0.72, Val Loss: 0.29439
# Training Acc: 75.12, Training F1:0.75, Train Loss: 0.28662
# Epoch:42
# Validation Accuracy:72.29, Validation F1:0.72, Val Loss: 0.29535
# Training Acc: 75.03, Training F1:0.75, Train Loss: 0.28879
# Epoch:43
# Validation Accuracy:72.30, Validation F1:0.72, Val Loss: 0.29443
# Training Acc: 75.12, Training F1:0.75, Train Loss: 0.28658
# Epoch:44
# Validation Accuracy:72.40, Validation F1:0.72, Val Loss: 0.29455
# Training Acc: 75.20, Training F1:0.75, Train Loss: 0.28614
# Epoch:45
# Validation Accuracy:72.32, Validation F1:0.72, Val Loss: 0.29471
# Training Acc: 75.16, Training F1:0.75, Train Loss: 0.28476
# Epoch:46
# Validation Accuracy:72.19, Validation F1:0.72, Val Loss: 0.29434
# Training Acc: 75.15, Training F1:0.75, Train Loss: 0.28104
# Epoch:47
# Validation Accuracy:72.59, Validation F1:0.73, Val Loss: 0.29531
# Training Acc: 75.10, Training F1:0.75, Train Loss: 0.28502
# Epoch:48
# Validation Accuracy:72.58, Validation F1:0.73, Val Loss: 0.29499
# Training Acc: 75.20, Training F1:0.75, Train Loss: 0.28693
# Epoch:49
# Validation Accuracy:72.50, Validation F1:0.72, Val Loss: 0.29506
# Training Acc: 75.07, Training F1:0.75, Train Loss: 0.28566
# Epoch:50
# Validation Accuracy:72.37, Validation F1:0.72, Val Loss: 0.29522
# Training Acc: 75.01, Training F1:0.75, Train Loss: 0.28624
# Epoch:1
# Validation Accuracy:64.49, Validation F1:0.64, Val Loss: 0.42953
# Training Acc: 66.67, Training F1:0.67, Train Loss: 0.41485
# Epoch:2
# Validation Accuracy:67.67, Validation F1:0.68, Val Loss: 0.35202
# Training Acc: 69.27, Training F1:0.69, Train Loss: 0.35435
# Epoch:3
# Validation Accuracy:67.35, Validation F1:0.67, Val Loss: 0.38949
# Training Acc: 68.91, Training F1:0.69, Train Loss: 0.38468
# Epoch:4
# Validation Accuracy:68.75, Validation F1:0.69, Val Loss: 0.33721
# Training Acc: 71.04, Training F1:0.71, Train Loss: 0.33271
# Epoch:5
# Validation Accuracy:69.66, Validation F1:0.70, Val Loss: 0.32550
# Training Acc: 71.53, Training F1:0.72, Train Loss: 0.32656
# Epoch:6
# Validation Accuracy:69.20, Validation F1:0.69, Val Loss: 0.33474
# Training Acc: 71.01, Training F1:0.71, Train Loss: 0.33669
# Epoch:7
# Validation Accuracy:69.43, Validation F1:0.69, Val Loss: 0.33246
# Training Acc: 70.92, Training F1:0.71, Train Loss: 0.33343
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:8
# Validation Accuracy:69.35, Validation F1:0.69, Val Loss: 0.33332
# Training Acc: 70.82, Training F1:0.71, Train Loss: 0.32997
# Epoch:9
# Validation Accuracy:70.50, Validation F1:0.70, Val Loss: 0.31704
# Training Acc: 72.34, Training F1:0.72, Train Loss: 0.31750
# Epoch:10
# Validation Accuracy:71.11, Validation F1:0.71, Val Loss: 0.31599
# Training Acc: 72.40, Training F1:0.72, Train Loss: 0.31553
# Epoch:11
# Validation Accuracy:70.70, Validation F1:0.71, Val Loss: 0.31836
# Training Acc: 72.53, Training F1:0.73, Train Loss: 0.31814
# Epoch:12
# Validation Accuracy:70.79, Validation F1:0.71, Val Loss: 0.31314
# Training Acc: 72.61, Training F1:0.73, Train Loss: 0.31397
# Epoch:13
# Validation Accuracy:71.62, Validation F1:0.72, Val Loss: 0.30745
# Training Acc: 73.21, Training F1:0.73, Train Loss: 0.30600
# Epoch:14
# Validation Accuracy:71.32, Validation F1:0.71, Val Loss: 0.30970
# Training Acc: 73.38, Training F1:0.73, Train Loss: 0.30446
# Epoch:15
# Validation Accuracy:70.82, Validation F1:0.71, Val Loss: 0.30936
# Training Acc: 73.11, Training F1:0.73, Train Loss: 0.30660
# Epoch    15: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:16
# Validation Accuracy:71.37, Validation F1:0.71, Val Loss: 0.30285
# Training Acc: 73.53, Training F1:0.74, Train Loss: 0.30057
# Epoch:17
# Validation Accuracy:72.11, Validation F1:0.72, Val Loss: 0.30085
# Training Acc: 74.00, Training F1:0.74, Train Loss: 0.29484
# Epoch:18
# Validation Accuracy:72.12, Validation F1:0.72, Val Loss: 0.29966
# Training Acc: 74.00, Training F1:0.74, Train Loss: 0.29565
# Epoch:19
# Validation Accuracy:72.11, Validation F1:0.72, Val Loss: 0.29947
# Training Acc: 74.17, Training F1:0.74, Train Loss: 0.29399
# Epoch:20
# Validation Accuracy:72.45, Validation F1:0.72, Val Loss: 0.29892
# Training Acc: 74.36, Training F1:0.74, Train Loss: 0.29430
# Epoch:21
# Validation Accuracy:72.00, Validation F1:0.72, Val Loss: 0.29979
# Training Acc: 74.27, Training F1:0.74, Train Loss: 0.29614
# Epoch:22
# Validation Accuracy:72.29, Validation F1:0.72, Val Loss: 0.29834
# Training Acc: 74.40, Training F1:0.74, Train Loss: 0.29553
# Epoch:23
# Validation Accuracy:72.54, Validation F1:0.73, Val Loss: 0.29911
# Training Acc: 74.46, Training F1:0.74, Train Loss: 0.29199
# Epoch:24
# Validation Accuracy:72.67, Validation F1:0.73, Val Loss: 0.29861
# Training Acc: 74.60, Training F1:0.75, Train Loss: 0.29372
# Epoch:25
# Validation Accuracy:72.75, Validation F1:0.73, Val Loss: 0.29791
# Training Acc: 74.65, Training F1:0.75, Train Loss: 0.29422
# Epoch:26
# Validation Accuracy:72.82, Validation F1:0.73, Val Loss: 0.29762
# Training Acc: 74.62, Training F1:0.75, Train Loss: 0.29112
# Epoch:27
# Validation Accuracy:72.46, Validation F1:0.72, Val Loss: 0.29732
# Training Acc: 74.62, Training F1:0.75, Train Loss: 0.29172
# Epoch:28
# Validation Accuracy:72.46, Validation F1:0.72, Val Loss: 0.29674
# Training Acc: 74.73, Training F1:0.75, Train Loss: 0.28897
# Epoch    28: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:29
# Validation Accuracy:72.72, Validation F1:0.73, Val Loss: 0.29681
# Training Acc: 74.65, Training F1:0.75, Train Loss: 0.29249
# Epoch:30
# Validation Accuracy:72.71, Validation F1:0.73, Val Loss: 0.29659
# Training Acc: 74.51, Training F1:0.75, Train Loss: 0.29126
# Epoch:31
# Validation Accuracy:72.72, Validation F1:0.73, Val Loss: 0.29615
# Training Acc: 74.62, Training F1:0.75, Train Loss: 0.29142
# Epoch    31: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:32
# Validation Accuracy:72.66, Validation F1:0.73, Val Loss: 0.29702
# Training Acc: 74.77, Training F1:0.75, Train Loss: 0.29185
# Epoch:33
# Validation Accuracy:72.64, Validation F1:0.73, Val Loss: 0.29654
# Training Acc: 74.72, Training F1:0.75, Train Loss: 0.29283
# Epoch:34
# Validation Accuracy:72.71, Validation F1:0.73, Val Loss: 0.29686
# Training Acc: 74.68, Training F1:0.75, Train Loss: 0.29148
# Epoch    34: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:35
# Validation Accuracy:72.79, Validation F1:0.73, Val Loss: 0.29664
# Training Acc: 74.76, Training F1:0.75, Train Loss: 0.29184
# Epoch:36
# Validation Accuracy:72.74, Validation F1:0.73, Val Loss: 0.29641
# Training Acc: 74.72, Training F1:0.75, Train Loss: 0.29282
# Epoch:37
# Validation Accuracy:72.82, Validation F1:0.73, Val Loss: 0.29627
# Training Acc: 74.73, Training F1:0.75, Train Loss: 0.29142
# Epoch    37: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:38
# Validation Accuracy:72.74, Validation F1:0.73, Val Loss: 0.29681
# Training Acc: 74.67, Training F1:0.75, Train Loss: 0.28805
# Epoch:39
# Validation Accuracy:72.79, Validation F1:0.73, Val Loss: 0.29653
# Training Acc: 74.71, Training F1:0.75, Train Loss: 0.28986
# Epoch:40
# Validation Accuracy:72.54, Validation F1:0.73, Val Loss: 0.29731
# Training Acc: 74.63, Training F1:0.75, Train Loss: 0.29541
# Epoch:41
# Validation Accuracy:72.82, Validation F1:0.73, Val Loss: 0.29629
# Training Acc: 74.67, Training F1:0.75, Train Loss: 0.28904
# Epoch:42
# Validation Accuracy:72.71, Validation F1:0.73, Val Loss: 0.29673
# Training Acc: 74.77, Training F1:0.75, Train Loss: 0.29022
# Epoch:43
# Validation Accuracy:72.75, Validation F1:0.73, Val Loss: 0.29630
# Training Acc: 74.66, Training F1:0.75, Train Loss: 0.29093
# Epoch:44
# Validation Accuracy:72.75, Validation F1:0.73, Val Loss: 0.29656
# Training Acc: 74.70, Training F1:0.75, Train Loss: 0.28961
# Epoch:45
# Validation Accuracy:72.72, Validation F1:0.73, Val Loss: 0.29678
# Training Acc: 74.81, Training F1:0.75, Train Loss: 0.29072
# Epoch:46
# Validation Accuracy:72.83, Validation F1:0.73, Val Loss: 0.29634
# Training Acc: 74.77, Training F1:0.75, Train Loss: 0.28996
# Epoch:47
# Validation Accuracy:72.72, Validation F1:0.73, Val Loss: 0.29598
# Training Acc: 74.72, Training F1:0.75, Train Loss: 0.29024
# Epoch:48
# Validation Accuracy:72.71, Validation F1:0.73, Val Loss: 0.29606
# Training Acc: 74.75, Training F1:0.75, Train Loss: 0.29030
# Epoch:49
# Validation Accuracy:72.80, Validation F1:0.73, Val Loss: 0.29695
# Training Acc: 74.80, Training F1:0.75, Train Loss: 0.29074
# Epoch:50
# Validation Accuracy:72.75, Validation F1:0.73, Val Loss: 0.29629
# Training Acc: 74.71, Training F1:0.75, Train Loss: 0.29074
# Epoch:1
# Validation Accuracy:67.53, Validation F1:0.68, Val Loss: 0.37445
# Training Acc: 68.21, Training F1:0.68, Train Loss: 0.38948
# Epoch:2
# Validation Accuracy:68.30, Validation F1:0.68, Val Loss: 0.33534
# Training Acc: 69.57, Training F1:0.70, Train Loss: 0.34464
# Epoch:3
# Validation Accuracy:69.35, Validation F1:0.69, Val Loss: 0.33251
# Training Acc: 69.93, Training F1:0.70, Train Loss: 0.33802
# Epoch:4
# Validation Accuracy:70.82, Validation F1:0.71, Val Loss: 0.32368
# Training Acc: 71.35, Training F1:0.71, Train Loss: 0.32990
# Epoch:5
# Validation Accuracy:70.29, Validation F1:0.70, Val Loss: 0.31738
# Training Acc: 71.57, Training F1:0.72, Train Loss: 0.32622
# Epoch:6
# Validation Accuracy:70.53, Validation F1:0.71, Val Loss: 0.31642
# Training Acc: 71.34, Training F1:0.71, Train Loss: 0.32367
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:7
# Validation Accuracy:70.04, Validation F1:0.70, Val Loss: 0.31804
# Training Acc: 71.04, Training F1:0.71, Train Loss: 0.32931
# Epoch:8
# Validation Accuracy:71.91, Validation F1:0.72, Val Loss: 0.30316
# Training Acc: 72.85, Training F1:0.73, Train Loss: 0.30612
# Epoch:9
# Validation Accuracy:72.12, Validation F1:0.72, Val Loss: 0.30152
# Training Acc: 73.05, Training F1:0.73, Train Loss: 0.30520
# Epoch:10
# Validation Accuracy:71.96, Validation F1:0.72, Val Loss: 0.30143
# Training Acc: 73.03, Training F1:0.73, Train Loss: 0.30385
# Epoch:11
# Validation Accuracy:72.25, Validation F1:0.72, Val Loss: 0.30001
# Training Acc: 73.15, Training F1:0.73, Train Loss: 0.30124
# Epoch:12
# Validation Accuracy:72.41, Validation F1:0.72, Val Loss: 0.30370
# Training Acc: 73.35, Training F1:0.73, Train Loss: 0.30205
# Epoch:13
# Validation Accuracy:72.56, Validation F1:0.73, Val Loss: 0.29708
# Training Acc: 73.43, Training F1:0.73, Train Loss: 0.29842
# Epoch:14
# Validation Accuracy:72.38, Validation F1:0.72, Val Loss: 0.29759
# Training Acc: 73.42, Training F1:0.73, Train Loss: 0.29824
# Epoch:15
# Validation Accuracy:72.43, Validation F1:0.72, Val Loss: 0.29962
# Training Acc: 73.45, Training F1:0.73, Train Loss: 0.30069
# Epoch:16
# Validation Accuracy:72.69, Validation F1:0.73, Val Loss: 0.29549
# Training Acc: 73.48, Training F1:0.73, Train Loss: 0.29654
# Epoch:17
# Validation Accuracy:72.90, Validation F1:0.73, Val Loss: 0.29718
# Training Acc: 73.60, Training F1:0.74, Train Loss: 0.29925
# Epoch:18
# Validation Accuracy:72.85, Validation F1:0.73, Val Loss: 0.29450
# Training Acc: 73.85, Training F1:0.74, Train Loss: 0.29755
# Epoch:19
# Validation Accuracy:73.11, Validation F1:0.73, Val Loss: 0.29438
# Training Acc: 73.69, Training F1:0.74, Train Loss: 0.29759
# Epoch:20
# Validation Accuracy:72.40, Validation F1:0.72, Val Loss: 0.30095
# Training Acc: 73.76, Training F1:0.74, Train Loss: 0.29675
# Epoch:21
# Validation Accuracy:73.32, Validation F1:0.73, Val Loss: 0.29354
# Training Acc: 74.24, Training F1:0.74, Train Loss: 0.29523
# Epoch:22
# Validation Accuracy:72.87, Validation F1:0.73, Val Loss: 0.29595
# Training Acc: 74.42, Training F1:0.74, Train Loss: 0.29276
# Epoch:23
# Validation Accuracy:73.09, Validation F1:0.73, Val Loss: 0.29658
# Training Acc: 74.60, Training F1:0.75, Train Loss: 0.29629
# Epoch    23: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:24
# Validation Accuracy:73.27, Validation F1:0.73, Val Loss: 0.29149
# Training Acc: 74.38, Training F1:0.74, Train Loss: 0.29085
# Epoch:25
# Validation Accuracy:73.46, Validation F1:0.73, Val Loss: 0.28940
# Training Acc: 75.12, Training F1:0.75, Train Loss: 0.28702
# Epoch:26
# Validation Accuracy:73.43, Validation F1:0.73, Val Loss: 0.28885
# Training Acc: 75.04, Training F1:0.75, Train Loss: 0.28713
# Epoch:27
# Validation Accuracy:73.66, Validation F1:0.74, Val Loss: 0.28816
# Training Acc: 75.12, Training F1:0.75, Train Loss: 0.28448
# Epoch:28
# Validation Accuracy:73.66, Validation F1:0.74, Val Loss: 0.28817
# Training Acc: 75.14, Training F1:0.75, Train Loss: 0.28243
# Epoch:29
# Validation Accuracy:73.53, Validation F1:0.74, Val Loss: 0.28848
# Training Acc: 75.31, Training F1:0.75, Train Loss: 0.28540
# Epoch    29: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:30
# Validation Accuracy:73.59, Validation F1:0.74, Val Loss: 0.28856
# Training Acc: 75.41, Training F1:0.75, Train Loss: 0.28692
# Epoch:31
# Validation Accuracy:73.43, Validation F1:0.73, Val Loss: 0.28787
# Training Acc: 75.32, Training F1:0.75, Train Loss: 0.28508
# Epoch:32
# Validation Accuracy:73.62, Validation F1:0.74, Val Loss: 0.28831
# Training Acc: 75.40, Training F1:0.75, Train Loss: 0.28340
# Epoch    32: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:33
# Validation Accuracy:73.48, Validation F1:0.73, Val Loss: 0.28813
# Training Acc: 75.31, Training F1:0.75, Train Loss: 0.28543
# Epoch:34
# Validation Accuracy:73.71, Validation F1:0.74, Val Loss: 0.28758
# Training Acc: 75.31, Training F1:0.75, Train Loss: 0.28338
# Epoch:35
# Validation Accuracy:73.88, Validation F1:0.74, Val Loss: 0.28777
# Training Acc: 75.27, Training F1:0.75, Train Loss: 0.28422
# Epoch:36
# Validation Accuracy:73.56, Validation F1:0.74, Val Loss: 0.28829
# Training Acc: 75.41, Training F1:0.75, Train Loss: 0.28432
# Epoch:37
# Validation Accuracy:73.69, Validation F1:0.74, Val Loss: 0.28782
# Training Acc: 75.32, Training F1:0.75, Train Loss: 0.28256
# Epoch    37: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:38
# Validation Accuracy:73.42, Validation F1:0.73, Val Loss: 0.28810
# Training Acc: 75.28, Training F1:0.75, Train Loss: 0.28518
# Epoch:39
# Validation Accuracy:73.46, Validation F1:0.73, Val Loss: 0.28826
# Training Acc: 75.36, Training F1:0.75, Train Loss: 0.28504
# Epoch:40
# Validation Accuracy:73.46, Validation F1:0.73, Val Loss: 0.28786
# Training Acc: 75.29, Training F1:0.75, Train Loss: 0.28285
# Epoch    40: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:41
# Validation Accuracy:73.54, Validation F1:0.74, Val Loss: 0.28861
# Training Acc: 75.48, Training F1:0.75, Train Loss: 0.28372
# Epoch:42
# Validation Accuracy:73.72, Validation F1:0.74, Val Loss: 0.28821
# Training Acc: 75.33, Training F1:0.75, Train Loss: 0.28456
# Epoch:43
# Validation Accuracy:73.46, Validation F1:0.73, Val Loss: 0.28802
# Training Acc: 75.33, Training F1:0.75, Train Loss: 0.28436
# Epoch:44
# Validation Accuracy:73.71, Validation F1:0.74, Val Loss: 0.28794
# Training Acc: 75.33, Training F1:0.75, Train Loss: 0.28450
# Epoch:45
# Validation Accuracy:73.43, Validation F1:0.73, Val Loss: 0.28803
# Training Acc: 75.28, Training F1:0.75, Train Loss: 0.28453
# Epoch:46
# Validation Accuracy:73.74, Validation F1:0.74, Val Loss: 0.28821
# Training Acc: 75.39, Training F1:0.75, Train Loss: 0.28441
# Epoch:47
# Validation Accuracy:73.62, Validation F1:0.74, Val Loss: 0.28775
# Training Acc: 75.35, Training F1:0.75, Train Loss: 0.28370
# Epoch:48
# Validation Accuracy:73.46, Validation F1:0.73, Val Loss: 0.28815
# Training Acc: 75.35, Training F1:0.75, Train Loss: 0.28641
# Epoch:49
# Validation Accuracy:73.56, Validation F1:0.74, Val Loss: 0.28827
# Training Acc: 75.35, Training F1:0.75, Train Loss: 0.28366
# Epoch:50
# Validation Accuracy:73.61, Validation F1:0.74, Val Loss: 0.28755
# Training Acc: 75.29, Training F1:0.75, Train Loss: 0.28381
# Epoch:1
# Validation Accuracy:66.62, Validation F1:0.67, Val Loss: 0.36261
# Training Acc: 67.07, Training F1:0.67, Train Loss: 0.36775
# Epoch:2
# Validation Accuracy:65.85, Validation F1:0.66, Val Loss: 0.37024
# Training Acc: 66.04, Training F1:0.66, Train Loss: 0.37300
# Epoch:3
# Validation Accuracy:66.70, Validation F1:0.67, Val Loss: 0.36744
# Training Acc: 67.54, Training F1:0.68, Train Loss: 0.37008
# Epoch:4
# Validation Accuracy:68.53, Validation F1:0.69, Val Loss: 0.34519
# Training Acc: 69.25, Training F1:0.69, Train Loss: 0.34579
# Epoch:5
# Validation Accuracy:68.66, Validation F1:0.69, Val Loss: 0.33717
# Training Acc: 69.83, Training F1:0.70, Train Loss: 0.34236
# Epoch:6
# Validation Accuracy:67.96, Validation F1:0.68, Val Loss: 0.34444
# Training Acc: 68.69, Training F1:0.69, Train Loss: 0.34959
# Epoch:7
# Validation Accuracy:69.11, Validation F1:0.69, Val Loss: 0.33647
# Training Acc: 69.71, Training F1:0.70, Train Loss: 0.33901
# Epoch:8
# Validation Accuracy:68.41, Validation F1:0.68, Val Loss: 0.35214
# Training Acc: 69.03, Training F1:0.69, Train Loss: 0.35748
# Epoch:9
# Validation Accuracy:69.90, Validation F1:0.70, Val Loss: 0.33304
# Training Acc: 70.43, Training F1:0.70, Train Loss: 0.33577
# Epoch:10
# Validation Accuracy:69.54, Validation F1:0.70, Val Loss: 0.33465
# Training Acc: 69.85, Training F1:0.70, Train Loss: 0.33925
# Epoch:11
# Validation Accuracy:68.67, Validation F1:0.69, Val Loss: 0.33834
# Training Acc: 69.53, Training F1:0.70, Train Loss: 0.34079
# Epoch    11: reducing learning rate of group 0 to 1.0000e-03.
# Epoch:12
# Validation Accuracy:67.91, Validation F1:0.68, Val Loss: 0.35162
# Training Acc: 67.91, Training F1:0.68, Train Loss: 0.36062
# Epoch:13
# Validation Accuracy:70.11, Validation F1:0.70, Val Loss: 0.32630
# Training Acc: 70.72, Training F1:0.71, Train Loss: 0.33029
# Epoch:14
# Validation Accuracy:70.80, Validation F1:0.71, Val Loss: 0.32146
# Training Acc: 71.02, Training F1:0.71, Train Loss: 0.32367
# Epoch:15
# Validation Accuracy:70.88, Validation F1:0.71, Val Loss: 0.32070
# Training Acc: 70.90, Training F1:0.71, Train Loss: 0.32535
# Epoch:16
# Validation Accuracy:70.75, Validation F1:0.71, Val Loss: 0.32056
# Training Acc: 70.85, Training F1:0.71, Train Loss: 0.32651
# Epoch:17
# Validation Accuracy:71.03, Validation F1:0.71, Val Loss: 0.31929
# Training Acc: 71.20, Training F1:0.71, Train Loss: 0.32515
# Epoch:18
# Validation Accuracy:70.95, Validation F1:0.71, Val Loss: 0.32308
# Training Acc: 71.12, Training F1:0.71, Train Loss: 0.32573
# Epoch:19
# Validation Accuracy:70.93, Validation F1:0.71, Val Loss: 0.31818
# Training Acc: 71.27, Training F1:0.71, Train Loss: 0.32249
# Epoch:20
# Validation Accuracy:71.32, Validation F1:0.71, Val Loss: 0.31768
# Training Acc: 71.23, Training F1:0.71, Train Loss: 0.32087
# Epoch:21
# Validation Accuracy:71.04, Validation F1:0.71, Val Loss: 0.31629
# Training Acc: 71.15, Training F1:0.71, Train Loss: 0.32369
# Epoch:22
# Validation Accuracy:71.19, Validation F1:0.71, Val Loss: 0.31863
# Training Acc: 71.52, Training F1:0.72, Train Loss: 0.32259
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:23
# Validation Accuracy:71.25, Validation F1:0.71, Val Loss: 0.31618
# Training Acc: 71.55, Training F1:0.72, Train Loss: 0.32027
# Epoch:24
# Validation Accuracy:71.53, Validation F1:0.72, Val Loss: 0.31483
# Training Acc: 71.61, Training F1:0.72, Train Loss: 0.31826
# Epoch:25
# Validation Accuracy:71.51, Validation F1:0.72, Val Loss: 0.31399
# Training Acc: 71.77, Training F1:0.72, Train Loss: 0.31722
# Epoch:26
# Validation Accuracy:71.59, Validation F1:0.72, Val Loss: 0.31357
# Training Acc: 71.73, Training F1:0.72, Train Loss: 0.31856
# Epoch:27
# Validation Accuracy:71.66, Validation F1:0.72, Val Loss: 0.31431
# Training Acc: 71.76, Training F1:0.72, Train Loss: 0.31823
# Epoch:28
# Validation Accuracy:71.56, Validation F1:0.72, Val Loss: 0.31394
# Training Acc: 71.72, Training F1:0.72, Train Loss: 0.31792
# Epoch:29
# Validation Accuracy:71.46, Validation F1:0.71, Val Loss: 0.31403
# Training Acc: 71.76, Training F1:0.72, Train Loss: 0.31747
# Epoch    29: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:30
# Validation Accuracy:71.41, Validation F1:0.71, Val Loss: 0.31451
# Training Acc: 71.72, Training F1:0.72, Train Loss: 0.31750
# Epoch:31
# Validation Accuracy:71.61, Validation F1:0.72, Val Loss: 0.31314
# Training Acc: 71.77, Training F1:0.72, Train Loss: 0.31901
# Epoch:32
# Validation Accuracy:71.61, Validation F1:0.72, Val Loss: 0.31347
# Training Acc: 71.76, Training F1:0.72, Train Loss: 0.31693
# Epoch    32: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:33
# Validation Accuracy:71.54, Validation F1:0.72, Val Loss: 0.31374
# Training Acc: 71.79, Training F1:0.72, Train Loss: 0.31835
# Epoch:34
# Validation Accuracy:71.69, Validation F1:0.72, Val Loss: 0.31331
# Training Acc: 71.83, Training F1:0.72, Train Loss: 0.31719
# Epoch:35
# Validation Accuracy:71.54, Validation F1:0.72, Val Loss: 0.31408
# Training Acc: 71.68, Training F1:0.72, Train Loss: 0.31827
# Epoch:36
# Validation Accuracy:71.64, Validation F1:0.72, Val Loss: 0.31390
# Training Acc: 71.78, Training F1:0.72, Train Loss: 0.31471
# Epoch:37
# Validation Accuracy:71.72, Validation F1:0.72, Val Loss: 0.31359
# Training Acc: 71.78, Training F1:0.72, Train Loss: 0.32086
# Epoch:38
# Validation Accuracy:71.66, Validation F1:0.72, Val Loss: 0.31339
# Training Acc: 71.78, Training F1:0.72, Train Loss: 0.31772
# Epoch:39
# Validation Accuracy:71.66, Validation F1:0.72, Val Loss: 0.31379
# Training Acc: 71.78, Training F1:0.72, Train Loss: 0.31713
# Epoch:40
# Validation Accuracy:71.75, Validation F1:0.72, Val Loss: 0.31322
# Training Acc: 71.73, Training F1:0.72, Train Loss: 0.31622
# Epoch:41
# Validation Accuracy:71.54, Validation F1:0.72, Val Loss: 0.31372
# Training Acc: 71.82, Training F1:0.72, Train Loss: 0.31942
# Epoch:42
# Validation Accuracy:71.61, Validation F1:0.72, Val Loss: 0.31339
# Training Acc: 71.81, Training F1:0.72, Train Loss: 0.31731
# Epoch    42: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:43
# Validation Accuracy:71.69, Validation F1:0.72, Val Loss: 0.31365
# Training Acc: 71.82, Training F1:0.72, Train Loss: 0.31733
# Epoch:44
# Validation Accuracy:71.66, Validation F1:0.72, Val Loss: 0.31336
# Training Acc: 71.81, Training F1:0.72, Train Loss: 0.31758
# Epoch:45
# Validation Accuracy:71.75, Validation F1:0.72, Val Loss: 0.31381
# Training Acc: 71.81, Training F1:0.72, Train Loss: 0.31874
# Epoch    45: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:46
# Validation Accuracy:71.71, Validation F1:0.72, Val Loss: 0.31339
# Training Acc: 71.84, Training F1:0.72, Train Loss: 0.31923
# Epoch:47
# Validation Accuracy:71.50, Validation F1:0.71, Val Loss: 0.31376
# Training Acc: 71.79, Training F1:0.72, Train Loss: 0.31883
# Epoch:48
# Validation Accuracy:71.67, Validation F1:0.72, Val Loss: 0.31334
# Training Acc: 71.81, Training F1:0.72, Train Loss: 0.31766
# Epoch:49
# Validation Accuracy:71.59, Validation F1:0.72, Val Loss: 0.31413
# Training Acc: 71.72, Training F1:0.72, Train Loss: 0.31931
# Epoch:50
# Validation Accuracy:71.56, Validation F1:0.72, Val Loss: 0.31359
# Training Acc: 71.76, Training F1:0.72, Train Loss: 0.31741

# %%
mean = 0.
std = 0.
for images, _, _ in Train_loader:
    batch_samples = images.size(0) # batch size (the last batch can have smaller size!)
    images1 = images.reshape(batch_samples, images.size(1), -1)
    mean += images1.mean(2).sum(0)
    std += images1.std(2).sum(0)
    
mean /= len(Train_loader.dataset)
std /= len(Train_loader.dataset)

# %%
print(mean, std)
# Out:
# tensor([-24.3633]) tensor([14.2659])
