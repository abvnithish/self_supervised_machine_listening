# %%
# -*- coding: utf-8 -*-

from matplotlib import pyplot as plt
import numpy as np
import random
from torch.utils.data import Dataset, DataLoader
import torch
import os
from torch.optim import *
from torch import nn
from torch.nn import functional as F
from scipy import ndimage
import pandas as pd
from copy import deepcopy
import random
from sklearn.metrics import f1_score
import torchvision.models as models


random.seed(7)
torch.cuda.manual_seed(7)
torch.manual_seed(7)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(7)

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
DATA_ROOT = '/beegfs/bva212/openmic-2018'
OPENMIC = np.load(os.path.join(DATA_ROOT, 'openmic-2018.npz'))
X, Y_true, Y_mask, sample_key = OPENMIC['X'], OPENMIC['Y_true'], OPENMIC['Y_mask'], OPENMIC['sample_key']

# %%
train_samples = pd.read_csv(os.path.join(DATA_ROOT,'partitions/split01_train.csv'), names =['id']).to_numpy().squeeze()
test_samples = pd.read_csv(os.path.join(DATA_ROOT,'partitions/split01_test.csv'), names =['id']).to_numpy().squeeze()

# %%
len_data = len(train_samples)
idx_train = np.random.choice(len_data, int(len_data*0.8), replace=False)
remain_set = list(set(np.arange(len_data))-set(idx_train))

# %%
val_idx = np.isin(sample_key, train_samples[remain_set])
train_idx = np.isin(sample_key, train_samples[idx_train])
test_idx = np.isin(sample_key, test_samples)

# %%
class ArrowOfTime(Dataset):

    def __init__(self, root_dir, files, weights, label):
        self.weights = weights
        self.device = device
        self.root_dir = root_dir
        self.files = files
        self.label = label

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        logscalogram = (np.load(self.root_dir + self.files[idx]+'_cqt.npy') - -24.3633)/14.2659
        len_cqt = logscalogram.shape[1]
        rem = len_cqt % 3
        logscalograms = np.split(logscalogram[:, :-rem], 3, axis = 1)
        logscalograms = np.stack(logscalograms)

        weight = self.weights[idx]
        label = (self.label[idx] > 0.5).astype(int)
        return {'logscalogram': logscalograms, 'label': label[np.newaxis, :], 'weight': weight[np.newaxis, :]}

filenames = []
root_dir = '/beegfs/bva212/openmic-2018/cqt_full/'

BATCH_SIZE = 32

def my_collate(batch):
    data = np.stack([item['logscalogram'] for item in batch])
    target = np.concatenate([item['label'] for item in batch],axis=0)
    weight = np.concatenate([item['weight'] for item in batch],axis=0)
    weight_sum = weight.sum(0)
    weight_sum = np.repeat(weight_sum[np.newaxis, :], len(batch), 0)
    weight_sum[weight_sum==0]=1
    weight = weight/weight_sum
    return [torch.from_numpy(data).float(), torch.from_numpy(target).float(), torch.from_numpy(weight).float()]

# %%
# Function for testing the model
def test_model(loader, model):
    correct = 0
    total_loss = 0
    total = 0
    total_num = 0
    actual_arr = []
    predicted_arr = []
    weight_array = []
    model.eval()
    with torch.no_grad():
        for spectrogram, target, weight in loader:
            spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
            outputs = model(spectrogram_batch)
            loss = F.binary_cross_entropy_with_logits(outputs, target_batch,
                                                  weight = weight_batch,
                                                  reduction='sum')
            predicted = (torch.sigmoid(outputs.data)>0.5).float()
            
            actual_arr.extend(target.view(1,-1).squeeze().numpy().astype(int).tolist())
            predicted_arr.extend(predicted.view(1,-1).squeeze().cpu().numpy().astype(int).tolist())
            
            total_loss += loss.item()
            total += weight_batch.shape[0]
            
            correct += ((weight_batch != 0).float()*(predicted.eq(target_batch.view_as(predicted)).float())).sum().item()
            total_num += (weight_batch != 0).sum().item()
            weight_array = np.concatenate((weight_array,(weight != 0).reshape(-1).numpy().astype(int)))
        accuracy = (100 * correct / total_num)
        return accuracy, f1_score(actual_arr, predicted_arr, average='micro', sample_weight = weight_array), total_loss/total

def train_model(train_loader, val_loader, model, optimizer, scheduler, num_epochs):
    train_acc_list = []
    train_loss_list = []
    val_acc_list = []
    val_loss_list = []
    train_f1_list = []
    val_f1_list = []
    best_val_acc = 0
    for epoch in range(num_epochs):
        for spectrogram, target, weight in train_loader:
            model.train()
            spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
            optimizer.zero_grad()
            outputs = model(spectrogram_batch)
            loss = F.binary_cross_entropy_with_logits(outputs, target_batch,
                                                  weight = weight_batch,
                                                  reduction='sum')
            loss.backward()
            optimizer.step()
        train_acc, f1_score_train, train_loss = test_model(train_loader, model)
        val_acc, f1_score_val, val_loss = test_model(val_loader, model)
        
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state_dict = deepcopy(model.state_dict())
        
        train_acc_list.append(train_acc)
        train_f1_list.append(f1_score_train)
        train_loss_list.append(train_loss)
        val_f1_list.append(f1_score_val)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)
        
        scheduler.step(val_acc)
        print("Epoch:{}".format(epoch+1))
        print("Validation Accuracy:{:.2f}, Validation F1:{:.2f}, Val Loss: {:.5f}".format(val_acc, f1_score_val, val_loss))
        print("Training Acc: {:.2f}, Training F1:{:.2f}, Train Loss: {:.5f}".format(train_acc, f1_score_train, train_loss))
    return train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict

# %%
import pickle
sizes = [10, 50, 250, 500, 950, 'Full']

Model_Data = pickle.load(open('Training_Data_Index.pkl', 'rb'))

Val_dataset = ArrowOfTime(root_dir, sample_key[val_idx], Y_mask[val_idx], Y_true[val_idx])
Val_loader = torch.utils.data.DataLoader(dataset = Val_dataset, 
                                              batch_size = BATCH_SIZE,
                                              shuffle = False,
                                        collate_fn = my_collate)

results_dict = {}

for i in range(len(sizes)):
    if sizes[i] != 'Full':
        sample_key_train = Model_Data[i]
        idx_train_new = np.isin(sample_key, sample_key_train)
        Y_mask_train = Y_mask[idx_train_new]
        label_train = Y_true[idx_train_new]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train_new], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)
    else:
        Y_mask_train = Y_mask[train_idx]
        label_train = Y_true[train_idx]
        Train_dataset = ArrowOfTime(root_dir, sample_key[train_idx], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)

    
    weights = torch.load('/beegfs/sc6957/capstone/models/20191123/resnet_jigsaw_10_large_best_model.pth')['modelStateDict']
    reqd_wts = {key[7:]:val for key, val in weights.items()}
    model = models.resnet18(num_classes=2)
    model.load_state_dict(reqd_wts)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 20)
    model.avgpool = nn.AdaptiveAvgPool2d((1, 1))
    model = model.to(device)
    learning_rate = 10**(-5)
    num_epochs = 50 # number epoch to train

    optimizer = torch.optim.Adam([param for param in model.parameters() if param.requires_grad == True], lr=learning_rate, weight_decay = 0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=2, verbose=True, threshold=0.03,
                                                           threshold_mode='abs', cooldown=0, min_lr=0, eps=1e-08)

    train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict = train_model(Train_loader, Val_loader, model, optimizer, scheduler, num_epochs)
    results_dict[sizes[i]] = {
        'train_acc_list':train_acc_list,
        'train_loss_list': train_loss_list,
        'val_acc_list': val_acc_list,
        'val_loss_list': val_loss_list,
        'best_model_state_dict': best_model_state_dict
    }
pickle.dump(results_dict, open('/scratch/rc3620/Capstone/Size_Exp_resnet_Jigsaw_Wt_Results.pkl','wb'))
# Out:
# Epoch:1
# Validation Accuracy:47.96, Validation F1:0.48, Val Loss: 0.44771
# Training Acc: 46.62, Training F1:0.47, Train Loss: 0.47867
# Epoch:2
# Validation Accuracy:49.81, Validation F1:0.50, Val Loss: 0.43861
# Training Acc: 49.10, Training F1:0.49, Train Loss: 0.44988
# Epoch:3
# Validation Accuracy:51.56, Validation F1:0.52, Val Loss: 0.43813
# Training Acc: 51.58, Training F1:0.52, Train Loss: 0.44206
# Epoch:4
# Validation Accuracy:52.17, Validation F1:0.52, Val Loss: 0.43533
# Training Acc: 54.95, Training F1:0.55, Train Loss: 0.43864
# Epoch:5
# Validation Accuracy:52.39, Validation F1:0.52, Val Loss: 0.43586
# Training Acc: 59.91, Training F1:0.60, Train Loss: 0.41483
# Epoch:6
# Validation Accuracy:52.43, Validation F1:0.52, Val Loss: 0.44007
# Training Acc: 65.32, Training F1:0.65, Train Loss: 0.38039
# Epoch:7
# Validation Accuracy:52.56, Validation F1:0.53, Val Loss: 0.43757
# Training Acc: 71.17, Training F1:0.71, Train Loss: 0.36057
# Epoch:8
# Validation Accuracy:52.73, Validation F1:0.53, Val Loss: 0.43808
# Training Acc: 74.77, Training F1:0.75, Train Loss: 0.33420
# Epoch:9
# Validation Accuracy:53.09, Validation F1:0.53, Val Loss: 0.43552
# Training Acc: 79.95, Training F1:0.80, Train Loss: 0.29905
# Epoch:10
# Validation Accuracy:53.28, Validation F1:0.53, Val Loss: 0.43232
# Training Acc: 83.56, Training F1:0.84, Train Loss: 0.29576
# Epoch:11
# Validation Accuracy:53.91, Validation F1:0.54, Val Loss: 0.43350
# Training Acc: 86.94, Training F1:0.87, Train Loss: 0.26850
# Epoch:12
# Validation Accuracy:54.29, Validation F1:0.54, Val Loss: 0.43122
# Training Acc: 88.96, Training F1:0.89, Train Loss: 0.26865
# Epoch:13
# Validation Accuracy:54.64, Validation F1:0.55, Val Loss: 0.43416
# Training Acc: 91.44, Training F1:0.91, Train Loss: 0.24949
# Epoch:14
# Validation Accuracy:54.71, Validation F1:0.55, Val Loss: 0.43069
# Training Acc: 93.24, Training F1:0.93, Train Loss: 0.24059
# Epoch:15
# Validation Accuracy:55.07, Validation F1:0.55, Val Loss: 0.42655
# Training Acc: 95.27, Training F1:0.95, Train Loss: 0.23740
# Epoch:16
# Validation Accuracy:55.35, Validation F1:0.55, Val Loss: 0.42956
# Training Acc: 96.17, Training F1:0.96, Train Loss: 0.21466
# Epoch:17
# Validation Accuracy:55.58, Validation F1:0.56, Val Loss: 0.42977
# Training Acc: 96.85, Training F1:0.97, Train Loss: 0.20627
# Epoch:18
# Validation Accuracy:55.87, Validation F1:0.56, Val Loss: 0.42108
# Training Acc: 97.75, Training F1:0.98, Train Loss: 0.19270
# Epoch:19
# Validation Accuracy:56.18, Validation F1:0.56, Val Loss: 0.42282
# Training Acc: 98.42, Training F1:0.98, Train Loss: 0.18162
# Epoch:20
# Validation Accuracy:56.44, Validation F1:0.56, Val Loss: 0.42569
# Training Acc: 98.65, Training F1:0.99, Train Loss: 0.18165
# Epoch:21
# Validation Accuracy:56.73, Validation F1:0.57, Val Loss: 0.42573
# Training Acc: 98.65, Training F1:0.99, Train Loss: 0.16605
# Epoch:22
# Validation Accuracy:56.75, Validation F1:0.57, Val Loss: 0.41994
# Training Acc: 98.65, Training F1:0.99, Train Loss: 0.15074
# Epoch:23
# Validation Accuracy:56.92, Validation F1:0.57, Val Loss: 0.42209
# Training Acc: 99.55, Training F1:1.00, Train Loss: 0.14832
# Epoch:24
# Validation Accuracy:56.92, Validation F1:0.57, Val Loss: 0.42172
# Training Acc: 99.55, Training F1:1.00, Train Loss: 0.14161
# Epoch:25
# Validation Accuracy:57.15, Validation F1:0.57, Val Loss: 0.42130
# Training Acc: 99.77, Training F1:1.00, Train Loss: 0.12801
# Epoch:26
# Validation Accuracy:57.29, Validation F1:0.57, Val Loss: 0.42212
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.12567
# Epoch:27
# Validation Accuracy:57.40, Validation F1:0.57, Val Loss: 0.42451
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.12179
# Epoch:28
# Validation Accuracy:57.09, Validation F1:0.57, Val Loss: 0.41938
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.11539
# Epoch:29
# Validation Accuracy:57.44, Validation F1:0.57, Val Loss: 0.41993
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.10887
# Epoch:30
# Validation Accuracy:57.74, Validation F1:0.58, Val Loss: 0.41701
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.09928
# Epoch:31
# Validation Accuracy:57.81, Validation F1:0.58, Val Loss: 0.41976
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.09782
# Epoch:32
# Validation Accuracy:57.61, Validation F1:0.58, Val Loss: 0.41883
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08868
# Epoch:33
# Validation Accuracy:57.64, Validation F1:0.58, Val Loss: 0.41691
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.09029
# Epoch    33: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:34
# Validation Accuracy:57.72, Validation F1:0.58, Val Loss: 0.41366
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08619
# Epoch:35
# Validation Accuracy:57.92, Validation F1:0.58, Val Loss: 0.41470
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08259
# Epoch:36
# Validation Accuracy:57.75, Validation F1:0.58, Val Loss: 0.41980
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08436
# Epoch:37
# Validation Accuracy:57.78, Validation F1:0.58, Val Loss: 0.41319
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08056
# Epoch    37: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:38
# Validation Accuracy:57.81, Validation F1:0.58, Val Loss: 0.41677
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07736
# Epoch:39
# Validation Accuracy:57.87, Validation F1:0.58, Val Loss: 0.42131
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08015
# Epoch:40
# Validation Accuracy:57.49, Validation F1:0.57, Val Loss: 0.41990
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08237
# Epoch    40: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:41
# Validation Accuracy:57.59, Validation F1:0.58, Val Loss: 0.41591
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08083
# Epoch:42
# Validation Accuracy:57.67, Validation F1:0.58, Val Loss: 0.41816
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08215
# Epoch:43
# Validation Accuracy:57.73, Validation F1:0.58, Val Loss: 0.42239
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08049
# Epoch:44
# Validation Accuracy:58.13, Validation F1:0.58, Val Loss: 0.41825
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08329
# Epoch:45
# Validation Accuracy:58.02, Validation F1:0.58, Val Loss: 0.41911
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07816
# Epoch:46
# Validation Accuracy:58.17, Validation F1:0.58, Val Loss: 0.41760
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08121
# Epoch:47
# Validation Accuracy:57.99, Validation F1:0.58, Val Loss: 0.41408
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07924
# Epoch:48
# Validation Accuracy:57.85, Validation F1:0.58, Val Loss: 0.41855
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08112
# Epoch:49
# Validation Accuracy:57.88, Validation F1:0.58, Val Loss: 0.42425
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08066
# Epoch:50
# Validation Accuracy:57.87, Validation F1:0.58, Val Loss: 0.41994
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08041
# Epoch:1
# Validation Accuracy:50.98, Validation F1:0.51, Val Loss: 0.42763
# Training Acc: 53.91, Training F1:0.54, Train Loss: 0.43246
# Epoch:2
# Validation Accuracy:55.21, Validation F1:0.55, Val Loss: 0.41400
# Training Acc: 64.11, Training F1:0.64, Train Loss: 0.38008
# Epoch:3
# Validation Accuracy:57.55, Validation F1:0.58, Val Loss: 0.40568
# Training Acc: 70.92, Training F1:0.71, Train Loss: 0.35816
# Epoch:4
# Validation Accuracy:59.26, Validation F1:0.59, Val Loss: 0.40086
# Training Acc: 75.36, Training F1:0.75, Train Loss: 0.33638
# Epoch:5
# Validation Accuracy:60.90, Validation F1:0.61, Val Loss: 0.39611
# Training Acc: 80.87, Training F1:0.81, Train Loss: 0.31383
# Epoch:6
# Validation Accuracy:61.83, Validation F1:0.62, Val Loss: 0.38512
# Training Acc: 84.25, Training F1:0.84, Train Loss: 0.29322
# Epoch:7
# Validation Accuracy:62.70, Validation F1:0.63, Val Loss: 0.38650
# Training Acc: 87.49, Training F1:0.87, Train Loss: 0.27533
# Epoch:8
# Validation Accuracy:63.65, Validation F1:0.64, Val Loss: 0.37842
# Training Acc: 89.71, Training F1:0.90, Train Loss: 0.25805
# Epoch:9
# Validation Accuracy:64.41, Validation F1:0.64, Val Loss: 0.37383
# Training Acc: 92.17, Training F1:0.92, Train Loss: 0.23553
# Epoch:10
# Validation Accuracy:64.77, Validation F1:0.65, Val Loss: 0.37012
# Training Acc: 93.77, Training F1:0.94, Train Loss: 0.21559
# Epoch:11
# Validation Accuracy:65.62, Validation F1:0.66, Val Loss: 0.36417
# Training Acc: 95.60, Training F1:0.96, Train Loss: 0.20439
# Epoch:12
# Validation Accuracy:65.98, Validation F1:0.66, Val Loss: 0.36499
# Training Acc: 97.10, Training F1:0.97, Train Loss: 0.18583
# Epoch:13
# Validation Accuracy:66.03, Validation F1:0.66, Val Loss: 0.36635
# Training Acc: 97.63, Training F1:0.98, Train Loss: 0.17573
# Epoch:14
# Validation Accuracy:66.96, Validation F1:0.67, Val Loss: 0.36138
# Training Acc: 98.16, Training F1:0.98, Train Loss: 0.15833
# Epoch:15
# Validation Accuracy:66.76, Validation F1:0.67, Val Loss: 0.35867
# Training Acc: 98.70, Training F1:0.99, Train Loss: 0.14799
# Epoch:16
# Validation Accuracy:67.44, Validation F1:0.67, Val Loss: 0.35484
# Training Acc: 98.94, Training F1:0.99, Train Loss: 0.13481
# Epoch:17
# Validation Accuracy:67.57, Validation F1:0.68, Val Loss: 0.35359
# Training Acc: 99.23, Training F1:0.99, Train Loss: 0.12215
# Epoch:18
# Validation Accuracy:67.95, Validation F1:0.68, Val Loss: 0.35141
# Training Acc: 99.47, Training F1:0.99, Train Loss: 0.10985
# Epoch:19
# Validation Accuracy:67.87, Validation F1:0.68, Val Loss: 0.35510
# Training Acc: 99.52, Training F1:1.00, Train Loss: 0.10351
# Epoch:20
# Validation Accuracy:68.28, Validation F1:0.68, Val Loss: 0.35273
# Training Acc: 99.57, Training F1:1.00, Train Loss: 0.09685
# Epoch:21
# Validation Accuracy:68.31, Validation F1:0.68, Val Loss: 0.35002
# Training Acc: 99.71, Training F1:1.00, Train Loss: 0.08414
# Epoch:22
# Validation Accuracy:68.11, Validation F1:0.68, Val Loss: 0.35322
# Training Acc: 99.81, Training F1:1.00, Train Loss: 0.07560
# Epoch    22: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:23
# Validation Accuracy:68.13, Validation F1:0.68, Val Loss: 0.35666
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07166
# Epoch:24
# Validation Accuracy:67.92, Validation F1:0.68, Val Loss: 0.34946
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07339
# Epoch:25
# Validation Accuracy:68.37, Validation F1:0.68, Val Loss: 0.35177
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.07110
# Epoch:26
# Validation Accuracy:68.19, Validation F1:0.68, Val Loss: 0.35176
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06915
# Epoch:27
# Validation Accuracy:68.14, Validation F1:0.68, Val Loss: 0.35298
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07039
# Epoch    27: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:28
# Validation Accuracy:68.20, Validation F1:0.68, Val Loss: 0.34821
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.06898
# Epoch:29
# Validation Accuracy:68.48, Validation F1:0.68, Val Loss: 0.35056
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06770
# Epoch:30
# Validation Accuracy:68.78, Validation F1:0.69, Val Loss: 0.34822
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06872
# Epoch:31
# Validation Accuracy:68.40, Validation F1:0.68, Val Loss: 0.35271
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06879
# Epoch:32
# Validation Accuracy:68.48, Validation F1:0.68, Val Loss: 0.35300
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06863
# Epoch    32: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:33
# Validation Accuracy:68.52, Validation F1:0.69, Val Loss: 0.34994
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06683
# Epoch:34
# Validation Accuracy:68.45, Validation F1:0.68, Val Loss: 0.35023
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06736
# Epoch:35
# Validation Accuracy:67.92, Validation F1:0.68, Val Loss: 0.35387
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.06683
# Epoch:36
# Validation Accuracy:68.25, Validation F1:0.68, Val Loss: 0.35249
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06632
# Epoch:37
# Validation Accuracy:68.62, Validation F1:0.69, Val Loss: 0.35359
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06735
# Epoch:38
# Validation Accuracy:68.37, Validation F1:0.68, Val Loss: 0.34738
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06663
# Epoch:39
# Validation Accuracy:68.26, Validation F1:0.68, Val Loss: 0.35055
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06888
# Epoch:40
# Validation Accuracy:68.17, Validation F1:0.68, Val Loss: 0.35092
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.06699
# Epoch:41
# Validation Accuracy:68.46, Validation F1:0.68, Val Loss: 0.35032
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06851
# Epoch:42
# Validation Accuracy:68.24, Validation F1:0.68, Val Loss: 0.35150
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06676
# Epoch:43
# Validation Accuracy:68.34, Validation F1:0.68, Val Loss: 0.34981
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06944
# Epoch:44
# Validation Accuracy:68.21, Validation F1:0.68, Val Loss: 0.34780
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06819
# Epoch:45
# Validation Accuracy:68.15, Validation F1:0.68, Val Loss: 0.35024
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06844
# Epoch:46
# Validation Accuracy:68.39, Validation F1:0.68, Val Loss: 0.34993
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06777
# Epoch:47
# Validation Accuracy:68.46, Validation F1:0.68, Val Loss: 0.34871
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06737
# Epoch:48
# Validation Accuracy:68.11, Validation F1:0.68, Val Loss: 0.35210
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06665
# Epoch:49
# Validation Accuracy:68.45, Validation F1:0.68, Val Loss: 0.34887
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06806
# Epoch:50
# Validation Accuracy:68.58, Validation F1:0.69, Val Loss: 0.34908
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06679
# Epoch:1
# Validation Accuracy:61.06, Validation F1:0.61, Val Loss: 0.39097
# Training Acc: 65.41, Training F1:0.65, Train Loss: 0.37875
# Epoch:2
# Validation Accuracy:68.20, Validation F1:0.68, Val Loss: 0.35967
# Training Acc: 73.96, Training F1:0.74, Train Loss: 0.33061
# Epoch:3
# Validation Accuracy:71.26, Validation F1:0.71, Val Loss: 0.34313
# Training Acc: 78.83, Training F1:0.79, Train Loss: 0.29495
# Epoch:4
# Validation Accuracy:72.78, Validation F1:0.73, Val Loss: 0.32280
# Training Acc: 82.52, Training F1:0.83, Train Loss: 0.26809
# Epoch:5
# Validation Accuracy:73.91, Validation F1:0.74, Val Loss: 0.31285
# Training Acc: 85.27, Training F1:0.85, Train Loss: 0.23850
# Epoch:6
# Validation Accuracy:74.98, Validation F1:0.75, Val Loss: 0.30277
# Training Acc: 87.58, Training F1:0.88, Train Loss: 0.21255
# Epoch:7
# Validation Accuracy:76.41, Validation F1:0.76, Val Loss: 0.29649
# Training Acc: 90.49, Training F1:0.90, Train Loss: 0.18938
# Epoch:8
# Validation Accuracy:76.81, Validation F1:0.77, Val Loss: 0.29163
# Training Acc: 92.92, Training F1:0.93, Train Loss: 0.16791
# Epoch:9
# Validation Accuracy:77.43, Validation F1:0.77, Val Loss: 0.28193
# Training Acc: 94.53, Training F1:0.95, Train Loss: 0.14574
# Epoch:10
# Validation Accuracy:78.06, Validation F1:0.78, Val Loss: 0.28375
# Training Acc: 96.15, Training F1:0.96, Train Loss: 0.12889
# Epoch:11
# Validation Accuracy:78.09, Validation F1:0.78, Val Loss: 0.27749
# Training Acc: 97.71, Training F1:0.98, Train Loss: 0.11335
# Epoch:12
# Validation Accuracy:78.42, Validation F1:0.78, Val Loss: 0.27345
# Training Acc: 98.42, Training F1:0.98, Train Loss: 0.09616
# Epoch:13
# Validation Accuracy:78.34, Validation F1:0.78, Val Loss: 0.27434
# Training Acc: 99.12, Training F1:0.99, Train Loss: 0.08376
# Epoch:14
# Validation Accuracy:78.79, Validation F1:0.79, Val Loss: 0.26720
# Training Acc: 99.45, Training F1:0.99, Train Loss: 0.07167
# Epoch:15
# Validation Accuracy:78.89, Validation F1:0.79, Val Loss: 0.27316
# Training Acc: 99.69, Training F1:1.00, Train Loss: 0.06110
# Epoch:16
# Validation Accuracy:78.72, Validation F1:0.79, Val Loss: 0.26520
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.05080
# Epoch:17
# Validation Accuracy:79.00, Validation F1:0.79, Val Loss: 0.27063
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.04384
# Epoch:18
# Validation Accuracy:78.84, Validation F1:0.79, Val Loss: 0.26946
# Training Acc: 99.96, Training F1:1.00, Train Loss: 0.03907
# Epoch:19
# Validation Accuracy:78.90, Validation F1:0.79, Val Loss: 0.26660
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.03320
# Epoch    19: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:20
# Validation Accuracy:78.92, Validation F1:0.79, Val Loss: 0.26499
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02847
# Epoch:21
# Validation Accuracy:79.00, Validation F1:0.79, Val Loss: 0.27383
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02715
# Epoch:22
# Validation Accuracy:78.82, Validation F1:0.79, Val Loss: 0.26303
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02672
# Epoch:23
# Validation Accuracy:79.03, Validation F1:0.79, Val Loss: 0.26985
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.02690
# Epoch:24
# Validation Accuracy:78.95, Validation F1:0.79, Val Loss: 0.27245
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02773
# Epoch:25
# Validation Accuracy:78.80, Validation F1:0.79, Val Loss: 0.27275
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02624
# Epoch    25: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:26
# Validation Accuracy:78.89, Validation F1:0.79, Val Loss: 0.26972
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02585
# Epoch:27
# Validation Accuracy:79.02, Validation F1:0.79, Val Loss: 0.27370
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02497
# Epoch:28
# Validation Accuracy:79.14, Validation F1:0.79, Val Loss: 0.26787
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02439
# Epoch:29
# Validation Accuracy:79.08, Validation F1:0.79, Val Loss: 0.27188
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02490
# Epoch:30
# Validation Accuracy:79.00, Validation F1:0.79, Val Loss: 0.26935
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02568
# Epoch    30: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:31
# Validation Accuracy:78.74, Validation F1:0.79, Val Loss: 0.26701
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02559
# Epoch:32
# Validation Accuracy:78.86, Validation F1:0.79, Val Loss: 0.26540
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02539
# Epoch:33
# Validation Accuracy:79.13, Validation F1:0.79, Val Loss: 0.26832
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02539
# Epoch:34
# Validation Accuracy:79.01, Validation F1:0.79, Val Loss: 0.26488
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02457
# Epoch:35
# Validation Accuracy:78.85, Validation F1:0.79, Val Loss: 0.27020
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02576
# Epoch:36
# Validation Accuracy:78.88, Validation F1:0.79, Val Loss: 0.26437
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02495
# Epoch:37
# Validation Accuracy:79.04, Validation F1:0.79, Val Loss: 0.26516
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02584
# Epoch:38
# Validation Accuracy:78.86, Validation F1:0.79, Val Loss: 0.27025
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02522
# Epoch:39
# Validation Accuracy:78.90, Validation F1:0.79, Val Loss: 0.26702
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02554
# Epoch:40
# Validation Accuracy:79.03, Validation F1:0.79, Val Loss: 0.26878
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02434
# Epoch:41
# Validation Accuracy:79.08, Validation F1:0.79, Val Loss: 0.27004
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02472
# Epoch:42
# Validation Accuracy:79.03, Validation F1:0.79, Val Loss: 0.26398
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02422
# Epoch:43
# Validation Accuracy:78.95, Validation F1:0.79, Val Loss: 0.26973
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02513
# Epoch:44
# Validation Accuracy:78.97, Validation F1:0.79, Val Loss: 0.27297
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02486
# Epoch:45
# Validation Accuracy:78.94, Validation F1:0.79, Val Loss: 0.26533
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02552
# Epoch:46
# Validation Accuracy:78.98, Validation F1:0.79, Val Loss: 0.26777
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02429
# Epoch:47
# Validation Accuracy:78.79, Validation F1:0.79, Val Loss: 0.26658
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02461
# Epoch:48
# Validation Accuracy:78.86, Validation F1:0.79, Val Loss: 0.26664
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02532
# Epoch:49
# Validation Accuracy:79.03, Validation F1:0.79, Val Loss: 0.27049
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02570
# Epoch:50
# Validation Accuracy:78.88, Validation F1:0.79, Val Loss: 0.26753
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02528
# Epoch:1
# Validation Accuracy:68.89, Validation F1:0.69, Val Loss: 0.35637
# Training Acc: 71.76, Training F1:0.72, Train Loss: 0.34006
# Epoch:2
# Validation Accuracy:73.53, Validation F1:0.74, Val Loss: 0.31356
# Training Acc: 78.42, Training F1:0.78, Train Loss: 0.28797
# Epoch:3
# Validation Accuracy:75.73, Validation F1:0.76, Val Loss: 0.29345
# Training Acc: 82.29, Training F1:0.82, Train Loss: 0.25028
# Epoch:4
# Validation Accuracy:77.57, Validation F1:0.78, Val Loss: 0.27806
# Training Acc: 86.37, Training F1:0.86, Train Loss: 0.21613
# Epoch:5
# Validation Accuracy:79.50, Validation F1:0.80, Val Loss: 0.26570
# Training Acc: 89.40, Training F1:0.89, Train Loss: 0.18901
# Epoch:6
# Validation Accuracy:80.61, Validation F1:0.81, Val Loss: 0.25366
# Training Acc: 92.12, Training F1:0.92, Train Loss: 0.15961
# Epoch:7
# Validation Accuracy:81.53, Validation F1:0.82, Val Loss: 0.24458
# Training Acc: 94.27, Training F1:0.94, Train Loss: 0.13671
# Epoch:8
# Validation Accuracy:82.41, Validation F1:0.82, Val Loss: 0.23883
# Training Acc: 95.98, Training F1:0.96, Train Loss: 0.11422
# Epoch:9
# Validation Accuracy:82.77, Validation F1:0.83, Val Loss: 0.22987
# Training Acc: 97.43, Training F1:0.97, Train Loss: 0.09521
# Epoch:10
# Validation Accuracy:83.53, Validation F1:0.84, Val Loss: 0.22143
# Training Acc: 98.32, Training F1:0.98, Train Loss: 0.07855
# Epoch:11
# Validation Accuracy:83.67, Validation F1:0.84, Val Loss: 0.22418
# Training Acc: 98.96, Training F1:0.99, Train Loss: 0.06658
# Epoch:12
# Validation Accuracy:83.75, Validation F1:0.84, Val Loss: 0.22174
# Training Acc: 99.47, Training F1:0.99, Train Loss: 0.05321
# Epoch:13
# Validation Accuracy:84.01, Validation F1:0.84, Val Loss: 0.21401
# Training Acc: 99.73, Training F1:1.00, Train Loss: 0.04318
# Epoch:14
# Validation Accuracy:84.08, Validation F1:0.84, Val Loss: 0.21765
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.03419
# Epoch:15
# Validation Accuracy:83.99, Validation F1:0.84, Val Loss: 0.21392
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.02817
# Epoch:16
# Validation Accuracy:83.81, Validation F1:0.84, Val Loss: 0.21534
# Training Acc: 99.96, Training F1:1.00, Train Loss: 0.02263
# Epoch    16: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:17
# Validation Accuracy:83.85, Validation F1:0.84, Val Loss: 0.21461
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.01847
# Epoch:18
# Validation Accuracy:83.71, Validation F1:0.84, Val Loss: 0.21670
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01844
# Epoch:19
# Validation Accuracy:83.79, Validation F1:0.84, Val Loss: 0.22033
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01763
# Epoch    19: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:20
# Validation Accuracy:83.88, Validation F1:0.84, Val Loss: 0.22120
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01701
# Epoch:21
# Validation Accuracy:83.89, Validation F1:0.84, Val Loss: 0.21821
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01699
# Epoch:22
# Validation Accuracy:83.81, Validation F1:0.84, Val Loss: 0.21337
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01744
# Epoch    22: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:23
# Validation Accuracy:83.98, Validation F1:0.84, Val Loss: 0.21972
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01708
# Epoch:24
# Validation Accuracy:83.83, Validation F1:0.84, Val Loss: 0.21634
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01663
# Epoch:25
# Validation Accuracy:83.73, Validation F1:0.84, Val Loss: 0.21837
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01713
# Epoch:26
# Validation Accuracy:83.82, Validation F1:0.84, Val Loss: 0.21615
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01708
# Epoch:27
# Validation Accuracy:84.05, Validation F1:0.84, Val Loss: 0.21644
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01687
# Epoch:28
# Validation Accuracy:83.92, Validation F1:0.84, Val Loss: 0.21750
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01740
# Epoch:29
# Validation Accuracy:83.67, Validation F1:0.84, Val Loss: 0.21921
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01681
# Epoch:30
# Validation Accuracy:83.83, Validation F1:0.84, Val Loss: 0.21679
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01686
# Epoch:31
# Validation Accuracy:83.86, Validation F1:0.84, Val Loss: 0.21886
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01713
# Epoch:32
# Validation Accuracy:83.89, Validation F1:0.84, Val Loss: 0.21963
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01708
# Epoch:33
# Validation Accuracy:83.75, Validation F1:0.84, Val Loss: 0.21773
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01699
# Epoch:34
# Validation Accuracy:84.01, Validation F1:0.84, Val Loss: 0.21289
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01703
# Epoch:35
# Validation Accuracy:83.94, Validation F1:0.84, Val Loss: 0.21912
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01713
# Epoch:36
# Validation Accuracy:83.92, Validation F1:0.84, Val Loss: 0.21518
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01652
# Epoch:37
# Validation Accuracy:83.92, Validation F1:0.84, Val Loss: 0.21552
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01682
# Epoch:38
# Validation Accuracy:83.85, Validation F1:0.84, Val Loss: 0.21850
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01702
# Epoch:39
# Validation Accuracy:83.85, Validation F1:0.84, Val Loss: 0.22305
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01649
# Epoch:40
# Validation Accuracy:83.70, Validation F1:0.84, Val Loss: 0.21557
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01672
# Epoch:41
# Validation Accuracy:83.82, Validation F1:0.84, Val Loss: 0.22062
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01681
# Epoch:42
# Validation Accuracy:83.80, Validation F1:0.84, Val Loss: 0.21485
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01717
# Epoch:43
# Validation Accuracy:84.14, Validation F1:0.84, Val Loss: 0.21592
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01683
# Epoch:44
# Validation Accuracy:83.97, Validation F1:0.84, Val Loss: 0.22086
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01690
# Epoch:45
# Validation Accuracy:83.88, Validation F1:0.84, Val Loss: 0.22111
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01689
# Epoch:46
# Validation Accuracy:83.81, Validation F1:0.84, Val Loss: 0.21669
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01692
# Epoch:47
# Validation Accuracy:84.03, Validation F1:0.84, Val Loss: 0.21696
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01663
# Epoch:48
# Validation Accuracy:83.87, Validation F1:0.84, Val Loss: 0.21285
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01668
# Epoch:49
# Validation Accuracy:83.89, Validation F1:0.84, Val Loss: 0.21341
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01669
# Epoch:50
# Validation Accuracy:83.91, Validation F1:0.84, Val Loss: 0.21862
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01712
# Epoch:1
# Validation Accuracy:73.30, Validation F1:0.73, Val Loss: 0.32260
# Training Acc: 75.04, Training F1:0.75, Train Loss: 0.30978
# Epoch:2
# Validation Accuracy:78.22, Validation F1:0.78, Val Loss: 0.27661
# Training Acc: 81.90, Training F1:0.82, Train Loss: 0.25196
# Epoch:3
# Validation Accuracy:81.73, Validation F1:0.82, Val Loss: 0.24842
# Training Acc: 87.29, Training F1:0.87, Train Loss: 0.20598
# Epoch:4
# Validation Accuracy:83.88, Validation F1:0.84, Val Loss: 0.22822
# Training Acc: 91.46, Training F1:0.91, Train Loss: 0.16476
# Epoch:5
# Validation Accuracy:85.74, Validation F1:0.86, Val Loss: 0.20642
# Training Acc: 94.29, Training F1:0.94, Train Loss: 0.13157
# Epoch:6
# Validation Accuracy:86.91, Validation F1:0.87, Val Loss: 0.19437
# Training Acc: 96.23, Training F1:0.96, Train Loss: 0.10225
# Epoch:7
# Validation Accuracy:87.92, Validation F1:0.88, Val Loss: 0.18019
# Training Acc: 97.93, Training F1:0.98, Train Loss: 0.07843
# Epoch:8
# Validation Accuracy:88.78, Validation F1:0.89, Val Loss: 0.16814
# Training Acc: 98.76, Training F1:0.99, Train Loss: 0.06037
# Epoch:9
# Validation Accuracy:89.03, Validation F1:0.89, Val Loss: 0.16017
# Training Acc: 99.27, Training F1:0.99, Train Loss: 0.04484
# Epoch:10
# Validation Accuracy:89.55, Validation F1:0.90, Val Loss: 0.15637
# Training Acc: 99.67, Training F1:1.00, Train Loss: 0.03310
# Epoch:11
# Validation Accuracy:89.43, Validation F1:0.89, Val Loss: 0.15215
# Training Acc: 99.84, Training F1:1.00, Train Loss: 0.02607
# Epoch:12
# Validation Accuracy:89.85, Validation F1:0.90, Val Loss: 0.15069
# Training Acc: 99.93, Training F1:1.00, Train Loss: 0.01832
# Epoch:13
# Validation Accuracy:89.66, Validation F1:0.90, Val Loss: 0.14550
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.01393
# Epoch:14
# Validation Accuracy:89.87, Validation F1:0.90, Val Loss: 0.15172
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.00994
# Epoch    14: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:15
# Validation Accuracy:89.84, Validation F1:0.90, Val Loss: 0.15570
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00755
# Epoch:16
# Validation Accuracy:89.82, Validation F1:0.90, Val Loss: 0.15707
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00692
# Epoch:17
# Validation Accuracy:89.90, Validation F1:0.90, Val Loss: 0.15576
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00669
# Epoch:18
# Validation Accuracy:89.78, Validation F1:0.90, Val Loss: 0.14598
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00621
# Epoch:19
# Validation Accuracy:89.82, Validation F1:0.90, Val Loss: 0.15181
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00614
# Epoch    19: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:20
# Validation Accuracy:89.73, Validation F1:0.90, Val Loss: 0.15252
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00573
# Epoch:21
# Validation Accuracy:89.85, Validation F1:0.90, Val Loss: 0.15137
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00552
# Epoch:22
# Validation Accuracy:89.77, Validation F1:0.90, Val Loss: 0.14909
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00555
# Epoch    22: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:23
# Validation Accuracy:89.88, Validation F1:0.90, Val Loss: 0.15778
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00536
# Epoch:24
# Validation Accuracy:89.97, Validation F1:0.90, Val Loss: 0.15641
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00547
# Epoch:25
# Validation Accuracy:89.99, Validation F1:0.90, Val Loss: 0.15093
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00563
# Epoch:26
# Validation Accuracy:89.88, Validation F1:0.90, Val Loss: 0.16432
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00548
# Epoch:27
# Validation Accuracy:89.61, Validation F1:0.90, Val Loss: 0.15365
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00567
# Epoch:28
# Validation Accuracy:89.82, Validation F1:0.90, Val Loss: 0.15515
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00526
# Epoch:29
# Validation Accuracy:89.83, Validation F1:0.90, Val Loss: 0.15159
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00549
# Epoch:30
# Validation Accuracy:89.71, Validation F1:0.90, Val Loss: 0.15096
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00537
# Epoch:31
# Validation Accuracy:89.99, Validation F1:0.90, Val Loss: 0.15458
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00529
# Epoch:32
# Validation Accuracy:89.76, Validation F1:0.90, Val Loss: 0.15801
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00542
# Epoch:33
# Validation Accuracy:89.96, Validation F1:0.90, Val Loss: 0.14951
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00547
# Epoch:34
# Validation Accuracy:89.91, Validation F1:0.90, Val Loss: 0.15518
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00539
# Epoch:35
# Validation Accuracy:89.79, Validation F1:0.90, Val Loss: 0.15010
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00575
# Epoch:36
# Validation Accuracy:89.84, Validation F1:0.90, Val Loss: 0.15369
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00560
# Epoch:37
# Validation Accuracy:90.10, Validation F1:0.90, Val Loss: 0.15425
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00534
# Epoch:38
# Validation Accuracy:89.83, Validation F1:0.90, Val Loss: 0.15057
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00549
# Epoch:39
# Validation Accuracy:89.77, Validation F1:0.90, Val Loss: 0.15424
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00552
# Epoch:40
# Validation Accuracy:89.82, Validation F1:0.90, Val Loss: 0.15279
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00524
# Epoch:41
# Validation Accuracy:89.78, Validation F1:0.90, Val Loss: 0.14963
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00562
# Epoch:42
# Validation Accuracy:89.87, Validation F1:0.90, Val Loss: 0.15292
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00549
# Epoch:43
# Validation Accuracy:89.84, Validation F1:0.90, Val Loss: 0.14854
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00539
# Epoch:44
# Validation Accuracy:89.93, Validation F1:0.90, Val Loss: 0.15382
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00548
# Epoch:45
# Validation Accuracy:89.83, Validation F1:0.90, Val Loss: 0.14761
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00535
# Epoch:46
# Validation Accuracy:89.75, Validation F1:0.90, Val Loss: 0.15654
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00537
# Epoch:47
# Validation Accuracy:89.81, Validation F1:0.90, Val Loss: 0.15483
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00534
# Epoch:48
# Validation Accuracy:89.84, Validation F1:0.90, Val Loss: 0.14935
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00549
# Epoch:49
# Validation Accuracy:89.82, Validation F1:0.90, Val Loss: 0.15365
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00540
# Epoch:50
# Validation Accuracy:89.91, Validation F1:0.90, Val Loss: 0.15401
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.00539
# Epoch:1
# Validation Accuracy:70.00, Validation F1:0.70, Val Loss: 0.34627
# Training Acc: 72.38, Training F1:0.72, Train Loss: 0.33210
# Epoch:2
# Validation Accuracy:73.08, Validation F1:0.73, Val Loss: 0.32097
# Training Acc: 76.25, Training F1:0.76, Train Loss: 0.29279
# Epoch:3
# Validation Accuracy:73.72, Validation F1:0.74, Val Loss: 0.30345
# Training Acc: 79.11, Training F1:0.79, Train Loss: 0.26499
# Epoch:4
# Validation Accuracy:74.76, Validation F1:0.75, Val Loss: 0.29366
# Training Acc: 81.97, Training F1:0.82, Train Loss: 0.24089
# Epoch:5
# Validation Accuracy:75.24, Validation F1:0.75, Val Loss: 0.28806
# Training Acc: 84.07, Training F1:0.84, Train Loss: 0.21499
# Epoch:6
# Validation Accuracy:75.67, Validation F1:0.76, Val Loss: 0.28541
# Training Acc: 87.06, Training F1:0.87, Train Loss: 0.19367
# Epoch:7
# Validation Accuracy:75.44, Validation F1:0.75, Val Loss: 0.28170
# Training Acc: 89.95, Training F1:0.90, Train Loss: 0.17213
# Epoch:8
# Validation Accuracy:75.51, Validation F1:0.76, Val Loss: 0.28451
# Training Acc: 92.21, Training F1:0.92, Train Loss: 0.15273
# Epoch     8: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:9
# Validation Accuracy:75.49, Validation F1:0.75, Val Loss: 0.28194
# Training Acc: 94.08, Training F1:0.94, Train Loss: 0.13374
# Epoch:10
# Validation Accuracy:75.92, Validation F1:0.76, Val Loss: 0.28326
# Training Acc: 94.44, Training F1:0.94, Train Loss: 0.12801
# Epoch:11
# Validation Accuracy:75.67, Validation F1:0.76, Val Loss: 0.28348
# Training Acc: 94.68, Training F1:0.95, Train Loss: 0.12696
# Epoch:12
# Validation Accuracy:75.90, Validation F1:0.76, Val Loss: 0.28724
# Training Acc: 94.72, Training F1:0.95, Train Loss: 0.12318
# Epoch    12: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:13
# Validation Accuracy:75.73, Validation F1:0.76, Val Loss: 0.29056
# Training Acc: 95.17, Training F1:0.95, Train Loss: 0.12261
# Epoch:14
# Validation Accuracy:75.88, Validation F1:0.76, Val Loss: 0.28670
# Training Acc: 94.93, Training F1:0.95, Train Loss: 0.12103
# Epoch:15
# Validation Accuracy:75.63, Validation F1:0.76, Val Loss: 0.28270
# Training Acc: 95.22, Training F1:0.95, Train Loss: 0.12079
# Epoch:16
# Validation Accuracy:75.97, Validation F1:0.76, Val Loss: 0.28247
# Training Acc: 95.31, Training F1:0.95, Train Loss: 0.12110
# Epoch:17
# Validation Accuracy:75.74, Validation F1:0.76, Val Loss: 0.27976
# Training Acc: 95.20, Training F1:0.95, Train Loss: 0.12131
# Epoch:18
# Validation Accuracy:75.91, Validation F1:0.76, Val Loss: 0.28703
# Training Acc: 95.06, Training F1:0.95, Train Loss: 0.11916
# Epoch    18: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:19
# Validation Accuracy:75.87, Validation F1:0.76, Val Loss: 0.28362
# Training Acc: 95.24, Training F1:0.95, Train Loss: 0.12030
# Epoch:20
# Validation Accuracy:75.82, Validation F1:0.76, Val Loss: 0.28392
# Training Acc: 95.26, Training F1:0.95, Train Loss: 0.11964
# Epoch:21
# Validation Accuracy:75.59, Validation F1:0.76, Val Loss: 0.28612
# Training Acc: 95.15, Training F1:0.95, Train Loss: 0.12052
# Epoch:22
# Validation Accuracy:75.57, Validation F1:0.76, Val Loss: 0.28701
# Training Acc: 95.39, Training F1:0.95, Train Loss: 0.11981
# Epoch:23
# Validation Accuracy:75.57, Validation F1:0.76, Val Loss: 0.28623
# Training Acc: 95.38, Training F1:0.95, Train Loss: 0.11987
# Epoch:24
# Validation Accuracy:75.70, Validation F1:0.76, Val Loss: 0.28437
# Training Acc: 95.22, Training F1:0.95, Train Loss: 0.12084
# Epoch:25
# Validation Accuracy:75.68, Validation F1:0.76, Val Loss: 0.28742
# Training Acc: 95.30, Training F1:0.95, Train Loss: 0.11932
# Epoch:26
# Validation Accuracy:75.57, Validation F1:0.76, Val Loss: 0.28467
# Training Acc: 95.36, Training F1:0.95, Train Loss: 0.11907
# Epoch:27
# Validation Accuracy:75.87, Validation F1:0.76, Val Loss: 0.28577
# Training Acc: 95.10, Training F1:0.95, Train Loss: 0.11904
# Epoch:28
# Validation Accuracy:75.78, Validation F1:0.76, Val Loss: 0.28374
# Training Acc: 95.24, Training F1:0.95, Train Loss: 0.12019
# Epoch:29
# Validation Accuracy:75.92, Validation F1:0.76, Val Loss: 0.29052
# Training Acc: 95.26, Training F1:0.95, Train Loss: 0.11977
# Epoch:30
# Validation Accuracy:75.75, Validation F1:0.76, Val Loss: 0.28365
# Training Acc: 95.17, Training F1:0.95, Train Loss: 0.12081
# Epoch:31
# Validation Accuracy:75.68, Validation F1:0.76, Val Loss: 0.28845
# Training Acc: 95.37, Training F1:0.95, Train Loss: 0.11950
# Epoch:32
# Validation Accuracy:75.57, Validation F1:0.76, Val Loss: 0.28736
# Training Acc: 95.31, Training F1:0.95, Train Loss: 0.11995
# Epoch:33
# Validation Accuracy:75.67, Validation F1:0.76, Val Loss: 0.28473
# Training Acc: 95.29, Training F1:0.95, Train Loss: 0.12074
# Epoch:34
# Validation Accuracy:75.64, Validation F1:0.76, Val Loss: 0.28588
# Training Acc: 95.27, Training F1:0.95, Train Loss: 0.11789
# Epoch:35
# Validation Accuracy:75.79, Validation F1:0.76, Val Loss: 0.28438
# Training Acc: 95.35, Training F1:0.95, Train Loss: 0.11909
# Epoch:36
# Validation Accuracy:75.78, Validation F1:0.76, Val Loss: 0.28272
# Training Acc: 95.27, Training F1:0.95, Train Loss: 0.12084
# Epoch:37
# Validation Accuracy:75.91, Validation F1:0.76, Val Loss: 0.28500
# Training Acc: 95.24, Training F1:0.95, Train Loss: 0.11857
# Epoch:38
# Validation Accuracy:75.49, Validation F1:0.75, Val Loss: 0.28455
# Training Acc: 95.39, Training F1:0.95, Train Loss: 0.12094
# Epoch:39
# Validation Accuracy:75.75, Validation F1:0.76, Val Loss: 0.28522
# Training Acc: 95.22, Training F1:0.95, Train Loss: 0.12006
# Epoch:40
# Validation Accuracy:75.81, Validation F1:0.76, Val Loss: 0.28088
# Training Acc: 95.19, Training F1:0.95, Train Loss: 0.11989
# Epoch:41
# Validation Accuracy:75.78, Validation F1:0.76, Val Loss: 0.28202
# Training Acc: 95.32, Training F1:0.95, Train Loss: 0.12005
# Epoch:42
# Validation Accuracy:75.78, Validation F1:0.76, Val Loss: 0.28591
# Training Acc: 95.46, Training F1:0.95, Train Loss: 0.11868
# Epoch:43
# Validation Accuracy:75.71, Validation F1:0.76, Val Loss: 0.28315
# Training Acc: 95.32, Training F1:0.95, Train Loss: 0.11881
# Epoch:44
# Validation Accuracy:75.56, Validation F1:0.76, Val Loss: 0.28405
# Training Acc: 95.29, Training F1:0.95, Train Loss: 0.11850
# Epoch:45
# Validation Accuracy:75.67, Validation F1:0.76, Val Loss: 0.28689
# Training Acc: 95.39, Training F1:0.95, Train Loss: 0.11941
# Epoch:46
# Validation Accuracy:75.56, Validation F1:0.76, Val Loss: 0.28649
# Training Acc: 95.37, Training F1:0.95, Train Loss: 0.11998
# Epoch:47
# Validation Accuracy:75.49, Validation F1:0.75, Val Loss: 0.28510
# Training Acc: 95.26, Training F1:0.95, Train Loss: 0.12064
# Epoch:48
# Validation Accuracy:75.67, Validation F1:0.76, Val Loss: 0.28274
# Training Acc: 95.32, Training F1:0.95, Train Loss: 0.11926
# Epoch:49
# Validation Accuracy:75.85, Validation F1:0.76, Val Loss: 0.28486
# Training Acc: 95.35, Training F1:0.95, Train Loss: 0.12087
# Epoch:50
# Validation Accuracy:75.67, Validation F1:0.76, Val Loss: 0.28739
# Training Acc: 95.18, Training F1:0.95, Train Loss: 0.11866

# %%
results_dict = {}
model1 = models.resnet18(num_classes=20).to(device)
model = models.resnet18(num_classes=20).to(device)
model.avgpool = nn.AdaptiveAvgPool2d((1, 1))
for i in range(len(sizes)):
    if sizes[i] != 'Full':
        sample_key_train = Model_Data[i]
        idx_train_new = np.isin(sample_key, sample_key_train)
        Y_mask_train = Y_mask[idx_train_new]
        label_train = Y_true[idx_train_new]
        Train_dataset = ArrowOfTime(root_dir, sample_key[idx_train_new], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)
    else:
        Y_mask_train = Y_mask[train_idx]
        label_train = Y_true[train_idx]
        Train_dataset = ArrowOfTime(root_dir, sample_key[train_idx], Y_mask_train, label_train)
        Train_loader = torch.utils.data.DataLoader(dataset = Train_dataset, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = True,
                                                  collate_fn = my_collate)

    
    model.load_state_dict(model1.state_dict())
    learning_rate = 10**(-5)
    num_epochs = 50 # number epoch to train

    optimizer = torch.optim.Adam([param for param in model.parameters() if param.requires_grad == True], lr=learning_rate, weight_decay = 0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=2, verbose=True, threshold=0.03,
                                                           threshold_mode='abs', cooldown=0, min_lr=0, eps=1e-08)

    train_acc_list, train_loss_list, val_acc_list, val_loss_list, best_model_state_dict = train_model(Train_loader, Val_loader, model, optimizer, scheduler, num_epochs)
    results_dict[sizes[i]] = {
        'train_acc_list':train_acc_list,
        'train_loss_list': train_loss_list,
        'val_acc_list': val_acc_list,
        'val_loss_list': val_loss_list,
        'best_model_state_dict': best_model_state_dict
    }
pickle.dump(results_dict, open('/scratch/rc3620/Capstone/Size_Exp_Random_Wt_Resnet_Results.pkl','wb'))
# Out:
# Epoch:1
# Validation Accuracy:50.40, Validation F1:0.50, Val Loss: 0.42198
# Training Acc: 53.15, Training F1:0.53, Train Loss: 0.45469
# Epoch:2
# Validation Accuracy:50.59, Validation F1:0.51, Val Loss: 0.42273
# Training Acc: 56.31, Training F1:0.56, Train Loss: 0.45277
# Epoch:3
# Validation Accuracy:51.94, Validation F1:0.52, Val Loss: 0.42340
# Training Acc: 57.21, Training F1:0.57, Train Loss: 0.43500
# Epoch:4
# Validation Accuracy:52.73, Validation F1:0.53, Val Loss: 0.41881
# Training Acc: 60.81, Training F1:0.61, Train Loss: 0.40633
# Epoch:5
# Validation Accuracy:53.46, Validation F1:0.53, Val Loss: 0.41948
# Training Acc: 67.12, Training F1:0.67, Train Loss: 0.39452
# Epoch:6
# Validation Accuracy:54.37, Validation F1:0.54, Val Loss: 0.42500
# Training Acc: 74.32, Training F1:0.74, Train Loss: 0.37350
# Epoch:7
# Validation Accuracy:54.84, Validation F1:0.55, Val Loss: 0.42309
# Training Acc: 78.38, Training F1:0.78, Train Loss: 0.34594
# Epoch:8
# Validation Accuracy:55.52, Validation F1:0.56, Val Loss: 0.41957
# Training Acc: 81.08, Training F1:0.81, Train Loss: 0.33139
# Epoch:9
# Validation Accuracy:55.80, Validation F1:0.56, Val Loss: 0.41742
# Training Acc: 84.46, Training F1:0.84, Train Loss: 0.32333
# Epoch:10
# Validation Accuracy:56.13, Validation F1:0.56, Val Loss: 0.41816
# Training Acc: 87.61, Training F1:0.88, Train Loss: 0.30028
# Epoch:11
# Validation Accuracy:56.50, Validation F1:0.56, Val Loss: 0.41548
# Training Acc: 91.22, Training F1:0.91, Train Loss: 0.28736
# Epoch:12
# Validation Accuracy:56.36, Validation F1:0.56, Val Loss: 0.41895
# Training Acc: 93.24, Training F1:0.93, Train Loss: 0.28353
# Epoch:13
# Validation Accuracy:56.87, Validation F1:0.57, Val Loss: 0.41591
# Training Acc: 94.82, Training F1:0.95, Train Loss: 0.27240
# Epoch:14
# Validation Accuracy:57.33, Validation F1:0.57, Val Loss: 0.41146
# Training Acc: 95.27, Training F1:0.95, Train Loss: 0.25777
# Epoch:15
# Validation Accuracy:57.65, Validation F1:0.58, Val Loss: 0.41097
# Training Acc: 95.27, Training F1:0.95, Train Loss: 0.25050
# Epoch:16
# Validation Accuracy:58.20, Validation F1:0.58, Val Loss: 0.41161
# Training Acc: 95.50, Training F1:0.95, Train Loss: 0.24144
# Epoch:17
# Validation Accuracy:58.20, Validation F1:0.58, Val Loss: 0.40852
# Training Acc: 96.17, Training F1:0.96, Train Loss: 0.23450
# Epoch:18
# Validation Accuracy:58.48, Validation F1:0.58, Val Loss: 0.40888
# Training Acc: 96.17, Training F1:0.96, Train Loss: 0.23020
# Epoch:19
# Validation Accuracy:58.60, Validation F1:0.59, Val Loss: 0.40840
# Training Acc: 96.62, Training F1:0.97, Train Loss: 0.20808
# Epoch:20
# Validation Accuracy:59.32, Validation F1:0.59, Val Loss: 0.40934
# Training Acc: 97.07, Training F1:0.97, Train Loss: 0.21194
# Epoch:21
# Validation Accuracy:59.85, Validation F1:0.60, Val Loss: 0.40441
# Training Acc: 97.75, Training F1:0.98, Train Loss: 0.19694
# Epoch:22
# Validation Accuracy:60.48, Validation F1:0.60, Val Loss: 0.40370
# Training Acc: 97.97, Training F1:0.98, Train Loss: 0.19992
# Epoch:23
# Validation Accuracy:60.79, Validation F1:0.61, Val Loss: 0.40101
# Training Acc: 98.20, Training F1:0.98, Train Loss: 0.19944
# Epoch:24
# Validation Accuracy:60.92, Validation F1:0.61, Val Loss: 0.40169
# Training Acc: 98.42, Training F1:0.98, Train Loss: 0.18687
# Epoch:25
# Validation Accuracy:61.19, Validation F1:0.61, Val Loss: 0.39963
# Training Acc: 98.65, Training F1:0.99, Train Loss: 0.17571
# Epoch:26
# Validation Accuracy:61.27, Validation F1:0.61, Val Loss: 0.40091
# Training Acc: 98.87, Training F1:0.99, Train Loss: 0.16774
# Epoch:27
# Validation Accuracy:61.61, Validation F1:0.62, Val Loss: 0.39784
# Training Acc: 99.10, Training F1:0.99, Train Loss: 0.16797
# Epoch:28
# Validation Accuracy:62.00, Validation F1:0.62, Val Loss: 0.39794
# Training Acc: 99.32, Training F1:0.99, Train Loss: 0.15524
# Epoch:29
# Validation Accuracy:62.34, Validation F1:0.62, Val Loss: 0.40179
# Training Acc: 99.32, Training F1:0.99, Train Loss: 0.15194
# Epoch:30
# Validation Accuracy:62.43, Validation F1:0.62, Val Loss: 0.39558
# Training Acc: 99.32, Training F1:0.99, Train Loss: 0.14928
# Epoch:31
# Validation Accuracy:62.72, Validation F1:0.63, Val Loss: 0.39510
# Training Acc: 99.77, Training F1:1.00, Train Loss: 0.14038
# Epoch:32
# Validation Accuracy:62.41, Validation F1:0.62, Val Loss: 0.39431
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.13593
# Epoch:33
# Validation Accuracy:62.82, Validation F1:0.63, Val Loss: 0.39307
# Training Acc: 99.77, Training F1:1.00, Train Loss: 0.13382
# Epoch:34
# Validation Accuracy:63.02, Validation F1:0.63, Val Loss: 0.39046
# Training Acc: 99.77, Training F1:1.00, Train Loss: 0.12844
# Epoch:35
# Validation Accuracy:62.91, Validation F1:0.63, Val Loss: 0.39554
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.12194
# Epoch:36
# Validation Accuracy:63.49, Validation F1:0.63, Val Loss: 0.39160
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.12259
# Epoch:37
# Validation Accuracy:63.47, Validation F1:0.63, Val Loss: 0.39125
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.11061
# Epoch:38
# Validation Accuracy:63.61, Validation F1:0.64, Val Loss: 0.39386
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.11142
# Epoch:39
# Validation Accuracy:63.39, Validation F1:0.63, Val Loss: 0.39348
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.10491
# Epoch:40
# Validation Accuracy:63.57, Validation F1:0.64, Val Loss: 0.39379
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.10176
# Epoch:41
# Validation Accuracy:64.08, Validation F1:0.64, Val Loss: 0.39009
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.09600
# Epoch:42
# Validation Accuracy:63.72, Validation F1:0.64, Val Loss: 0.39391
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.09806
# Epoch:43
# Validation Accuracy:63.81, Validation F1:0.64, Val Loss: 0.38852
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.09560
# Epoch    43: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:44
# Validation Accuracy:64.02, Validation F1:0.64, Val Loss: 0.39542
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08874
# Epoch:45
# Validation Accuracy:63.90, Validation F1:0.64, Val Loss: 0.39099
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08528
# Epoch:46
# Validation Accuracy:63.92, Validation F1:0.64, Val Loss: 0.39546
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08917
# Epoch    46: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:47
# Validation Accuracy:63.95, Validation F1:0.64, Val Loss: 0.38846
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08963
# Epoch:48
# Validation Accuracy:63.78, Validation F1:0.64, Val Loss: 0.39370
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08631
# Epoch:49
# Validation Accuracy:63.84, Validation F1:0.64, Val Loss: 0.39186
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08718
# Epoch    49: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:50
# Validation Accuracy:63.90, Validation F1:0.64, Val Loss: 0.39092
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.08616
# Epoch:1
# Validation Accuracy:54.51, Validation F1:0.55, Val Loss: 0.41641
# Training Acc: 57.10, Training F1:0.57, Train Loss: 0.41387
# Epoch:2
# Validation Accuracy:57.24, Validation F1:0.57, Val Loss: 0.41051
# Training Acc: 65.65, Training F1:0.66, Train Loss: 0.37985
# Epoch:3
# Validation Accuracy:59.48, Validation F1:0.59, Val Loss: 0.40363
# Training Acc: 72.32, Training F1:0.72, Train Loss: 0.35960
# Epoch:4
# Validation Accuracy:61.97, Validation F1:0.62, Val Loss: 0.39489
# Training Acc: 77.39, Training F1:0.77, Train Loss: 0.34033
# Epoch:5
# Validation Accuracy:64.33, Validation F1:0.64, Val Loss: 0.38727
# Training Acc: 82.61, Training F1:0.83, Train Loss: 0.31604
# Epoch:6
# Validation Accuracy:65.95, Validation F1:0.66, Val Loss: 0.38161
# Training Acc: 84.20, Training F1:0.84, Train Loss: 0.30862
# Epoch:7
# Validation Accuracy:66.51, Validation F1:0.67, Val Loss: 0.37875
# Training Acc: 86.67, Training F1:0.87, Train Loss: 0.29024
# Epoch:8
# Validation Accuracy:67.57, Validation F1:0.68, Val Loss: 0.37532
# Training Acc: 87.73, Training F1:0.88, Train Loss: 0.27623
# Epoch:9
# Validation Accuracy:68.20, Validation F1:0.68, Val Loss: 0.36719
# Training Acc: 88.50, Training F1:0.89, Train Loss: 0.26638
# Epoch:10
# Validation Accuracy:68.24, Validation F1:0.68, Val Loss: 0.36053
# Training Acc: 90.82, Training F1:0.91, Train Loss: 0.24876
# Epoch:11
# Validation Accuracy:69.08, Validation F1:0.69, Val Loss: 0.36213
# Training Acc: 91.35, Training F1:0.91, Train Loss: 0.24169
# Epoch:12
# Validation Accuracy:69.07, Validation F1:0.69, Val Loss: 0.35755
# Training Acc: 93.43, Training F1:0.93, Train Loss: 0.22487
# Epoch:13
# Validation Accuracy:69.48, Validation F1:0.69, Val Loss: 0.35373
# Training Acc: 94.30, Training F1:0.94, Train Loss: 0.21534
# Epoch:14
# Validation Accuracy:69.60, Validation F1:0.70, Val Loss: 0.35122
# Training Acc: 95.02, Training F1:0.95, Train Loss: 0.20304
# Epoch:15
# Validation Accuracy:70.17, Validation F1:0.70, Val Loss: 0.34932
# Training Acc: 95.41, Training F1:0.95, Train Loss: 0.19096
# Epoch:16
# Validation Accuracy:70.73, Validation F1:0.71, Val Loss: 0.34639
# Training Acc: 96.62, Training F1:0.97, Train Loss: 0.18116
# Epoch:17
# Validation Accuracy:70.58, Validation F1:0.71, Val Loss: 0.34500
# Training Acc: 97.63, Training F1:0.98, Train Loss: 0.16938
# Epoch:18
# Validation Accuracy:70.68, Validation F1:0.71, Val Loss: 0.34060
# Training Acc: 97.68, Training F1:0.98, Train Loss: 0.16004
# Epoch:19
# Validation Accuracy:70.90, Validation F1:0.71, Val Loss: 0.34006
# Training Acc: 98.12, Training F1:0.98, Train Loss: 0.14983
# Epoch:20
# Validation Accuracy:71.01, Validation F1:0.71, Val Loss: 0.33746
# Training Acc: 98.60, Training F1:0.99, Train Loss: 0.13782
# Epoch:21
# Validation Accuracy:71.19, Validation F1:0.71, Val Loss: 0.33621
# Training Acc: 99.23, Training F1:0.99, Train Loss: 0.13133
# Epoch:22
# Validation Accuracy:71.25, Validation F1:0.71, Val Loss: 0.33547
# Training Acc: 99.52, Training F1:1.00, Train Loss: 0.12268
# Epoch:23
# Validation Accuracy:71.18, Validation F1:0.71, Val Loss: 0.33723
# Training Acc: 99.57, Training F1:1.00, Train Loss: 0.11318
# Epoch:24
# Validation Accuracy:71.52, Validation F1:0.72, Val Loss: 0.33398
# Training Acc: 99.66, Training F1:1.00, Train Loss: 0.10410
# Epoch:25
# Validation Accuracy:71.25, Validation F1:0.71, Val Loss: 0.33162
# Training Acc: 99.81, Training F1:1.00, Train Loss: 0.09768
# Epoch:26
# Validation Accuracy:71.75, Validation F1:0.72, Val Loss: 0.33166
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.08801
# Epoch:27
# Validation Accuracy:71.73, Validation F1:0.72, Val Loss: 0.33143
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.08317
# Epoch:28
# Validation Accuracy:71.69, Validation F1:0.72, Val Loss: 0.33345
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.07476
# Epoch    28: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:29
# Validation Accuracy:71.76, Validation F1:0.72, Val Loss: 0.32517
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06858
# Epoch:30
# Validation Accuracy:71.78, Validation F1:0.72, Val Loss: 0.32702
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06778
# Epoch:31
# Validation Accuracy:71.97, Validation F1:0.72, Val Loss: 0.32816
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06864
# Epoch:32
# Validation Accuracy:71.85, Validation F1:0.72, Val Loss: 0.32896
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06775
# Epoch:33
# Validation Accuracy:72.00, Validation F1:0.72, Val Loss: 0.32717
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06581
# Epoch    33: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:34
# Validation Accuracy:71.83, Validation F1:0.72, Val Loss: 0.32968
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06462
# Epoch:35
# Validation Accuracy:71.81, Validation F1:0.72, Val Loss: 0.32845
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06530
# Epoch:36
# Validation Accuracy:71.99, Validation F1:0.72, Val Loss: 0.32540
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06634
# Epoch    36: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:37
# Validation Accuracy:71.78, Validation F1:0.72, Val Loss: 0.33162
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06705
# Epoch:38
# Validation Accuracy:71.70, Validation F1:0.72, Val Loss: 0.32805
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06536
# Epoch:39
# Validation Accuracy:71.81, Validation F1:0.72, Val Loss: 0.33098
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06541
# Epoch:40
# Validation Accuracy:72.05, Validation F1:0.72, Val Loss: 0.32568
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06619
# Epoch:41
# Validation Accuracy:71.84, Validation F1:0.72, Val Loss: 0.33009
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06576
# Epoch:42
# Validation Accuracy:71.79, Validation F1:0.72, Val Loss: 0.32799
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06560
# Epoch:43
# Validation Accuracy:71.75, Validation F1:0.72, Val Loss: 0.32945
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06642
# Epoch:44
# Validation Accuracy:71.88, Validation F1:0.72, Val Loss: 0.32752
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06604
# Epoch:45
# Validation Accuracy:71.94, Validation F1:0.72, Val Loss: 0.33126
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06556
# Epoch:46
# Validation Accuracy:72.16, Validation F1:0.72, Val Loss: 0.32709
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06400
# Epoch:47
# Validation Accuracy:71.82, Validation F1:0.72, Val Loss: 0.32958
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06545
# Epoch:48
# Validation Accuracy:71.93, Validation F1:0.72, Val Loss: 0.32731
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06621
# Epoch:49
# Validation Accuracy:71.96, Validation F1:0.72, Val Loss: 0.32594
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06521
# Epoch:50
# Validation Accuracy:71.87, Validation F1:0.72, Val Loss: 0.32821
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.06669
# Epoch:1
# Validation Accuracy:65.89, Validation F1:0.66, Val Loss: 0.38125
# Training Acc: 68.97, Training F1:0.69, Train Loss: 0.37174
# Epoch:2
# Validation Accuracy:70.59, Validation F1:0.71, Val Loss: 0.35270
# Training Acc: 74.92, Training F1:0.75, Train Loss: 0.33619
# Epoch:3
# Validation Accuracy:72.58, Validation F1:0.73, Val Loss: 0.33737
# Training Acc: 78.37, Training F1:0.78, Train Loss: 0.30712
# Epoch:4
# Validation Accuracy:73.56, Validation F1:0.74, Val Loss: 0.32349
# Training Acc: 79.92, Training F1:0.80, Train Loss: 0.28521
# Epoch:5
# Validation Accuracy:74.92, Validation F1:0.75, Val Loss: 0.31516
# Training Acc: 84.04, Training F1:0.84, Train Loss: 0.26355
# Epoch:6
# Validation Accuracy:75.74, Validation F1:0.76, Val Loss: 0.30583
# Training Acc: 85.50, Training F1:0.86, Train Loss: 0.24346
# Epoch:7
# Validation Accuracy:76.34, Validation F1:0.76, Val Loss: 0.30272
# Training Acc: 88.76, Training F1:0.89, Train Loss: 0.22503
# Epoch:8
# Validation Accuracy:77.54, Validation F1:0.78, Val Loss: 0.29380
# Training Acc: 90.60, Training F1:0.91, Train Loss: 0.20351
# Epoch:9
# Validation Accuracy:77.74, Validation F1:0.78, Val Loss: 0.28380
# Training Acc: 92.79, Training F1:0.93, Train Loss: 0.18177
# Epoch:10
# Validation Accuracy:78.41, Validation F1:0.78, Val Loss: 0.27886
# Training Acc: 93.91, Training F1:0.94, Train Loss: 0.15867
# Epoch:11
# Validation Accuracy:78.65, Validation F1:0.79, Val Loss: 0.27636
# Training Acc: 96.30, Training F1:0.96, Train Loss: 0.14277
# Epoch:12
# Validation Accuracy:78.75, Validation F1:0.79, Val Loss: 0.27176
# Training Acc: 97.57, Training F1:0.98, Train Loss: 0.12079
# Epoch:13
# Validation Accuracy:79.23, Validation F1:0.79, Val Loss: 0.26494
# Training Acc: 98.24, Training F1:0.98, Train Loss: 0.09894
# Epoch:14
# Validation Accuracy:79.13, Validation F1:0.79, Val Loss: 0.26041
# Training Acc: 99.05, Training F1:0.99, Train Loss: 0.08445
# Epoch:15
# Validation Accuracy:78.61, Validation F1:0.79, Val Loss: 0.26583
# Training Acc: 99.46, Training F1:0.99, Train Loss: 0.07133
# Epoch    15: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:16
# Validation Accuracy:79.00, Validation F1:0.79, Val Loss: 0.26319
# Training Acc: 99.56, Training F1:1.00, Train Loss: 0.05998
# Epoch:17
# Validation Accuracy:79.13, Validation F1:0.79, Val Loss: 0.25987
# Training Acc: 99.68, Training F1:1.00, Train Loss: 0.05832
# Epoch:18
# Validation Accuracy:79.29, Validation F1:0.79, Val Loss: 0.26395
# Training Acc: 99.75, Training F1:1.00, Train Loss: 0.05837
# Epoch:19
# Validation Accuracy:79.23, Validation F1:0.79, Val Loss: 0.26440
# Training Acc: 99.81, Training F1:1.00, Train Loss: 0.05554
# Epoch:20
# Validation Accuracy:79.32, Validation F1:0.79, Val Loss: 0.26349
# Training Acc: 99.80, Training F1:1.00, Train Loss: 0.05517
# Epoch:21
# Validation Accuracy:79.38, Validation F1:0.79, Val Loss: 0.26167
# Training Acc: 99.85, Training F1:1.00, Train Loss: 0.05460
# Epoch:22
# Validation Accuracy:79.32, Validation F1:0.79, Val Loss: 0.25524
# Training Acc: 99.82, Training F1:1.00, Train Loss: 0.05358
# Epoch:23
# Validation Accuracy:79.20, Validation F1:0.79, Val Loss: 0.26010
# Training Acc: 99.82, Training F1:1.00, Train Loss: 0.05150
# Epoch    23: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:24
# Validation Accuracy:79.27, Validation F1:0.79, Val Loss: 0.26225
# Training Acc: 99.85, Training F1:1.00, Train Loss: 0.05143
# Epoch:25
# Validation Accuracy:79.25, Validation F1:0.79, Val Loss: 0.25816
# Training Acc: 99.88, Training F1:1.00, Train Loss: 0.04878
# Epoch:26
# Validation Accuracy:79.13, Validation F1:0.79, Val Loss: 0.26416
# Training Acc: 99.88, Training F1:1.00, Train Loss: 0.04940
# Epoch    26: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:27
# Validation Accuracy:79.23, Validation F1:0.79, Val Loss: 0.26185
# Training Acc: 99.84, Training F1:1.00, Train Loss: 0.05040
# Epoch:28
# Validation Accuracy:79.29, Validation F1:0.79, Val Loss: 0.25903
# Training Acc: 99.82, Training F1:1.00, Train Loss: 0.05263
# Epoch:29
# Validation Accuracy:79.17, Validation F1:0.79, Val Loss: 0.25897
# Training Acc: 99.85, Training F1:1.00, Train Loss: 0.04995
# Epoch:30
# Validation Accuracy:79.18, Validation F1:0.79, Val Loss: 0.26297
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.04918
# Epoch:31
# Validation Accuracy:79.32, Validation F1:0.79, Val Loss: 0.25855
# Training Acc: 99.82, Training F1:1.00, Train Loss: 0.05228
# Epoch:32
# Validation Accuracy:79.30, Validation F1:0.79, Val Loss: 0.25999
# Training Acc: 99.85, Training F1:1.00, Train Loss: 0.05195
# Epoch:33
# Validation Accuracy:79.20, Validation F1:0.79, Val Loss: 0.25692
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.04909
# Epoch:34
# Validation Accuracy:79.19, Validation F1:0.79, Val Loss: 0.25855
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.05090
# Epoch:35
# Validation Accuracy:79.32, Validation F1:0.79, Val Loss: 0.25993
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.04905
# Epoch:36
# Validation Accuracy:79.18, Validation F1:0.79, Val Loss: 0.25743
# Training Acc: 99.88, Training F1:1.00, Train Loss: 0.04945
# Epoch:37
# Validation Accuracy:79.09, Validation F1:0.79, Val Loss: 0.26007
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.05084
# Epoch:38
# Validation Accuracy:79.12, Validation F1:0.79, Val Loss: 0.25929
# Training Acc: 99.85, Training F1:1.00, Train Loss: 0.05078
# Epoch:39
# Validation Accuracy:79.24, Validation F1:0.79, Val Loss: 0.26131
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.04871
# Epoch:40
# Validation Accuracy:79.41, Validation F1:0.79, Val Loss: 0.26133
# Training Acc: 99.88, Training F1:1.00, Train Loss: 0.05018
# Epoch:41
# Validation Accuracy:79.06, Validation F1:0.79, Val Loss: 0.25940
# Training Acc: 99.83, Training F1:1.00, Train Loss: 0.04963
# Epoch:42
# Validation Accuracy:79.15, Validation F1:0.79, Val Loss: 0.25928
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.04979
# Epoch:43
# Validation Accuracy:79.32, Validation F1:0.79, Val Loss: 0.26201
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.04979
# Epoch:44
# Validation Accuracy:79.17, Validation F1:0.79, Val Loss: 0.26078
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.05008
# Epoch:45
# Validation Accuracy:79.31, Validation F1:0.79, Val Loss: 0.25850
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.05009
# Epoch:46
# Validation Accuracy:79.36, Validation F1:0.79, Val Loss: 0.26057
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.05001
# Epoch:47
# Validation Accuracy:79.17, Validation F1:0.79, Val Loss: 0.26429
# Training Acc: 99.88, Training F1:1.00, Train Loss: 0.05133
# Epoch:48
# Validation Accuracy:79.29, Validation F1:0.79, Val Loss: 0.26242
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.04911
# Epoch:49
# Validation Accuracy:79.23, Validation F1:0.79, Val Loss: 0.26525
# Training Acc: 99.85, Training F1:1.00, Train Loss: 0.05068
# Epoch:50
# Validation Accuracy:78.97, Validation F1:0.79, Val Loss: 0.25962
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.04975
# Epoch:1
# Validation Accuracy:69.72, Validation F1:0.70, Val Loss: 0.35588
# Training Acc: 72.12, Training F1:0.72, Train Loss: 0.34342
# Epoch:2
# Validation Accuracy:73.10, Validation F1:0.73, Val Loss: 0.32751
# Training Acc: 75.72, Training F1:0.76, Train Loss: 0.30168
# Epoch:3
# Validation Accuracy:74.95, Validation F1:0.75, Val Loss: 0.30971
# Training Acc: 79.57, Training F1:0.80, Train Loss: 0.27372
# Epoch:4
# Validation Accuracy:76.76, Validation F1:0.77, Val Loss: 0.29089
# Training Acc: 83.64, Training F1:0.84, Train Loss: 0.24745
# Epoch:5
# Validation Accuracy:78.55, Validation F1:0.79, Val Loss: 0.27963
# Training Acc: 86.96, Training F1:0.87, Train Loss: 0.21857
# Epoch:6
# Validation Accuracy:79.80, Validation F1:0.80, Val Loss: 0.26753
# Training Acc: 90.16, Training F1:0.90, Train Loss: 0.18938
# Epoch:7
# Validation Accuracy:80.67, Validation F1:0.81, Val Loss: 0.25422
# Training Acc: 92.59, Training F1:0.93, Train Loss: 0.16223
# Epoch:8
# Validation Accuracy:81.23, Validation F1:0.81, Val Loss: 0.24456
# Training Acc: 94.37, Training F1:0.94, Train Loss: 0.13449
# Epoch:9
# Validation Accuracy:81.87, Validation F1:0.82, Val Loss: 0.23625
# Training Acc: 96.61, Training F1:0.97, Train Loss: 0.10610
# Epoch:10
# Validation Accuracy:82.43, Validation F1:0.82, Val Loss: 0.22770
# Training Acc: 97.61, Training F1:0.98, Train Loss: 0.08741
# Epoch:11
# Validation Accuracy:83.07, Validation F1:0.83, Val Loss: 0.22895
# Training Acc: 98.80, Training F1:0.99, Train Loss: 0.07094
# Epoch:12
# Validation Accuracy:82.64, Validation F1:0.83, Val Loss: 0.22749
# Training Acc: 99.36, Training F1:0.99, Train Loss: 0.05617
# Epoch:13
# Validation Accuracy:83.40, Validation F1:0.83, Val Loss: 0.23075
# Training Acc: 99.68, Training F1:1.00, Train Loss: 0.04383
# Epoch:14
# Validation Accuracy:82.81, Validation F1:0.83, Val Loss: 0.22319
# Training Acc: 99.86, Training F1:1.00, Train Loss: 0.03463
# Epoch:15
# Validation Accuracy:82.86, Validation F1:0.83, Val Loss: 0.22434
# Training Acc: 99.92, Training F1:1.00, Train Loss: 0.02731
# Epoch    15: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:16
# Validation Accuracy:82.35, Validation F1:0.82, Val Loss: 0.22087
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.02226
# Epoch:17
# Validation Accuracy:82.95, Validation F1:0.83, Val Loss: 0.22507
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.02097
# Epoch:18
# Validation Accuracy:82.97, Validation F1:0.83, Val Loss: 0.22569
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.02044
# Epoch    18: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:19
# Validation Accuracy:82.83, Validation F1:0.83, Val Loss: 0.22509
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01956
# Epoch:20
# Validation Accuracy:82.81, Validation F1:0.83, Val Loss: 0.22852
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01919
# Epoch:21
# Validation Accuracy:83.03, Validation F1:0.83, Val Loss: 0.22561
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.01937
# Epoch    21: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:22
# Validation Accuracy:82.89, Validation F1:0.83, Val Loss: 0.22655
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01979
# Epoch:23
# Validation Accuracy:82.93, Validation F1:0.83, Val Loss: 0.22573
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01954
# Epoch:24
# Validation Accuracy:82.80, Validation F1:0.83, Val Loss: 0.21982
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.01975
# Epoch:25
# Validation Accuracy:83.00, Validation F1:0.83, Val Loss: 0.22792
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01918
# Epoch:26
# Validation Accuracy:82.92, Validation F1:0.83, Val Loss: 0.22617
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01951
# Epoch:27
# Validation Accuracy:82.69, Validation F1:0.83, Val Loss: 0.22554
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01937
# Epoch:28
# Validation Accuracy:82.95, Validation F1:0.83, Val Loss: 0.22708
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.02006
# Epoch:29
# Validation Accuracy:82.60, Validation F1:0.83, Val Loss: 0.22076
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01939
# Epoch:30
# Validation Accuracy:82.53, Validation F1:0.83, Val Loss: 0.22808
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01960
# Epoch:31
# Validation Accuracy:82.82, Validation F1:0.83, Val Loss: 0.22613
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01931
# Epoch:32
# Validation Accuracy:82.66, Validation F1:0.83, Val Loss: 0.22235
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01941
# Epoch:33
# Validation Accuracy:83.10, Validation F1:0.83, Val Loss: 0.22326
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01986
# Epoch:34
# Validation Accuracy:82.81, Validation F1:0.83, Val Loss: 0.22206
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01938
# Epoch:35
# Validation Accuracy:82.83, Validation F1:0.83, Val Loss: 0.22375
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01927
# Epoch:36
# Validation Accuracy:83.21, Validation F1:0.83, Val Loss: 0.22540
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.01954
# Epoch:37
# Validation Accuracy:82.84, Validation F1:0.83, Val Loss: 0.22288
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.01922
# Epoch:38
# Validation Accuracy:83.06, Validation F1:0.83, Val Loss: 0.22642
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01955
# Epoch:39
# Validation Accuracy:82.72, Validation F1:0.83, Val Loss: 0.22950
# Training Acc: 100.00, Training F1:1.00, Train Loss: 0.01909
# Epoch:40
# Validation Accuracy:82.70, Validation F1:0.83, Val Loss: 0.22449
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01994
# Epoch:41
# Validation Accuracy:82.93, Validation F1:0.83, Val Loss: 0.22594
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01900
# Epoch:42
# Validation Accuracy:83.01, Validation F1:0.83, Val Loss: 0.22458
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.01951
# Epoch:43
# Validation Accuracy:83.06, Validation F1:0.83, Val Loss: 0.22114
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01891
# Epoch:44
# Validation Accuracy:83.07, Validation F1:0.83, Val Loss: 0.22768
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01929
# Epoch:45
# Validation Accuracy:82.56, Validation F1:0.83, Val Loss: 0.22767
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.02062
# Epoch:46
# Validation Accuracy:82.65, Validation F1:0.83, Val Loss: 0.22418
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01946
# Epoch:47
# Validation Accuracy:82.80, Validation F1:0.83, Val Loss: 0.22698
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01871
# Epoch:48
# Validation Accuracy:82.99, Validation F1:0.83, Val Loss: 0.22568
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.02003
# Epoch:49
# Validation Accuracy:82.86, Validation F1:0.83, Val Loss: 0.22624
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.01950
# Epoch:50
# Validation Accuracy:83.06, Validation F1:0.83, Val Loss: 0.22927
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.01932
# Epoch:1
# Validation Accuracy:73.29, Validation F1:0.73, Val Loss: 0.32162
# Training Acc: 74.53, Training F1:0.75, Train Loss: 0.31401
# Epoch:2
# Validation Accuracy:76.54, Validation F1:0.77, Val Loss: 0.28709
# Training Acc: 79.94, Training F1:0.80, Train Loss: 0.26881
# Epoch:3
# Validation Accuracy:79.72, Validation F1:0.80, Val Loss: 0.26487
# Training Acc: 84.81, Training F1:0.85, Train Loss: 0.22735
# Epoch:4
# Validation Accuracy:82.42, Validation F1:0.82, Val Loss: 0.24154
# Training Acc: 89.44, Training F1:0.89, Train Loss: 0.18827
# Epoch:5
# Validation Accuracy:85.22, Validation F1:0.85, Val Loss: 0.21995
# Training Acc: 93.48, Training F1:0.93, Train Loss: 0.14472
# Epoch:6
# Validation Accuracy:86.61, Validation F1:0.87, Val Loss: 0.19976
# Training Acc: 96.06, Training F1:0.96, Train Loss: 0.11005
# Epoch:7
# Validation Accuracy:87.50, Validation F1:0.88, Val Loss: 0.18423
# Training Acc: 97.58, Training F1:0.98, Train Loss: 0.08116
# Epoch:8
# Validation Accuracy:88.51, Validation F1:0.89, Val Loss: 0.17479
# Training Acc: 98.55, Training F1:0.99, Train Loss: 0.05905
# Epoch:9
# Validation Accuracy:88.95, Validation F1:0.89, Val Loss: 0.16199
# Training Acc: 99.27, Training F1:0.99, Train Loss: 0.04258
# Epoch:10
# Validation Accuracy:89.05, Validation F1:0.89, Val Loss: 0.15781
# Training Acc: 99.70, Training F1:1.00, Train Loss: 0.03045
# Epoch:11
# Validation Accuracy:89.27, Validation F1:0.89, Val Loss: 0.15547
# Training Acc: 99.84, Training F1:1.00, Train Loss: 0.02241
# Epoch:12
# Validation Accuracy:89.36, Validation F1:0.89, Val Loss: 0.15659
# Training Acc: 99.87, Training F1:1.00, Train Loss: 0.01672
# Epoch:13
# Validation Accuracy:89.20, Validation F1:0.89, Val Loss: 0.16000
# Training Acc: 99.93, Training F1:1.00, Train Loss: 0.01314
# Epoch:14
# Validation Accuracy:89.07, Validation F1:0.89, Val Loss: 0.15840
# Training Acc: 99.95, Training F1:1.00, Train Loss: 0.01006
# Epoch    14: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:15
# Validation Accuracy:89.09, Validation F1:0.89, Val Loss: 0.15588
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.00755
# Epoch:16
# Validation Accuracy:89.23, Validation F1:0.89, Val Loss: 0.16283
# Training Acc: 99.97, Training F1:1.00, Train Loss: 0.00676
# Epoch:17
# Validation Accuracy:89.21, Validation F1:0.89, Val Loss: 0.15808
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00608
# Epoch    17: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:18
# Validation Accuracy:89.37, Validation F1:0.89, Val Loss: 0.15605
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00626
# Epoch:19
# Validation Accuracy:89.20, Validation F1:0.89, Val Loss: 0.15469
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00615
# Epoch:20
# Validation Accuracy:89.38, Validation F1:0.89, Val Loss: 0.15508
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00626
# Epoch    20: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:21
# Validation Accuracy:89.25, Validation F1:0.89, Val Loss: 0.15862
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00619
# Epoch:22
# Validation Accuracy:89.35, Validation F1:0.89, Val Loss: 0.15687
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00596
# Epoch:23
# Validation Accuracy:89.15, Validation F1:0.89, Val Loss: 0.15807
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00630
# Epoch:24
# Validation Accuracy:89.34, Validation F1:0.89, Val Loss: 0.15923
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00616
# Epoch:25
# Validation Accuracy:89.32, Validation F1:0.89, Val Loss: 0.16137
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00591
# Epoch:26
# Validation Accuracy:89.29, Validation F1:0.89, Val Loss: 0.16068
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00602
# Epoch:27
# Validation Accuracy:89.44, Validation F1:0.89, Val Loss: 0.16020
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00614
# Epoch:28
# Validation Accuracy:89.23, Validation F1:0.89, Val Loss: 0.15594
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00577
# Epoch:29
# Validation Accuracy:89.31, Validation F1:0.89, Val Loss: 0.15255
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00616
# Epoch:30
# Validation Accuracy:89.31, Validation F1:0.89, Val Loss: 0.15988
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00587
# Epoch:31
# Validation Accuracy:89.15, Validation F1:0.89, Val Loss: 0.15275
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00607
# Epoch:32
# Validation Accuracy:89.34, Validation F1:0.89, Val Loss: 0.15232
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00573
# Epoch:33
# Validation Accuracy:89.32, Validation F1:0.89, Val Loss: 0.15231
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00616
# Epoch:34
# Validation Accuracy:89.27, Validation F1:0.89, Val Loss: 0.15818
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00606
# Epoch:35
# Validation Accuracy:89.27, Validation F1:0.89, Val Loss: 0.16189
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00593
# Epoch:36
# Validation Accuracy:89.15, Validation F1:0.89, Val Loss: 0.15837
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00602
# Epoch:37
# Validation Accuracy:89.11, Validation F1:0.89, Val Loss: 0.15341
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00606
# Epoch:38
# Validation Accuracy:89.36, Validation F1:0.89, Val Loss: 0.16080
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00617
# Epoch:39
# Validation Accuracy:89.20, Validation F1:0.89, Val Loss: 0.15723
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00603
# Epoch:40
# Validation Accuracy:89.26, Validation F1:0.89, Val Loss: 0.15747
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00597
# Epoch:41
# Validation Accuracy:89.31, Validation F1:0.89, Val Loss: 0.15987
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00578
# Epoch:42
# Validation Accuracy:89.36, Validation F1:0.89, Val Loss: 0.15721
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00603
# Epoch:43
# Validation Accuracy:89.27, Validation F1:0.89, Val Loss: 0.15516
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00581
# Epoch:44
# Validation Accuracy:89.38, Validation F1:0.89, Val Loss: 0.15644
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00601
# Epoch:45
# Validation Accuracy:89.40, Validation F1:0.89, Val Loss: 0.15787
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00605
# Epoch:46
# Validation Accuracy:89.36, Validation F1:0.89, Val Loss: 0.15797
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00589
# Epoch:47
# Validation Accuracy:89.37, Validation F1:0.89, Val Loss: 0.16007
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00579
# Epoch:48
# Validation Accuracy:89.44, Validation F1:0.89, Val Loss: 0.15618
# Training Acc: 99.98, Training F1:1.00, Train Loss: 0.00616
# Epoch:49
# Validation Accuracy:89.26, Validation F1:0.89, Val Loss: 0.15605
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00566
# Epoch:50
# Validation Accuracy:89.36, Validation F1:0.89, Val Loss: 0.15643
# Training Acc: 99.99, Training F1:1.00, Train Loss: 0.00605
# Epoch:1
# Validation Accuracy:70.37, Validation F1:0.70, Val Loss: 0.34744
# Training Acc: 71.66, Training F1:0.72, Train Loss: 0.33736
# Epoch:2
# Validation Accuracy:72.48, Validation F1:0.72, Val Loss: 0.31992
# Training Acc: 74.39, Training F1:0.74, Train Loss: 0.30609
# Epoch:3
# Validation Accuracy:73.87, Validation F1:0.74, Val Loss: 0.30877
# Training Acc: 76.66, Training F1:0.77, Train Loss: 0.28242
# Epoch:4
# Validation Accuracy:74.56, Validation F1:0.75, Val Loss: 0.30151
# Training Acc: 79.72, Training F1:0.80, Train Loss: 0.25991
# Epoch:5
# Validation Accuracy:75.29, Validation F1:0.75, Val Loss: 0.29163
# Training Acc: 82.94, Training F1:0.83, Train Loss: 0.24075
# Epoch:6
# Validation Accuracy:75.69, Validation F1:0.76, Val Loss: 0.29008
# Training Acc: 85.10, Training F1:0.85, Train Loss: 0.22158
# Epoch:7
# Validation Accuracy:75.91, Validation F1:0.76, Val Loss: 0.28547
# Training Acc: 87.87, Training F1:0.88, Train Loss: 0.19758
# Epoch:8
# Validation Accuracy:75.80, Validation F1:0.76, Val Loss: 0.28238
# Training Acc: 90.14, Training F1:0.90, Train Loss: 0.17550
# Epoch:9
# Validation Accuracy:75.65, Validation F1:0.76, Val Loss: 0.29376
# Training Acc: 93.20, Training F1:0.93, Train Loss: 0.14813
# Epoch     9: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:10
# Validation Accuracy:75.06, Validation F1:0.75, Val Loss: 0.29418
# Training Acc: 95.29, Training F1:0.95, Train Loss: 0.12901
# Epoch:11
# Validation Accuracy:75.45, Validation F1:0.75, Val Loss: 0.29524
# Training Acc: 95.76, Training F1:0.96, Train Loss: 0.12009
# Epoch:12
# Validation Accuracy:75.52, Validation F1:0.76, Val Loss: 0.30130
# Training Acc: 95.81, Training F1:0.96, Train Loss: 0.11742
# Epoch    12: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:13
# Validation Accuracy:75.59, Validation F1:0.76, Val Loss: 0.29435
# Training Acc: 96.11, Training F1:0.96, Train Loss: 0.11546
# Epoch:14
# Validation Accuracy:75.32, Validation F1:0.75, Val Loss: 0.29547
# Training Acc: 96.22, Training F1:0.96, Train Loss: 0.11506
# Epoch:15
# Validation Accuracy:75.32, Validation F1:0.75, Val Loss: 0.29324
# Training Acc: 96.35, Training F1:0.96, Train Loss: 0.11344
# Epoch    15: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:16
# Validation Accuracy:75.46, Validation F1:0.75, Val Loss: 0.29127
# Training Acc: 96.33, Training F1:0.96, Train Loss: 0.11325
# Epoch:17
# Validation Accuracy:75.46, Validation F1:0.75, Val Loss: 0.29670
# Training Acc: 96.40, Training F1:0.96, Train Loss: 0.11230
# Epoch:18
# Validation Accuracy:75.41, Validation F1:0.75, Val Loss: 0.29781
# Training Acc: 95.92, Training F1:0.96, Train Loss: 0.11550
# Epoch:19
# Validation Accuracy:75.56, Validation F1:0.76, Val Loss: 0.29565
# Training Acc: 96.32, Training F1:0.96, Train Loss: 0.11212
# Epoch:20
# Validation Accuracy:75.28, Validation F1:0.75, Val Loss: 0.29410
# Training Acc: 96.31, Training F1:0.96, Train Loss: 0.11428
# Epoch:21
# Validation Accuracy:75.43, Validation F1:0.75, Val Loss: 0.28819
# Training Acc: 96.11, Training F1:0.96, Train Loss: 0.11262
# Epoch:22
# Validation Accuracy:75.22, Validation F1:0.75, Val Loss: 0.29872
# Training Acc: 96.50, Training F1:0.97, Train Loss: 0.11267
# Epoch:23
# Validation Accuracy:75.10, Validation F1:0.75, Val Loss: 0.29453
# Training Acc: 96.35, Training F1:0.96, Train Loss: 0.11340
# Epoch:24
# Validation Accuracy:75.36, Validation F1:0.75, Val Loss: 0.29482
# Training Acc: 96.25, Training F1:0.96, Train Loss: 0.11284
# Epoch:25
# Validation Accuracy:75.32, Validation F1:0.75, Val Loss: 0.29331
# Training Acc: 96.35, Training F1:0.96, Train Loss: 0.11299
# Epoch:26
# Validation Accuracy:75.41, Validation F1:0.75, Val Loss: 0.29305
# Training Acc: 96.47, Training F1:0.96, Train Loss: 0.11348
# Epoch:27
# Validation Accuracy:75.62, Validation F1:0.76, Val Loss: 0.29508
# Training Acc: 96.12, Training F1:0.96, Train Loss: 0.11240
# Epoch:28
# Validation Accuracy:75.53, Validation F1:0.76, Val Loss: 0.29557
# Training Acc: 96.14, Training F1:0.96, Train Loss: 0.11276
# Epoch:29
# Validation Accuracy:75.38, Validation F1:0.75, Val Loss: 0.29717
# Training Acc: 96.30, Training F1:0.96, Train Loss: 0.11281
# Epoch:30
# Validation Accuracy:75.63, Validation F1:0.76, Val Loss: 0.29818
# Training Acc: 96.22, Training F1:0.96, Train Loss: 0.11301
# Epoch:31
# Validation Accuracy:75.50, Validation F1:0.75, Val Loss: 0.29816
# Training Acc: 96.41, Training F1:0.96, Train Loss: 0.11235
# Epoch:32
# Validation Accuracy:75.43, Validation F1:0.75, Val Loss: 0.29118
# Training Acc: 96.39, Training F1:0.96, Train Loss: 0.11219
# Epoch:33
# Validation Accuracy:75.26, Validation F1:0.75, Val Loss: 0.29588
# Training Acc: 96.15, Training F1:0.96, Train Loss: 0.11309
# Epoch:34
# Validation Accuracy:75.45, Validation F1:0.75, Val Loss: 0.29562
# Training Acc: 96.43, Training F1:0.96, Train Loss: 0.11234
# Epoch:35
# Validation Accuracy:75.58, Validation F1:0.76, Val Loss: 0.29349
# Training Acc: 96.27, Training F1:0.96, Train Loss: 0.11152
# Epoch:36
# Validation Accuracy:75.30, Validation F1:0.75, Val Loss: 0.29036
# Training Acc: 96.25, Training F1:0.96, Train Loss: 0.11425
# Epoch:37
# Validation Accuracy:75.28, Validation F1:0.75, Val Loss: 0.29269
# Training Acc: 96.37, Training F1:0.96, Train Loss: 0.11384
# Epoch:38
# Validation Accuracy:75.32, Validation F1:0.75, Val Loss: 0.29812
# Training Acc: 96.40, Training F1:0.96, Train Loss: 0.11350
# Epoch:39
# Validation Accuracy:75.55, Validation F1:0.76, Val Loss: 0.29505
# Training Acc: 96.30, Training F1:0.96, Train Loss: 0.11111
# Epoch:40
# Validation Accuracy:75.43, Validation F1:0.75, Val Loss: 0.29942
# Training Acc: 96.03, Training F1:0.96, Train Loss: 0.11269
# Epoch:41
# Validation Accuracy:75.47, Validation F1:0.75, Val Loss: 0.29262
# Training Acc: 96.28, Training F1:0.96, Train Loss: 0.11228
# Epoch:42
# Validation Accuracy:75.44, Validation F1:0.75, Val Loss: 0.29767
# Training Acc: 96.52, Training F1:0.97, Train Loss: 0.11122
# Epoch:43
# Validation Accuracy:75.53, Validation F1:0.76, Val Loss: 0.29399
# Training Acc: 96.51, Training F1:0.97, Train Loss: 0.11222
# Epoch:44
# Validation Accuracy:75.45, Validation F1:0.75, Val Loss: 0.29558
# Training Acc: 96.43, Training F1:0.96, Train Loss: 0.11347
# Epoch:45
# Validation Accuracy:75.44, Validation F1:0.75, Val Loss: 0.29496
# Training Acc: 96.23, Training F1:0.96, Train Loss: 0.11034
# Epoch:46
# Validation Accuracy:75.53, Validation F1:0.76, Val Loss: 0.28705
# Training Acc: 96.27, Training F1:0.96, Train Loss: 0.11403
# Epoch:47
# Validation Accuracy:75.50, Validation F1:0.75, Val Loss: 0.29740
# Training Acc: 96.28, Training F1:0.96, Train Loss: 0.11009
# Epoch:48
# Validation Accuracy:74.94, Validation F1:0.75, Val Loss: 0.29382
# Training Acc: 96.52, Training F1:0.97, Train Loss: 0.11398
# Epoch:49
# Validation Accuracy:75.46, Validation F1:0.75, Val Loss: 0.30078
# Training Acc: 96.62, Training F1:0.97, Train Loss: 0.11128
# Epoch:50
# Validation Accuracy:75.40, Validation F1:0.75, Val Loss: 0.30217
# Training Acc: 96.37, Training F1:0.96, Train Loss: 0.11250

# %%
mean = 0.
std = 0.
for images, _, _ in Train_loader:
    batch_samples = images.size(0) # batch size (the last batch can have smaller size!)
    images1 = images.reshape(batch_samples, images.size(1), -1)
    mean += images1.mean(2).sum(0)
    std += images1.std(2).sum(0)
    
mean /= len(Train_loader.dataset)
std /= len(Train_loader.dataset)

# %%
print(mean, std)
# Out:
# tensor([-24.3633]) tensor([14.2659])

# %%
model = conv_net().to(device)
model.load_state_dict(reqd_weights)
# Out:
# <All keys matched successfully>

# %%
pickle.dump(results_dict, open('Size_Exp_Jigsaw_Wt_Results.pkl'.format(sizes[i]),'wb'))

# %%
results_dict.keys()
# Out:
# dict_keys([10, 50, 250, 500])

# %%
import torchvision.models as models
resnet18 = models.resnet18().to(device)
alexnet = models.alexnet().to(device)
vgg16 = models.vgg16().to(device)
squeezenet = models.squeezenet1_0().to(device)
densenet = models.densenet161().to(device)
inception = models.inception_v3().to(device)

# %%
spectrogram, target, weight = next(iter(Train_loader))    
model.train()
spectrogram_batch, target_batch, weight_batch = spectrogram.to(device), target.to(device), weight.to(device)
x = model.conv1(spectrogram_batch)
x = model.bn1(x)
x = model.relu(x)
x = model.maxpool(x)

x = model.layer1(x)
x = model.layer2(x)
x = model.layer3(x)
x = model.layer4(x)

# %%
model.avgpool = nn.AdaptiveAvgPool2d((1, 1))
model.avgpool(x)
# Out:
# tensor([[[[1.4650]],
#
#          [[0.5089]],
#
#          [[0.9111]],
#
#          ...,
#
#          [[0.3773]],
#
#          [[0.7808]],
#
#          [[0.7331]]],
#
#
#         [[[0.9524]],
#
#          [[0.7230]],
#
#          [[1.1426]],
#
#          ...,
#
#          [[1.1358]],
#
#          [[1.3831]],
#
#          [[1.1897]]],
#
#
#         [[[1.9119]],
#
#          [[1.6279]],
#
#          [[0.7233]],
#
#          ...,
#
#          [[0.5244]],
#
#          [[0.6860]],
#
#          [[1.0922]]],
#
#
#         ...,
#
#
#         [[[0.4779]],
#
#          [[0.7169]],
#
#          [[1.0866]],
#
#          ...,
#
#          [[1.1316]],
#
#          [[0.6493]],
#
#          [[0.5833]]],
#
#
#         [[[0.3052]],
#
#          [[1.0795]],
#
#          [[1.7370]],
#
#          ...,
#
#          [[0.6132]],
#
#          [[2.3522]],
#
#          [[1.9071]]],
#
#
#         [[[0.1804]],
#
#          [[0.4987]],
#
#          [[1.0965]],
#
#          ...,
#
#          [[0.9759]],
#
#          [[0.5855]],
#
#          [[0.4740]]]], device='cuda:0', grad_fn=<ViewBackward>)
